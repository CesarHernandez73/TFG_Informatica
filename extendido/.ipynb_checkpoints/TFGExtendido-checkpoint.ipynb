# %% [markdown]
# ### TFG - Cesar Hernandez Rodriguez
# Segundos pasos en las redes neuronales y la bolsa, para este caso buscamos predecir valores y no tendencias
#
# Este script se basa en descargar datos de la bolsa de EEUU, exactamente todos los del índice nasdaq que es uno de los índices más importantes de Estados Unidos, siendo la segunda bolsa de valores automatizada y electronica mas grande del mundo con 3800 compañias. (https://es.wikipedia.org/wiki/NASDAQ)
#
# Para ello usaré la librería QUANDL (https://www.quandl.com/tools/python) que implementa una API para poder descargar los datos de manera sencilla.
#
# El primer paso será mediante WEB-Scrapping descargar de Wikipedia los tickets de los 500 valores del índice bursatil, después ire recursivamente descargando todos los datos disponibles de los 500 valores desde el 2000 hasta el final del año 2017, estos datos los usare para entrenar la red neuronal y poder predecir el primer trimestre de 2018. La selección de estas fechas se debe al a disponibilidad que ofrece la librería Quandl ya que al usarla de forma gratuita no se puede descargar los históricos de todos los datos ni todo los datos más actuales, de todas formas aún asi vamos a tener problemas ya que solo he conseguido de 485 de 500 activos y de algunos no tenemos unos datos históricos tan extensos como lo que buscabamos.
#
# A mayores una vez descagardo los datos (ya que tarda mucho) los voy a guardar dentro de mi ordenador serializandolo con el paquete Pickle (http://pyspanishdoc.sourceforge.net/lib/module-pickle.html)

# %%
import pandas as pd
import numpy as np
import random
import quandl
from time import time
import pickle
import matplotlib.pyplot as plt
from collections import Counter
from sklearn import model_selection
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from math import *
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.

# %%
#Tengo dos bases de datos con todos los tickers del indice nasdaq y todos los tickers
# que tiene mi base de datos y extraigo solo los que tengo
def get_tickers_sample_nasdaq():
    tickers_wiki_quandl = pd.read_csv('WIKI_PRICES.csv')['ticker']
    tickers_nasdaq = pd.read_csv('nasdaq-listed-symbols.csv')['Symbol']
    
    tickersQuandl = []    
    tickers = []
    for i in range(len(tickers_nasdaq)):
        word = tickers_nasdaq[i]
        for j in range(len(tickers_wiki_quandl)):
            if word == tickers_wiki_quandl[j]:
                tickers.append(word)
    
    tickers = random.choices(tickers, k=50)
    
    for tick in tickers:
        tickersQuandl.append("WIKI/"+tick)
    
    return tickers, tickersQuandl

# a,b = get_tickers_sample_nasdaq()

# %%
# Descargo los datos de la API Quandl, para ello uso el conjunto de datos que me ofrece WIKI/ que se puede ver en la página 
# de la libreria y me registro en la pagina de forma gratuita dandome esa key.
# me devuelve una lista con los datos y con los datos solo de cierre, a parte de guardan los datos serializados en 
# una carpeta llamada datos/
def get_data(verbose):
    quandl.ApiConfig.api_key = 'WgQVD8Npfox1MN7SV3Nm'
    tickers, tickersQuandl = get_tickers_sample_nasdaq()
    
    print(" ****Empezamos a descargar los datos****\n")
    
    datos = {}
    start_time = time()
    long = len(tickersQuandl)
    i = 0
    for ticker in tickersQuandl:
        if i % 5 == 0:
            print("LLeva descargados el ",i/long *100,"% de los datos")
        aux=quandl.get(ticker,start_date="2000-01-01",end_date="2016-12-31")
        datos[ticker[5:len(ticker)]] = aux
        i = i + 1
    
    datosClose = {}
    for key in datos:
        datosClose[key] = datos[key]["Adj. Close"]
        #print(key, ":", datosClose[key])
    
    elapsed_time = time() - start_time
    print("\nHa tardado en descargar los datos: %0.10f segundos." % elapsed_time)
    
    print("\n ****Empezamos a descargar los datos test****\n")
    
    datos_test = {}
    i = 0
    long = len(tickersQuandl)
    start_time = time()    
    for ticker in tickersQuandl:
        if i % 5 == 0:
            print("LLeva descargados el ",i/long *100,"% de los datos test")
        aux=quandl.get(ticker,start_date="2016-08-23",end_date="2020-12-31")
        datos_test[ticker[5:len(ticker)]] = aux
        i = i + 1
    
    datosClose_test = {}
    for key in datos_test:
        datosClose_test[key] = datos_test[key]["Adj. Close"]
    
        elapsed_time = time() - start_time
    print("\nHa tardado en descargar los datos test: %0.10f segundos." % elapsed_time)
    print("\n")
    
        # Solo cogemos los datos que nos da la aplicacion
    # ya que hay activos que no tenemos su valor en esas fechas o tenemos muy pocos datos
    quitar = []
    for key in tickers:
        if datosClose_test[key].empty:
            if verbose == True : print("Restriccion de vacio",key) 
            datos.pop(key,None)
            datosClose.pop(key,None)
            datos_test.pop(key,None)
            datosClose_test.pop(key,None)
            quitar.append(key)
        elif len(datosClose_test[key]) < 300:
            if verbose == True :  print("Restriccion de longitud",key)
            datos.pop(key,None)
            datosClose.pop(key,None)
            datos_test.pop(key,None)
            datosClose_test.pop(key,None)
            quitar.append(key)
            
    for key in quitar:
        tickers.remove(key)
    
    pickle.dump(tickers, open("datos/tickers_nasdaq.p", "wb"))
    pickle.dump(tickersQuandl, open("datos/tickersQuandl_nasdaq.p", "wb"))
    pickle.dump(datos, open("datos/nasdaq.p", "wb"))
    pickle.dump(datosClose, open("datos/nasdaqClose.p", "wb"))
    pickle.dump(datos_test, open("datos/nasdaq_test.p", "wb"))
    pickle.dump(datosClose_test, open("datos/nasdaqClose_test.p", "wb"))
    
    return tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test

# %%
# Si los datos ya han sido descargados con esta funcion los cargo gracias a la libreria pickles
def get_data_load():
    tickers = pickle.load(open("datos/tickers_nasdaq.p", "rb" ))
    tickersQuandl = pickle.load(open("datos/tickersQuandl_nasdaq.p", "rb" ))
    datos = pickle.load(open("datos/nasdaq.p", "rb" ))
    datosClose = pickle.load(open("datos/nasdaqClose.p", "rb" ))
    return tickers, tickersQuandl, datos, datosClose

def get_data_load_test():
    datos = pickle.load(open("datos/nasdaq_test.p", "rb" ))
    datosClose = pickle.load(open("datos/nasdaqClose_test.p", "rb" ))
    return datos, datosClose

# Para imprimir cualquier conjunto de datos descargados, se necesita el conjunto de datosClose sin ser data frame 
# y el ticker de los valores (luego se muestra un ejemplo)
def plot_datos(datosClose,nombre,test):
    datosClose[nombre].plot(figsize=(12,5),grid=True)
    plt.title('{} {}\n'.format(nombre,test))
    plt.ylabel('Precio de Cierre')
    plt.xlabel('Fecha')
    plt.show()

# %%
datos_descargados = False
if datos_descargados:
    tickers, tickersQuandl, datos, datosClose= get_data_load()
    datos_test, datosClose_test = get_data_load_test()
else : 
    tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test = get_data(True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-f33084d11383> in <module>
#       4     datos_test, datosClose_test = get_data_load_test()
#       5 else :
# ----> 6     tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test = get_data(True)
#
# <ipython-input-3-ffa651726c43> in get_data(verbose)
#       5 def get_data(verbose):
#       6     quandl.ApiConfig.api_key = 'WgQVD8Npfox1MN7SV3Nm'
# ----> 7     tickers, tickersQuandl = get_tickers_sample_nasdaq()
#       8
#       9     print(" ****Empezamos a descargar los datos****\n")
#
# <ipython-input-2-a5b30be199f0> in get_tickers_sample_nasdaq()
#       2 # que tiene mi base de datos y extraigo solo los que tengo
#       3 def get_tickers_sample_nasdaq():
# ----> 4     tickers_wiki_quandl = pd.read_csv('WIKI_PRICES.csv')['ticker']
#       5     tickers_nasdaq = pd.read_csv('nasdaq-listed-symbols.csv')['Symbol']
#       6
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'WIKI_PRICES.csv' does not exist: b'WIKI_PRICES.csv'

# %%
# plot de uno aleatorio
ran = random.randint(0,len(tickers)-1)
plot_datos(datosClose,tickers[ran],"train")
plot_datos(datosClose_test,tickers[ran],"test")

# %%
# plot del que voy a hacer la prediccion
plot_datos(datosClose,tickers[5],"train")
plot_datos(datosClose_test,tickers[5],"test")

# %%
def differences(x):
    return x[-1] - x[0]

# Creamos las variables, aunque podemos meter osciladores o mas medias unicamente
# de momento considero la media movil para sacar la tendencia corta y otra para la tendencia
# larga, como he calculado las tendencias con la media movil de más dias tengo que
# eliminar los primeros \dias datos.
# Añado la variable de variacion de 30 dias de una misma media movil
# Si va yendo bien todo a la hora de hacer esto puedo meter aqui mas atributos, tendre que buscar
# cuales pero que sean restas entre medias moviles, como el momento o la tasa de cambio
def create_features(datosClose,days1,days2):
    X = pd.DataFrame()
    data = pd.DataFrame()
    data['Adj. Close'] = datosClose.values
    
    indices = datosClose.index
    
    X['MA_{}'.format(days1)] = data['Adj. Close'].rolling(window=days1).mean()
    X['MA_{}'.format(days2)] = data['Adj. Close'].rolling(window=days2).mean()
    #X['Diferencia'] = data['Adj. Close'].rolling(window=days2).apply(differences) 
    X = X[days2:(len(X)-days2)].reset_index()
    X.drop(['index'], axis='columns', inplace=True)

    return X, indices[days2:len(indices)-days2]

# %%
#index =  5
index = ran
timeStep = 30

# Extraigo los atributos de los datos y los preparo para meterlos a la red neuronal

X, ind_time = create_features(datosClose[tickers[index]],15,30)
Y = pd.DataFrame(datosClose[tickers[index]].values[30:len(datosClose[tickers[index]])-30])
X = X.to_numpy()

Xt = []
yt = []
index_time = []

for i in range(timeStep, len(X)):
    Xt.append(X[i-timeStep:i,:])
    yt.append(Y.iloc[i,0])
    index_time.append(ind_time[i])


Xt, yt, index_time = np.array(Xt), np.array(yt), pd.Series(index_time)

P=yt.shape[0]
indices=np.arange(P,dtype=int)
np.random.shuffle(indices)
sequences_train=indices[0:int(P*2/3)]
sequences_test=indices[int(P*2/3):]
X_train, X_test, y_train, y_test = Xt[sequences_train],Xt[sequences_test],yt[sequences_train],yt[sequences_test]

# Lo mismo para el conjunto TEST

ticket_uso = tickers[index]
Xtesteo, ind_time_t = create_features(datosClose_test[tickers[index]],15,30)
Ytesteo = pd.DataFrame(datosClose_test[tickers[index]].values[30:len(datosClose_test[tickers[index]])-30])
Xtesteo = Xtesteo.to_numpy()

Xtt = []
ytt = []
index_time_t = []

for i in range(timeStep, len(Xtesteo)):
    Xtt.append(Xtesteo[i-timeStep:i,:])
    ytt.append(Ytesteo.iloc[i,0])
    index_time_t.append(ind_time_t[i])
    
Xtt, ytt, index_time_t = np.array(Xtt), np.array(ytt), pd.Series(index_time_t)
print(ticket_uso)
# Out:
# MGRC

# %%
# Creacion de la red neural LSTM

model = Sequential()
model.add(LSTM(10, input_shape=(30,2),return_sequences=True))
# model.add(Dropout(0.2)) # Ir reduciendo las inputs empezar con 10 y bajar
model.add(LSTM(units = 5,return_sequences = False))
model.add(Dense(1)) 
model.compile(optimizer="adam",loss='mse') 
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 30, 10)            520
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 5)                 320
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 846
# Trainable params: 846
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_LSTM = model.fit(X_train,
                  y_train,
                  epochs=500,
                  verbose=1,
                  validation_data=(X_test,y_test))
# Out:
# Train on 2791 samples, validate on 1396 samples
# Epoch 1/500
# 2791/2791 [==============================] - 4s 1ms/step - loss: 0.3195 - val_loss: 0.3742
# Epoch 2/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3322 - val_loss: 0.3769
# Epoch 3/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3524 - val_loss: 0.4412
# Epoch 4/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3334 - val_loss: 0.3857
# Epoch 5/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3302 - val_loss: 0.3996
# Epoch 6/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3322 - val_loss: 0.3972
# Epoch 7/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3231 - val_loss: 0.3582
# Epoch 8/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3116 - val_loss: 0.3675
# Epoch 9/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3193 - val_loss: 0.3766
# Epoch 10/500
# 2791/2791 [==============================] - 4s 1ms/step - loss: 0.3277 - val_loss: 0.3664
# Epoch 11/500
# 2791/2791 [==============================] - 4s 1ms/step - loss: 0.3106 - val_loss: 0.3480
# Epoch 12/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3086 - val_loss: 0.3514
# Epoch 13/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3355 - val_loss: 0.4995
# Epoch 14/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3450 - val_loss: 0.3685
# Epoch 15/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3321 - val_loss: 0.3587
# Epoch 16/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3085 - val_loss: 0.3732
# Epoch 17/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3140 - val_loss: 0.3818
# Epoch 18/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3067 - val_loss: 0.3997
# Epoch 19/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3241 - val_loss: 0.3610
# Epoch 20/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3241 - val_loss: 0.3689
# Epoch 21/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3141 - val_loss: 0.3594
# Epoch 22/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3214 - val_loss: 0.3613
# Epoch 23/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3167 - val_loss: 0.3832
# Epoch 24/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3297 - val_loss: 0.3435
# Epoch 25/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3071 - val_loss: 0.3843
# Epoch 26/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3110 - val_loss: 0.3523
# Epoch 27/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3093 - val_loss: 0.3735
# Epoch 28/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3100 - val_loss: 0.3443
# Epoch 29/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3106 - val_loss: 0.4573
# Epoch 30/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3278 - val_loss: 0.3656
# Epoch 31/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3206 - val_loss: 0.3659
# Epoch 32/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3058 - val_loss: 0.4632
# Epoch 33/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3159 - val_loss: 0.3426
# Epoch 34/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3269 - val_loss: 0.3680
# Epoch 35/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3060 - val_loss: 0.4001
# Epoch 36/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3180 - val_loss: 0.3538
# Epoch 37/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3098 - val_loss: 0.3526
# Epoch 38/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3198 - val_loss: 0.3531
# Epoch 39/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3137 - val_loss: 0.3455
# Epoch 40/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3047 - val_loss: 0.3588
# Epoch 41/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3100 - val_loss: 0.3518
# Epoch 42/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3120 - val_loss: 0.3634
# Epoch 43/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3254 - val_loss: 0.3595
# Epoch 44/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3026 - val_loss: 0.3376
# Epoch 45/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3133 - val_loss: 0.3878
# Epoch 46/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3163 - val_loss: 0.3391
# Epoch 47/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3153 - val_loss: 0.3319
# Epoch 48/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3078 - val_loss: 0.3347
# Epoch 49/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3084 - val_loss: 0.3484
# Epoch 50/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3156 - val_loss: 0.3607
# Epoch 51/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3106 - val_loss: 0.4187
# Epoch 52/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3418 - val_loss: 0.3456
# Epoch 53/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3021 - val_loss: 0.3989
# Epoch 54/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3180 - val_loss: 0.3527
# Epoch 55/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3042 - val_loss: 0.4544
# Epoch 56/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3013 - val_loss: 0.3445
# Epoch 57/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3066 - val_loss: 0.3433
# Epoch 58/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3094 - val_loss: 0.3344
# Epoch 59/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3048 - val_loss: 0.3879
# Epoch 60/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3043 - val_loss: 0.3337
# Epoch 61/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3062 - val_loss: 0.3986
# Epoch 62/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3105 - val_loss: 0.3320
# Epoch 63/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3062 - val_loss: 0.4342
# Epoch 64/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3027 - val_loss: 0.3382
# Epoch 65/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2935 - val_loss: 0.3386
# Epoch 66/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3135 - val_loss: 0.3415
# Epoch 67/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3082 - val_loss: 0.3395
# Epoch 68/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3029 - val_loss: 0.3502
# Epoch 69/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3136 - val_loss: 0.3829
# Epoch 70/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3014 - val_loss: 0.3655
# Epoch 71/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2949 - val_loss: 0.3385
# Epoch 72/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3040 - val_loss: 0.3360
# Epoch 73/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3254 - val_loss: 0.3575
# Epoch 74/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3046 - val_loss: 0.3733
# Epoch 75/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3030 - val_loss: 0.3478
# Epoch 76/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3073 - val_loss: 0.3282
# Epoch 77/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3128 - val_loss: 0.3308
# Epoch 78/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2953 - val_loss: 0.3595
# Epoch 79/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2964 - val_loss: 0.3571
# Epoch 80/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3085 - val_loss: 0.3466
# Epoch 81/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2977 - val_loss: 0.3357
# Epoch 82/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2952 - val_loss: 0.3308
# Epoch 83/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3002 - val_loss: 0.3956
# Epoch 84/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2964 - val_loss: 0.3651
# Epoch 85/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2951 - val_loss: 0.3419
# Epoch 86/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2936 - val_loss: 0.4060
# Epoch 87/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2911 - val_loss: 0.3381
# Epoch 88/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2994 - val_loss: 0.3534
# Epoch 89/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2988 - val_loss: 0.3470
# Epoch 90/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2928 - val_loss: 0.3548
# Epoch 91/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2951 - val_loss: 0.3361
# Epoch 92/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3040 - val_loss: 0.3475
# Epoch 93/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2923 - val_loss: 0.3445
# Epoch 94/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2960 - val_loss: 0.3448
# Epoch 95/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3118 - val_loss: 0.4197
# Epoch 96/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3052 - val_loss: 0.3286
# Epoch 97/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3005 - val_loss: 0.3562
# Epoch 98/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2946 - val_loss: 0.3344
# Epoch 99/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2950 - val_loss: 0.3436
# Epoch 100/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3039 - val_loss: 0.3299
# Epoch 101/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3184 - val_loss: 0.3705
# Epoch 102/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2945 - val_loss: 0.3450
# Epoch 103/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2931 - val_loss: 0.3416
# Epoch 104/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3080 - val_loss: 0.3323
# Epoch 105/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2939 - val_loss: 0.3381
# Epoch 106/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2875 - val_loss: 0.3666
# Epoch 107/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2879 - val_loss: 0.3283
# Epoch 108/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2948 - val_loss: 0.4267
# Epoch 109/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2992 - val_loss: 0.3529
# Epoch 110/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2972 - val_loss: 0.3416
# Epoch 111/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2941 - val_loss: 0.3268
# Epoch 112/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2941 - val_loss: 0.3382
# Epoch 113/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3097 - val_loss: 0.3393
# Epoch 114/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2998 - val_loss: 0.3315
# Epoch 115/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3003 - val_loss: 0.3204
# Epoch 116/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2886 - val_loss: 0.3454
# Epoch 117/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2964 - val_loss: 0.3260
# Epoch 118/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2927 - val_loss: 0.4001
# Epoch 119/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2991 - val_loss: 0.3495
# Epoch 120/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2921 - val_loss: 0.3183
# Epoch 121/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3021 - val_loss: 0.3172
# Epoch 122/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2851 - val_loss: 0.3184
# Epoch 123/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2918 - val_loss: 0.3549
# Epoch 124/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2876 - val_loss: 0.3201
# Epoch 125/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2863 - val_loss: 0.3901
# Epoch 126/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3019 - val_loss: 0.3461
# Epoch 127/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2919 - val_loss: 0.3217
# Epoch 128/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2914 - val_loss: 0.3368
# Epoch 129/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2872 - val_loss: 0.3170
# Epoch 130/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2867 - val_loss: 0.3184
# Epoch 131/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3030 - val_loss: 0.3280
# Epoch 132/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2876 - val_loss: 0.3317
# Epoch 133/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2898 - val_loss: 0.3160
# Epoch 134/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2864 - val_loss: 0.3156
# Epoch 135/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2955 - val_loss: 0.3213
# Epoch 136/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2950 - val_loss: 0.3211
# Epoch 137/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2835 - val_loss: 0.3195
# Epoch 138/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2842 - val_loss: 0.3375
# Epoch 139/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2916 - val_loss: 0.3159
# Epoch 140/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3005 - val_loss: 0.3300
# Epoch 141/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2899 - val_loss: 0.3238
# Epoch 142/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2930 - val_loss: 0.3348
# Epoch 143/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2933 - val_loss: 0.3151
# Epoch 144/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2833 - val_loss: 0.3267
# Epoch 145/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2943 - val_loss: 0.3739
# Epoch 146/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2811 - val_loss: 0.3187
# Epoch 147/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2843 - val_loss: 0.3436
# Epoch 148/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2870 - val_loss: 0.3481
# Epoch 149/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2832 - val_loss: 0.3172
# Epoch 150/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2854 - val_loss: 0.3547
# Epoch 151/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2806 - val_loss: 0.3273
# Epoch 152/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2886 - val_loss: 0.3288
# Epoch 153/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2921 - val_loss: 0.3225
# Epoch 154/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2806 - val_loss: 0.3072
# Epoch 155/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2801 - val_loss: 0.3135
# Epoch 156/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2935 - val_loss: 0.3530
# Epoch 157/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2891 - val_loss: 0.3299
# Epoch 158/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2981 - val_loss: 0.3264
# Epoch 159/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2935 - val_loss: 0.3285
# Epoch 160/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2936 - val_loss: 0.3244
# Epoch 161/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2972 - val_loss: 0.4276
# Epoch 162/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3121 - val_loss: 0.3307
# Epoch 163/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2810 - val_loss: 0.3355
# Epoch 164/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2917 - val_loss: 0.3461
# Epoch 165/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2845 - val_loss: 0.3147
# Epoch 166/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2822 - val_loss: 0.3229
# Epoch 167/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2866 - val_loss: 0.3228
# Epoch 168/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2857 - val_loss: 0.3211
# Epoch 169/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2874 - val_loss: 0.3220
# Epoch 170/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2799 - val_loss: 0.3659
# Epoch 171/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2906 - val_loss: 0.3155
# Epoch 172/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2841 - val_loss: 0.3236
# Epoch 173/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2770 - val_loss: 0.4873
# Epoch 174/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2982 - val_loss: 0.4302
# Epoch 175/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3129 - val_loss: 0.3341
# Epoch 176/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2842 - val_loss: 0.3081
# Epoch 177/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2758 - val_loss: 0.3250
# Epoch 178/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2867 - val_loss: 0.3419
# Epoch 179/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2932 - val_loss: 0.3115
# Epoch 180/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2849 - val_loss: 0.3188
# Epoch 181/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2803 - val_loss: 0.3131
# Epoch 182/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2784 - val_loss: 0.3362
# Epoch 183/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2867 - val_loss: 0.3890
# Epoch 184/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2886 - val_loss: 0.3366
# Epoch 185/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2827 - val_loss: 0.3308
# Epoch 186/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2958 - val_loss: 0.3094
# Epoch 187/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2759 - val_loss: 0.3324
# Epoch 188/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2826 - val_loss: 0.3304
# Epoch 189/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2893 - val_loss: 0.3351
# Epoch 190/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2865 - val_loss: 0.3098
# Epoch 191/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2775 - val_loss: 0.3528
# Epoch 192/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2842 - val_loss: 0.3573
# Epoch 193/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2951 - val_loss: 0.4190
# Epoch 194/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2997 - val_loss: 0.3100
# Epoch 195/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2755 - val_loss: 0.3247
# Epoch 196/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2942 - val_loss: 0.4858
# Epoch 197/500
# 2791/2791 [==============================] - 4s 1ms/step - loss: 0.2866 - val_loss: 0.3125
# Epoch 198/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2753 - val_loss: 0.3102
# Epoch 199/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2696 - val_loss: 0.3298
# Epoch 200/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2851 - val_loss: 0.3238
# Epoch 201/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2722 - val_loss: 0.3399
# Epoch 202/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2967 - val_loss: 0.4176
# Epoch 203/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2796 - val_loss: 0.3074
# Epoch 204/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2804 - val_loss: 0.3323
# Epoch 205/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.3053 - val_loss: 0.3321
# Epoch 206/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2767 - val_loss: 0.3671
# Epoch 207/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2750 - val_loss: 0.3137
# Epoch 208/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2684 - val_loss: 0.3657
# Epoch 209/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2809 - val_loss: 0.3431
# Epoch 210/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2702 - val_loss: 0.3968
# Epoch 211/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2793 - val_loss: 0.3159
# Epoch 212/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2822 - val_loss: 0.3155
# Epoch 213/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2770 - val_loss: 0.3590
# Epoch 214/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2828 - val_loss: 0.3125
# Epoch 215/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2830 - val_loss: 0.3139
# Epoch 216/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2805 - val_loss: 0.3076
# Epoch 217/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2774 - val_loss: 0.3092
# Epoch 218/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2829 - val_loss: 0.3419
# Epoch 219/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2796 - val_loss: 0.3328
# Epoch 220/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2866 - val_loss: 0.3596
# Epoch 221/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2778 - val_loss: 0.3458
# Epoch 222/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2922 - val_loss: 0.3176
# Epoch 223/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2794 - val_loss: 0.3331
# Epoch 224/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2814 - val_loss: 0.3172
# Epoch 225/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2848 - val_loss: 0.3138
# Epoch 226/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2800 - val_loss: 0.3786
# Epoch 227/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2918 - val_loss: 0.3088
# Epoch 228/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2831 - val_loss: 0.3102
# Epoch 229/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2915 - val_loss: 0.3457
# Epoch 230/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2977 - val_loss: 0.3130
# Epoch 231/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2840 - val_loss: 0.3185
# Epoch 232/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2751 - val_loss: 0.3457
# Epoch 233/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2916 - val_loss: 0.3266
# Epoch 234/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2804 - val_loss: 0.3153
# Epoch 235/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2728 - val_loss: 0.3054
# Epoch 236/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2711 - val_loss: 0.3220
# Epoch 237/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2724 - val_loss: 0.3032
# Epoch 238/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2741 - val_loss: 0.3439
# Epoch 239/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2892 - val_loss: 0.3151
# Epoch 240/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2758 - val_loss: 0.3185
# Epoch 241/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2741 - val_loss: 0.3113
# Epoch 242/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2911 - val_loss: 0.3235
# Epoch 243/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2825 - val_loss: 0.3054
# Epoch 244/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2647 - val_loss: 0.3024
# Epoch 245/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2806 - val_loss: 0.3085
# Epoch 246/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2708 - val_loss: 0.3153
# Epoch 247/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2736 - val_loss: 0.3392
# Epoch 248/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2858 - val_loss: 0.3366
# Epoch 249/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2845 - val_loss: 0.3327
# Epoch 250/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2837 - val_loss: 0.3278
# Epoch 251/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2801 - val_loss: 0.4648
# Epoch 252/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2867 - val_loss: 0.3089
# Epoch 253/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2792 - val_loss: 0.3300
# Epoch 254/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2827 - val_loss: 0.3456
# Epoch 255/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2806 - val_loss: 0.3160
# Epoch 256/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2751 - val_loss: 0.3158
# Epoch 257/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2739 - val_loss: 0.3069
# Epoch 258/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2846 - val_loss: 0.3268
# Epoch 259/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2733 - val_loss: 0.3388
# Epoch 260/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2894 - val_loss: 0.3154
# Epoch 261/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2783 - val_loss: 0.3242
# Epoch 262/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2738 - val_loss: 0.3139
# Epoch 263/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2943 - val_loss: 0.3055
# Epoch 264/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2700 - val_loss: 0.3381
# Epoch 265/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2748 - val_loss: 0.3162
# Epoch 266/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2797 - val_loss: 0.3530
# Epoch 267/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2736 - val_loss: 0.3101
# Epoch 268/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2902 - val_loss: 0.3087
# Epoch 269/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2707 - val_loss: 0.3405
# Epoch 270/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2770 - val_loss: 0.3260
# Epoch 271/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2789 - val_loss: 0.3070
# Epoch 272/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2714 - val_loss: 0.2983
# Epoch 273/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2710 - val_loss: 0.3664
# Epoch 274/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2669 - val_loss: 0.3078
# Epoch 275/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2702 - val_loss: 0.3491
# Epoch 276/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2946 - val_loss: 0.3235
# Epoch 277/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2658 - val_loss: 0.3031
# Epoch 278/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2686 - val_loss: 0.3288
# Epoch 279/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2734 - val_loss: 0.3156
# Epoch 280/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2780 - val_loss: 0.3080
# Epoch 281/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2739 - val_loss: 0.3457
# Epoch 282/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2948 - val_loss: 0.3332
# Epoch 283/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2743 - val_loss: 0.3160
# Epoch 284/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2754 - val_loss: 0.3142
# Epoch 285/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2675 - val_loss: 0.3399
# Epoch 286/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2881 - val_loss: 0.3374
# Epoch 287/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2823 - val_loss: 0.3179
# Epoch 288/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2744 - val_loss: 0.3014
# Epoch 289/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2711 - val_loss: 0.2977
# Epoch 290/500
# 2791/2791 [==============================] - 4s 1ms/step - loss: 0.2737 - val_loss: 0.3176
# Epoch 291/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2599 - val_loss: 0.3136
# Epoch 292/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2638 - val_loss: 0.3116
# Epoch 293/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2738 - val_loss: 0.3380
# Epoch 294/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2706 - val_loss: 0.3610
# Epoch 295/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2648 - val_loss: 0.3118
# Epoch 296/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2703 - val_loss: 0.3155
# Epoch 297/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2717 - val_loss: 0.3061
# Epoch 298/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2754 - val_loss: 0.3384
# Epoch 299/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2722 - val_loss: 0.2963
# Epoch 300/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2679 - val_loss: 0.3105
# Epoch 301/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2645 - val_loss: 0.3093
# Epoch 302/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2710 - val_loss: 0.3030
# Epoch 303/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2739 - val_loss: 0.3284
# Epoch 304/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2833 - val_loss: 0.3040
# Epoch 305/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2746 - val_loss: 0.3351
# Epoch 306/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2769 - val_loss: 0.3374
# Epoch 307/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2752 - val_loss: 0.3102
# Epoch 308/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2770 - val_loss: 0.3222
# Epoch 309/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2829 - val_loss: 0.3119
# Epoch 310/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2755 - val_loss: 0.3046
# Epoch 311/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2699 - val_loss: 0.3169
# Epoch 312/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2750 - val_loss: 0.3068
# Epoch 313/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2775 - val_loss: 0.3062
# Epoch 314/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2841 - val_loss: 0.3070
# Epoch 315/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2745 - val_loss: 0.3224
# Epoch 316/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2803 - val_loss: 0.3092
# Epoch 317/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2749 - val_loss: 0.4175
# Epoch 318/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2770 - val_loss: 0.3177
# Epoch 319/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2752 - val_loss: 0.3480
# Epoch 320/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2787 - val_loss: 0.3192
# Epoch 321/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2822 - val_loss: 0.3532
# Epoch 322/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2972 - val_loss: 0.3160
# Epoch 323/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2676 - val_loss: 0.3121
# Epoch 324/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2671 - val_loss: 0.3170
# Epoch 325/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2694 - val_loss: 0.3284
# Epoch 326/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2765 - val_loss: 0.3187
# Epoch 327/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2642 - val_loss: 0.3147
# Epoch 328/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2649 - val_loss: 0.3292
# Epoch 329/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2744 - val_loss: 0.3132
# Epoch 330/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2761 - val_loss: 0.3108
# Epoch 331/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2691 - val_loss: 0.3020
# Epoch 332/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2661 - val_loss: 0.3020
# Epoch 333/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2675 - val_loss: 0.3119
# Epoch 334/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2676 - val_loss: 0.3045
# Epoch 335/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2760 - val_loss: 0.3274
# Epoch 336/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2709 - val_loss: 0.3252
# Epoch 337/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2844 - val_loss: 0.3254
# Epoch 338/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2703 - val_loss: 0.3066
# Epoch 339/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2751 - val_loss: 0.3104
# Epoch 340/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2836 - val_loss: 0.3010
# Epoch 341/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2717 - val_loss: 0.3044
# Epoch 342/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2705 - val_loss: 0.3199
# Epoch 343/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2683 - val_loss: 0.4041
# Epoch 344/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2745 - val_loss: 0.2994
# Epoch 345/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2667 - val_loss: 0.2979
# Epoch 346/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2738 - val_loss: 0.3269
# Epoch 347/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2791 - val_loss: 0.2994
# Epoch 348/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2675 - val_loss: 0.3827
# Epoch 349/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2760 - val_loss: 0.3177
# Epoch 350/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2688 - val_loss: 0.3032
# Epoch 351/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2694 - val_loss: 0.3023
# Epoch 352/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2642 - val_loss: 0.2988
# Epoch 353/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2624 - val_loss: 0.2938
# Epoch 354/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2675 - val_loss: 0.3965
# Epoch 355/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2736 - val_loss: 0.3029
# Epoch 356/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2692 - val_loss: 0.3125
# Epoch 357/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2845 - val_loss: 0.2981
# Epoch 358/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2618 - val_loss: 0.3498
# Epoch 359/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2607 - val_loss: 0.3260
# Epoch 360/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2735 - val_loss: 0.3718
# Epoch 361/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2797 - val_loss: 0.3158
# Epoch 362/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2693 - val_loss: 0.2943
# Epoch 363/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2615 - val_loss: 0.3675
# Epoch 364/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2653 - val_loss: 0.3037
# Epoch 365/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2649 - val_loss: 0.3141
# Epoch 366/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2731 - val_loss: 0.2956
# Epoch 367/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2667 - val_loss: 0.3240
# Epoch 368/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2623 - val_loss: 0.3151
# Epoch 369/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2778 - val_loss: 0.3305
# Epoch 370/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2742 - val_loss: 0.3085
# Epoch 371/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2815 - val_loss: 0.3125
# Epoch 372/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2721 - val_loss: 0.3115
# Epoch 373/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2653 - val_loss: 0.3416
# Epoch 374/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2685 - val_loss: 0.3122
# Epoch 375/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2737 - val_loss: 0.3265
# Epoch 376/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2600 - val_loss: 0.2967
# Epoch 377/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2728 - val_loss: 0.2987
# Epoch 378/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2614 - val_loss: 0.3173
# Epoch 379/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2641 - val_loss: 0.3055
# Epoch 380/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2734 - val_loss: 0.2999
# Epoch 381/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2670 - val_loss: 0.3283
# Epoch 382/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2637 - val_loss: 0.3772
# Epoch 383/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2716 - val_loss: 0.3109
# Epoch 384/500
# 2791/2791 [==============================] - 4s 1ms/step - loss: 0.2646 - val_loss: 0.3088
# Epoch 385/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2599 - val_loss: 0.3124
# Epoch 386/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2907 - val_loss: 0.3032
# Epoch 387/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2737 - val_loss: 0.2967
# Epoch 388/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2631 - val_loss: 0.3086
# Epoch 389/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2617 - val_loss: 0.2948
# Epoch 390/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2591 - val_loss: 0.3442
# Epoch 391/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2626 - val_loss: 0.3073
# Epoch 392/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2726 - val_loss: 0.3013
# Epoch 393/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2629 - val_loss: 0.3391
# Epoch 394/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2709 - val_loss: 0.3129
# Epoch 395/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2686 - val_loss: 0.2981
# Epoch 396/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2653 - val_loss: 0.2963
# Epoch 397/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2680 - val_loss: 0.3045
# Epoch 398/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2629 - val_loss: 0.2956
# Epoch 399/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2625 - val_loss: 0.3430
# Epoch 400/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2651 - val_loss: 0.2929
# Epoch 401/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2649 - val_loss: 0.3080
# Epoch 402/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2739 - val_loss: 0.3293
# Epoch 403/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2705 - val_loss: 0.3291
# Epoch 404/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2684 - val_loss: 0.2964
# Epoch 405/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2687 - val_loss: 0.2960
# Epoch 406/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2684 - val_loss: 0.3201
# Epoch 407/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2690 - val_loss: 0.3174
# Epoch 408/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2617 - val_loss: 0.3002
# Epoch 409/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2768 - val_loss: 0.3207
# Epoch 410/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2839 - val_loss: 0.3132
# Epoch 411/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2604 - val_loss: 0.2935
# Epoch 412/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2571 - val_loss: 0.3025
# Epoch 413/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2579 - val_loss: 0.2930
# Epoch 414/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2700 - val_loss: 0.2928
# Epoch 415/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2609 - val_loss: 0.2931
# Epoch 416/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2590 - val_loss: 0.3033
# Epoch 417/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2704 - val_loss: 0.3549
# Epoch 418/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2878 - val_loss: 0.3100
# Epoch 419/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2624 - val_loss: 0.3025
# Epoch 420/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2629 - val_loss: 0.3040
# Epoch 421/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2641 - val_loss: 0.3126
# Epoch 422/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2694 - val_loss: 0.2980
# Epoch 423/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2615 - val_loss: 0.3357
# Epoch 424/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2642 - val_loss: 0.3062
# Epoch 425/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2662 - val_loss: 0.2910
# Epoch 426/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2519 - val_loss: 0.2998
# Epoch 427/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2607 - val_loss: 0.2940
# Epoch 428/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2595 - val_loss: 0.3398
# Epoch 429/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2840 - val_loss: 0.2985
# Epoch 430/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2559 - val_loss: 0.3217
# Epoch 431/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2674 - val_loss: 0.3140
# Epoch 432/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2716 - val_loss: 0.2920
# Epoch 433/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2595 - val_loss: 0.3061
# Epoch 434/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2696 - val_loss: 0.2998
# Epoch 435/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2606 - val_loss: 0.2895
# Epoch 436/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2561 - val_loss: 0.3025
# Epoch 437/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2571 - val_loss: 0.3121
# Epoch 438/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2768 - val_loss: 0.3171
# Epoch 439/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2644 - val_loss: 0.3471
# Epoch 440/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2613 - val_loss: 0.3075
# Epoch 441/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2557 - val_loss: 0.2905
# Epoch 442/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2609 - val_loss: 0.2961
# Epoch 443/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2563 - val_loss: 0.3041
# Epoch 444/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2645 - val_loss: 0.3299
# Epoch 445/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2737 - val_loss: 0.2959
# Epoch 446/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2639 - val_loss: 0.3831
# Epoch 447/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2684 - val_loss: 0.2979
# Epoch 448/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2626 - val_loss: 0.3011
# Epoch 449/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2668 - val_loss: 0.2960
# Epoch 450/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2644 - val_loss: 0.3044
# Epoch 451/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2542 - val_loss: 0.3042
# Epoch 452/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2580 - val_loss: 0.2958
# Epoch 453/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2660 - val_loss: 0.2984
# Epoch 454/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2689 - val_loss: 0.3777
# Epoch 455/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2860 - val_loss: 0.3166
# Epoch 456/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2880 - val_loss: 0.2944
# Epoch 457/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2723 - val_loss: 0.2915
# Epoch 458/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2562 - val_loss: 0.3246
# Epoch 459/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2592 - val_loss: 0.2879
# Epoch 460/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2530 - val_loss: 0.3239
# Epoch 461/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2672 - val_loss: 0.3064
# Epoch 462/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2555 - val_loss: 0.2928
# Epoch 463/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2649 - val_loss: 0.2970
# Epoch 464/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2622 - val_loss: 0.2924
# Epoch 465/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2584 - val_loss: 0.2943
# Epoch 466/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2646 - val_loss: 0.2914
# Epoch 467/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2564 - val_loss: 0.2992
# Epoch 468/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2580 - val_loss: 0.3464
# Epoch 469/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2600 - val_loss: 0.3550
# Epoch 470/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2637 - val_loss: 0.2957
# Epoch 471/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2540 - val_loss: 0.2894
# Epoch 472/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2660 - val_loss: 0.3029
# Epoch 473/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2628 - val_loss: 0.3275
# Epoch 474/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2644 - val_loss: 0.3781
# Epoch 475/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2683 - val_loss: 0.3143
# Epoch 476/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2643 - val_loss: 0.3433
# Epoch 477/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2613 - val_loss: 0.2943
# Epoch 478/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2618 - val_loss: 0.2912
# Epoch 479/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2576 - val_loss: 0.3050
# Epoch 480/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2695 - val_loss: 0.2948
# Epoch 481/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2721 - val_loss: 0.3153
# Epoch 482/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2573 - val_loss: 0.2949
# Epoch 483/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2605 - val_loss: 0.3024
# Epoch 484/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2646 - val_loss: 0.2930
# Epoch 485/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2594 - val_loss: 0.2925
# Epoch 486/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2591 - val_loss: 0.3175
# Epoch 487/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2618 - val_loss: 0.3022
# Epoch 488/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2616 - val_loss: 0.2936
# Epoch 489/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2678 - val_loss: 0.3232
# Epoch 490/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2546 - val_loss: 0.2943
# Epoch 491/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2657 - val_loss: 0.2949
# Epoch 492/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2790 - val_loss: 0.3526
# Epoch 493/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2647 - val_loss: 0.3022
# Epoch 494/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2548 - val_loss: 0.2893
# Epoch 495/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2523 - val_loss: 0.2863
# Epoch 496/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2568 - val_loss: 0.3092
# Epoch 497/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2568 - val_loss: 0.2869
# Epoch 498/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2575 - val_loss: 0.2957
# Epoch 499/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2561 - val_loss: 0.2968
# Epoch 500/500
# 2791/2791 [==============================] - 3s 1ms/step - loss: 0.2577 - val_loss: 0.3210

# %%
predicted_stock_price = pd.DataFrame(model.predict(Xtt))
indicedetiempo = pd.concat((index_time,index_time_t), axis = 0)
yt = pd.DataFrame(yt) ; ytt = pd.DataFrame(ytt)
stock_real_value = pd.concat((yt,ytt),axis = 0)
rmse = sqrt(mean_squared_error(ytt, predicted_stock_price))

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15, 5))
fig.suptitle(tickers[index],fontsize = 20)
# Plot de todo el grafico
ax1.plot(indicedetiempo,stock_real_value)
ax1.plot(index_time_t,predicted_stock_price, color = "black")

# Plot de solo la parte que hemos hecho el predict
ax2.plot(index_time_t,ytt)
ax2.plot(index_time_t,predicted_stock_price, color = "black")
ax2.annotate('RMSE = %.2f'% rmse, (index_time_t[40], ytt.iloc[40]), xytext=(-25, -150), 
            textcoords='offset points',fontsize = 15)

plt.show()
print("RMSE de resubstitucion","%.2f" % rmse)
# Out:
# RMSE de resubstitucion 5.27

# %%
rmse_verdadero = mean_squared_error(ytt, predicted_stock_price)
print(rmse_verdadero)
# Out:
# 27.804605422698966
