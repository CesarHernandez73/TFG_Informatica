# %% [markdown]
# ### TFG - Cesar Hernandez Rodriguez
# Segundos pasos en las redes neuronales y la bolsa, para este caso buscamos predecir valores y no tendencias
#
# Este script se basa en descargar datos de la bolsa de EEUU, exactamente todos los del índice nasdaq que es uno de los índices más importantes de Estados Unidos, siendo la segunda bolsa de valores automatizada y electronica mas grande del mundo con 3800 compañias. (https://es.wikipedia.org/wiki/NASDAQ)
#
# Para ello usaré la librería QUANDL (https://www.quandl.com/tools/python) que implementa una API para poder descargar los datos de manera sencilla.
#
# El primer paso será mediante WEB-Scrapping descargar de Wikipedia los tickets de los 500 valores del índice bursatil, después ire recursivamente descargando todos los datos disponibles de los 500 valores desde el 2000 hasta el final del año 2017, estos datos los usare para entrenar la red neuronal y poder predecir el primer trimestre de 2018. La selección de estas fechas se debe al a disponibilidad que ofrece la librería Quandl ya que al usarla de forma gratuita no se puede descargar los históricos de todos los datos ni todo los datos más actuales, de todas formas aún asi vamos a tener problemas ya que solo he conseguido de 485 de 500 activos y de algunos no tenemos unos datos históricos tan extensos como lo que buscabamos.
#
# A mayores una vez descagardo los datos (ya que tarda mucho) los voy a guardar dentro de mi ordenador serializandolo con el paquete Pickle (http://pyspanishdoc.sourceforge.net/lib/module-pickle.html)

# %%
# Import predefinifods
import pandas as pd
import numpy as np
import random
from math import *
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from time import time
import matplotlib.pyplot as plt
from collections import Counter

# Importa descaga de datos
import quandl

# Import serializar
import pickle

# Import red Neuronal
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
import keras.backend as K

# Conteo
from collections import Counter
# Out:
# Using TensorFlow backend.

# %%
#Tengo dos bases de datos con todos los tickers del indice nasdaq y todos los tickers
# que tiene mi base de datos y extraigo solo los que tengo
def get_tickers_sample_nasdaq():
    tickers_wiki_quandl = pd.read_csv('WIKI_PRICES.csv')['ticker']
    tickers_nasdaq = pd.read_csv('nasdaq-listed-symbols.csv')['Symbol']
    
    tickersQuandl = []    
    tickers = []
    for i in range(len(tickers_nasdaq)):
        word = tickers_nasdaq[i]
        for j in range(len(tickers_wiki_quandl)):
            if word == tickers_wiki_quandl[j]:
                tickers.append(word)
    
    tickers = random.choices(tickers, k=15)
    
    for tick in tickers:
        tickersQuandl.append("WIKI/"+tick)
    
    return tickers, tickersQuandl

# a,b = get_tickers_sample_nasdaq()

# %%
# Descargo los datos de la API Quandl, para ello uso el conjunto de datos que me ofrece WIKI/ que se puede ver
# en la página de la libreria y me registro en la pagina de forma gratuita dandome una key.
# me devuelve una lista con todos los datos posibles de ese activo, yo guardo todos y por separado los de cierre
# Aunque solo me interese los de cierre quiero guardar todos los datos por si en una extension de este trabajo se queire 
# usar cualquier otro dato
# Para no tener que realizar la parte de descarga cada vez que se inicia el programa se ha habilitado la descarga
# y guardado de datos en una carpeta datos que ya debe crearse antes. Los datos se guardan serializados.

def get_data(verbose):
    quandl.ApiConfig.api_key = 'WgQVD8Npfox1MN7SV3Nm'
    tickers, tickersQuandl = get_tickers_sample_nasdaq()
    
    if verbose: print(" ****Empezamos a descargar los datos****\n")
    
    datos = {}
    start_time = time()
    long = len(tickersQuandl)
    i = 0
    # Las fechas elegidas son esas para poder tener una gran cantidad de datos historicos y
    # que justo se complementen con las fechas de tipo test, al hacer Medias Moviles se pierden muchos datos
    for ticker in tickersQuandl:
        if i % 2 == 0 and verbose: print("LLeva descargados el ",i/long *100,"% de los datos")
        #aux=quandl.get(ticker,start_date="2000-01-01",end_date="2016-12-31")
        aux=quandl.get(ticker,start_date="2010-01-01",end_date="2016-12-31")
        datos[ticker[5:len(ticker)]] = aux
        i = i + 1
    
    datosClose = {}
    for key in datos:
        datosClose[key] = datos[key]["Adj. Close"]
    
    elapsed_time = time() - start_time
    if verbose: print("\nHa tardado en descargar los datos: %0.10f segundos." % elapsed_time)
    
    if verbose: print("\n ****Empezamos a descargar los datos test****\n")
    
    # Procedo a hacer las mismas operaciones para el conjunto TEST
    datos_test = {}
    i = 0
    long = len(tickersQuandl)
    start_time = time()    
    for ticker in tickersQuandl:
        if i % 2 == 0 and verbose: print("LLeva descargados el ",i/long *100,"% de los datos test")
        aux=quandl.get(ticker,start_date="2016-11-01",end_date="2020-12-31")
        datos_test[ticker[5:len(ticker)]] = aux
        i = i + 1
    
    datosClose_test = {}
    for key in datos_test:
        datosClose_test[key] = datos_test[key]["Adj. Close"]
    
        elapsed_time = time() - start_time
    if verbose: print("\nHa tardado en descargar los datos test: %0.10f segundos." % elapsed_time)
    if verbose: print("\n")
    
    # Solo cogemos los datos que nos da la aplicacion
    # ya que hay activos que no tenemos su valor en esas fechas o tenemos muy pocos datos

    quitar = []
    for key in tickers:
        if datosClose_test[key].empty:
            if verbose == True : print("Restriccion de vacio",key) 
            datos.pop(key,None)
            datosClose.pop(key,None)
            datos_test.pop(key,None)
            datosClose_test.pop(key,None)
            quitar.append(key)
        elif len(datosClose_test[key]) < 300:
            if verbose == True :  print("Restriccion de longitud",key)
            datos.pop(key,None)
            datosClose.pop(key,None)
            datos_test.pop(key,None)
            datosClose_test.pop(key,None)
            quitar.append(key)
            
    for key in quitar:
        tickers.remove(key)
    
    # Guardamos los datos y serializamos
    pickle.dump(tickers, open("datos/tickers_nasdaq.p", "wb"))
    pickle.dump(tickersQuandl, open("datos/tickersQuandl_nasdaq.p", "wb"))
    pickle.dump(datos, open("datos/nasdaq.p", "wb"))
    pickle.dump(datosClose, open("datos/nasdaqClose.p", "wb"))
    pickle.dump(datos_test, open("datos/nasdaq_test.p", "wb"))
    pickle.dump(datosClose_test, open("datos/nasdaqClose_test.p", "wb"))
    
    return tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test

# %%
# Si los datos ya han sido descargados con esta funcion los cargo gracias a la libreria pickles
def get_data_load(verbose):
    if verbose: print(" ****Empezamos a cargar los datos****\n")
    tickers = pickle.load(open("datos/tickers_nasdaq.p", "rb" ))
    tickersQuandl = pickle.load(open("datos/tickersQuandl_nasdaq.p", "rb" ))
    datos = pickle.load(open("datos/nasdaq.p", "rb" ))
    datosClose = pickle.load(open("datos/nasdaqClose.p", "rb" ))
    if verbose: print(" ****Cargados los datos****\n")
    
    if verbose: print("\n ****Empezamos a cargar los datos test****\n")
    datos_test = pickle.load(open("datos/nasdaq_test.p", "rb" ))
    datosClose_test = pickle.load(open("datos/nasdaqClose_test.p", "rb" ))
    if verbose: print(" ****Cargados los datos test****\n")
    
    return tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test

# Para imprimir cualquier conjunto tipo Serie temporal del conjunto de datos base uso esta funcion
def plot_datos(datosClose,nombre,test):
    datosClose[nombre].plot(figsize=(12,5),grid=True)
    plt.title('{} {}\n'.format(nombre,test))
    plt.ylabel('Precio de Cierre')
    plt.xlabel('Fecha')
    plt.show()

# %%
datos_descargados = False
if datos_descargados:
    tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test= get_data_load(True)
else : 
    tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test = get_data(True)
# Out:
#  ****Empezamos a descargar los datos****
#
# LLeva descargados el  0.0 % de los datos
# LLeva descargados el  13.333333333333334 % de los datos
# LLeva descargados el  26.666666666666668 % de los datos
# LLeva descargados el  40.0 % de los datos
# LLeva descargados el  53.333333333333336 % de los datos
# LLeva descargados el  66.66666666666666 % de los datos
# LLeva descargados el  80.0 % de los datos
# LLeva descargados el  93.33333333333333 % de los datos
#
# Ha tardado en descargar los datos: 24.0758750439 segundos.
#
#  ****Empezamos a descargar los datos test****
#
# LLeva descargados el  0.0 % de los datos test
# LLeva descargados el  13.333333333333334 % de los datos test
# LLeva descargados el  26.666666666666668 % de los datos test
# LLeva descargados el  40.0 % de los datos test
# LLeva descargados el  53.333333333333336 % de los datos test
# LLeva descargados el  66.66666666666666 % de los datos test
# LLeva descargados el  80.0 % de los datos test
# LLeva descargados el  93.33333333333333 % de los datos test
#
# Ha tardado en descargar los datos test: 12.1692366600 segundos.
#
#
# Restriccion de longitud AMSG
# Restriccion de vacio RENT
# Restriccion de vacio CMCSK

# %%
# Grafico un activo aleatorio que luego predecire
# Se tiene el gráfico con el que se creara el modelo y los datos sobre los que se va a testear
ran = random.randint(0,len(tickers)-1)
plot_datos(datosClose,tickers[ran],"train")
plot_datos(datosClose_test,tickers[ran],"test")

# %%
# Para crear los atributos que voy a meter en la red Neuronal uso esta funcion, mis atributos son
# Dos medias moviles, una de 30 dias y otra de 15 para hacer la simulacion con los datos de un mes y la mitad de mes
# por ulitmo creo un oscilador de la media movil de 30 dias donde resto los valores son separacion de 30 dias
def differences(x):
    return x[-1] - x[0]

def create_features(datosClose,days1,days2):
    X = pd.DataFrame()
    data = pd.DataFrame()
    data['Adj. Close'] = datosClose.values
    
    indices = datosClose.index
    
    X['MA_{}'.format(days1)] = data['Adj. Close'].rolling(window=days1).mean()
    X['MA_{}'.format(days2)] = data['Adj. Close'].rolling(window=days2).mean()
    X['Diferencia'] = data['Adj. Close'].rolling(window=days2).apply(differences,raw=True) 
    X = X[days2:len(X)-1].reset_index()
    X.drop(['index'], axis='columns', inplace=True)

    return X, indices[(days2+1):len(indices)]

# Creo tambien timestep de 30 dias (igual que la media movil) para la RED NEURONAL
def cut_timestep(x,y,time):
    
    Xt = []
    yt = []
    index_time = []

    for i in range(timeStep, len(x)):
        Xt.append(x[i-timeStep:i,:])
        yt.append(y.iloc[i,0])
        index_time.append(time[i])

    return np.array(Xt), np.array(yt), pd.Series(index_time)

# %%
# A parte de la creacion de atributos
index = ran
timeStep = 20 # longitud de secuencias que se hacen en cada iteracion de la red

# Extraigo los atributos de los datos y los preparo para meterlos a la red neuronal

X, ind_time = create_features(datosClose[tickers[index]],10,20)
Y = pd.DataFrame(datosClose[tickers[index]].values[21:len(datosClose[tickers[index]])])
X = X.to_numpy()

# Creamos los atributos para los datos test
ticket_uso = tickers[index]
Xtesteo, ind_time_t = create_features(datosClose_test[tickers[index]],10,20)
Ytesteo = pd.DataFrame(datosClose_test[tickers[index]].values[21:len(datosClose_test[tickers[index]])])
Xtesteo = Xtesteo.to_numpy()

X_aux = np.concatenate((X,Xtesteo),axis=0)

scaler = MinMaxScaler()
X_aux_scaled = scaler.fit_transform(X_aux)
X_scaled = X_aux_scaled[0:len(X)]
Xtesteo_scaled = X_aux_scaled[len(X):len(X_aux_scaled)]

# Creacion de los timestep
Xt, yt, index_time = cut_timestep(X_scaled,Y,ind_time)
Xtt, ytt, index_time_t = cut_timestep(Xtesteo_scaled,Ytesteo,ind_time_t)

# Split de en conjunto de prueba y entrenamiento para la red neuronal
P=yt.shape[0]
indices=np.arange(P,dtype=int)
np.random.shuffle(indices)
sequences_train=indices[0:int(P*2/3)]
sequences_test=indices[int(P*2/3):]
X_train, X_test, y_train, y_test = Xt[sequences_train],Xt[sequences_test],yt[sequences_train],yt[sequences_test]


print("Voy a predecir el activo ",ticket_uso)
# Out:
# Voy a predecir el activo  ARWR

# %%
# Calculates a successfull ratio using less relative error than a maximum
def porcentaje_margen(y_true, y_pred):
    margen = 0.05
    yy = K.sum(K.cast(K.less(K.abs((y_pred/y_true)-1.0), margen), dtype=float))
    return yy/K.cast(K.shape(y_pred)[0], dtype=float)

# %%
# Creacion de la red neural LSTM

model = Sequential()
model.add(LSTM(4, input_shape=(20,3),return_sequences=True))
model.add(LSTM(units = 2,return_sequences = False))
model.add(Dense(1)) 
model.compile(optimizer="adam",loss='mse',metrics=[porcentaje_margen]) 
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 20, 4)             128
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 2)                 56
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 187
# Trainable params: 187
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_LSTM = model.fit(X_train,
                  y_train,
                  epochs=1500,
                  verbose=1,
                  validation_data=(X_test,y_test))
# Out:
# Train on 1147 samples, validate on 574 samples
# Epoch 1/1500
# 1147/1147 [==============================] - 2s 2ms/step - loss: 65.1047 - porcentaje_margen: 0.0000e+00 - val_loss: 59.7195 - val_porcentaje_margen: 0.0000e+00
# Epoch 2/1500
# 1147/1147 [==============================] - 1s 966us/step - loss: 60.7236 - porcentaje_margen: 0.0000e+00 - val_loss: 55.2657 - val_porcentaje_margen: 0.0000e+00
# Epoch 3/1500
# 1147/1147 [==============================] - 1s 929us/step - loss: 54.6111 - porcentaje_margen: 0.0000e+00 - val_loss: 47.4573 - val_porcentaje_margen: 0.0000e+00
# Epoch 4/1500
# 1147/1147 [==============================] - 1s 893us/step - loss: 47.3504 - porcentaje_margen: 0.0017 - val_loss: 42.1257 - val_porcentaje_margen: 0.0035
# Epoch 5/1500
# 1147/1147 [==============================] - 1s 927us/step - loss: 43.5854 - porcentaje_margen: 0.0062 - val_loss: 39.3492 - val_porcentaje_margen: 0.0156
# Epoch 6/1500
# 1147/1147 [==============================] - 1s 951us/step - loss: 41.1579 - porcentaje_margen: 0.0269 - val_loss: 37.2438 - val_porcentaje_margen: 0.0594
# Epoch 7/1500
# 1147/1147 [==============================] - 1s 898us/step - loss: 39.2530 - porcentaje_margen: 0.0557 - val_loss: 35.5554 - val_porcentaje_margen: 0.0262
# Epoch 8/1500
# 1147/1147 [==============================] - 1s 885us/step - loss: 37.6897 - porcentaje_margen: 0.0330 - val_loss: 34.1379 - val_porcentaje_margen: 0.0035
# Epoch 9/1500
# 1147/1147 [==============================] - 1s 892us/step - loss: 36.3576 - porcentaje_margen: 0.0158 - val_loss: 32.8872 - val_porcentaje_margen: 0.0191
# Epoch 10/1500
# 1147/1147 [==============================] - 1s 904us/step - loss: 35.1784 - porcentaje_margen: 0.0316 - val_loss: 31.7675 - val_porcentaje_margen: 0.0191
# Epoch 11/1500
# 1147/1147 [==============================] - 1s 875us/step - loss: 34.1079 - porcentaje_margen: 0.0252 - val_loss: 30.7590 - val_porcentaje_margen: 0.0069
# Epoch 12/1500
# 1147/1147 [==============================] - 1s 868us/step - loss: 33.1226 - porcentaje_margen: 0.0078 - val_loss: 29.8332 - val_porcentaje_margen: 0.0000e+00
# Epoch 13/1500
# 1147/1147 [==============================] - 1s 890us/step - loss: 32.2135 - porcentaje_margen: 0.0035 - val_loss: 28.9642 - val_porcentaje_margen: 0.0035
# Epoch 14/1500
# 1147/1147 [==============================] - 1s 861us/step - loss: 31.3605 - porcentaje_margen: 0.0078 - val_loss: 28.1471 - val_porcentaje_margen: 0.0104
# Epoch 15/1500
# 1147/1147 [==============================] - 1s 932us/step - loss: 30.5625 - porcentaje_margen: 0.0140 - val_loss: 27.3675 - val_porcentaje_margen: 0.0104
# Epoch 16/1500
# 1147/1147 [==============================] - 1s 881us/step - loss: 29.8026 - porcentaje_margen: 0.0182 - val_loss: 26.6494 - val_porcentaje_margen: 0.0122
# Epoch 17/1500
# 1147/1147 [==============================] - 1s 893us/step - loss: 29.0907 - porcentaje_margen: 0.0174 - val_loss: 25.9612 - val_porcentaje_margen: 0.0191
# Epoch 18/1500
# 1147/1147 [==============================] - 1s 926us/step - loss: 28.4192 - porcentaje_margen: 0.0217 - val_loss: 25.2982 - val_porcentaje_margen: 0.0278
# Epoch 19/1500
# 1147/1147 [==============================] - 1s 901us/step - loss: 27.7757 - porcentaje_margen: 0.0234 - val_loss: 24.6846 - val_porcentaje_margen: 0.0295
# Epoch 20/1500
# 1147/1147 [==============================] - 1s 897us/step - loss: 27.1678 - porcentaje_margen: 0.0295 - val_loss: 24.1018 - val_porcentaje_margen: 0.0296
# Epoch 21/1500
# 1147/1147 [==============================] - 1s 914us/step - loss: 26.5928 - porcentaje_margen: 0.0297 - val_loss: 23.5425 - val_porcentaje_margen: 0.0262
# Epoch 22/1500
# 1147/1147 [==============================] - 1s 890us/step - loss: 26.0414 - porcentaje_margen: 0.0243 - val_loss: 23.0155 - val_porcentaje_margen: 0.0228
# Epoch 23/1500
# 1147/1147 [==============================] - 1s 904us/step - loss: 25.5193 - porcentaje_margen: 0.0304 - val_loss: 22.5147 - val_porcentaje_margen: 0.0420
# Epoch 24/1500
# 1147/1147 [==============================] - 1s 925us/step - loss: 25.0271 - porcentaje_margen: 0.0321 - val_loss: 22.0259 - val_porcentaje_margen: 0.0420
# Epoch 25/1500
# 1147/1147 [==============================] - 1s 846us/step - loss: 24.5477 - porcentaje_margen: 0.0382 - val_loss: 21.5850 - val_porcentaje_margen: 0.0454
# Epoch 26/1500
# 1147/1147 [==============================] - 1s 905us/step - loss: 24.1032 - porcentaje_margen: 0.0420 - val_loss: 21.1462 - val_porcentaje_margen: 0.0542
# Epoch 27/1500
# 1147/1147 [==============================] - 1s 912us/step - loss: 23.6734 - porcentaje_margen: 0.0429 - val_loss: 20.7339 - val_porcentaje_margen: 0.0541
# Epoch 28/1500
# 1147/1147 [==============================] - 1s 887us/step - loss: 23.2682 - porcentaje_margen: 0.0437 - val_loss: 20.3394 - val_porcentaje_margen: 0.0419
# Epoch 29/1500
# 1147/1147 [==============================] - 1s 836us/step - loss: 22.8808 - porcentaje_margen: 0.0411 - val_loss: 19.9675 - val_porcentaje_margen: 0.0506
# Epoch 30/1500
# 1147/1147 [==============================] - 1s 869us/step - loss: 22.5129 - porcentaje_margen: 0.0411 - val_loss: 19.6209 - val_porcentaje_margen: 0.0454
# Epoch 31/1500
# 1147/1147 [==============================] - 1s 878us/step - loss: 22.1650 - porcentaje_margen: 0.0375 - val_loss: 19.2894 - val_porcentaje_margen: 0.0488
# Epoch 32/1500
# 1147/1147 [==============================] - 1s 891us/step - loss: 21.8353 - porcentaje_margen: 0.0444 - val_loss: 18.9656 - val_porcentaje_margen: 0.0435
# Epoch 33/1500
# 1147/1147 [==============================] - 1s 892us/step - loss: 21.5211 - porcentaje_margen: 0.0453 - val_loss: 18.6622 - val_porcentaje_margen: 0.0557
# Epoch 34/1500
# 1147/1147 [==============================] - 1s 882us/step - loss: 21.2231 - porcentaje_margen: 0.0477 - val_loss: 18.3770 - val_porcentaje_margen: 0.0644
# Epoch 35/1500
# 1147/1147 [==============================] - 1s 841us/step - loss: 20.9403 - porcentaje_margen: 0.0517 - val_loss: 18.1099 - val_porcentaje_margen: 0.0784
# Epoch 36/1500
# 1147/1147 [==============================] - 1s 872us/step - loss: 20.6767 - porcentaje_margen: 0.0646 - val_loss: 17.8494 - val_porcentaje_margen: 0.0836
# Epoch 37/1500
# 1147/1147 [==============================] - 1s 852us/step - loss: 20.4208 - porcentaje_margen: 0.0706 - val_loss: 17.6161 - val_porcentaje_margen: 0.0924
# Epoch 38/1500
# 1147/1147 [==============================] - 1s 900us/step - loss: 20.1843 - porcentaje_margen: 0.0824 - val_loss: 17.3883 - val_porcentaje_margen: 0.1045
# Epoch 39/1500
# 1147/1147 [==============================] - 1s 885us/step - loss: 19.9565 - porcentaje_margen: 0.0894 - val_loss: 17.1791 - val_porcentaje_margen: 0.0993
# Epoch 40/1500
# 1147/1147 [==============================] - 1s 875us/step - loss: 19.7458 - porcentaje_margen: 0.0965 - val_loss: 16.9726 - val_porcentaje_margen: 0.1028
# Epoch 41/1500
# 1147/1147 [==============================] - 1s 865us/step - loss: 19.5453 - porcentaje_margen: 0.1074 - val_loss: 16.7766 - val_porcentaje_margen: 0.1132
# Epoch 42/1500
# 1147/1147 [==============================] - 1s 833us/step - loss: 19.3559 - porcentaje_margen: 0.1080 - val_loss: 16.5978 - val_porcentaje_margen: 0.1045
# Epoch 43/1500
# 1147/1147 [==============================] - 1s 919us/step - loss: 19.1781 - porcentaje_margen: 0.1073 - val_loss: 16.4302 - val_porcentaje_margen: 0.1028
# Epoch 44/1500
# 1147/1147 [==============================] - 1s 831us/step - loss: 19.0113 - porcentaje_margen: 0.1088 - val_loss: 16.2717 - val_porcentaje_margen: 0.1027
# Epoch 45/1500
# 1147/1147 [==============================] - 1s 862us/step - loss: 18.8544 - porcentaje_margen: 0.1151 - val_loss: 16.1231 - val_porcentaje_margen: 0.1027
# Epoch 46/1500
# 1147/1147 [==============================] - 1s 854us/step - loss: 18.7082 - porcentaje_margen: 0.1222 - val_loss: 15.9827 - val_porcentaje_margen: 0.0973
# Epoch 47/1500
# 1147/1147 [==============================] - 1s 841us/step - loss: 18.5697 - porcentaje_margen: 0.1277 - val_loss: 15.8567 - val_porcentaje_margen: 0.0921
# Epoch 48/1500
# 1147/1147 [==============================] - 1s 882us/step - loss: 18.4419 - porcentaje_margen: 0.1220 - val_loss: 15.7343 - val_porcentaje_margen: 0.0939
# Epoch 49/1500
# 1147/1147 [==============================] - 1s 810us/step - loss: 18.3213 - porcentaje_margen: 0.1227 - val_loss: 15.6224 - val_porcentaje_margen: 0.0973
# Epoch 50/1500
# 1147/1147 [==============================] - 1s 826us/step - loss: 18.2074 - porcentaje_margen: 0.1227 - val_loss: 15.5221 - val_porcentaje_margen: 0.1008
# Epoch 51/1500
# 1147/1147 [==============================] - 1s 832us/step - loss: 18.1038 - porcentaje_margen: 0.1256 - val_loss: 15.4217 - val_porcentaje_margen: 0.1043
# Epoch 52/1500
# 1147/1147 [==============================] - 1s 836us/step - loss: 18.0050 - porcentaje_margen: 0.1272 - val_loss: 15.3295 - val_porcentaje_margen: 0.1061
# Epoch 53/1500
# 1147/1147 [==============================] - 1s 806us/step - loss: 17.9141 - porcentaje_margen: 0.1287 - val_loss: 15.2426 - val_porcentaje_margen: 0.1115
# Epoch 54/1500
# 1147/1147 [==============================] - 1s 807us/step - loss: 17.8306 - porcentaje_margen: 0.1303 - val_loss: 15.1611 - val_porcentaje_margen: 0.1097
# Epoch 55/1500
# 1147/1147 [==============================] - 1s 873us/step - loss: 17.7506 - porcentaje_margen: 0.1307 - val_loss: 15.0897 - val_porcentaje_margen: 0.1149
# Epoch 56/1500
# 1147/1147 [==============================] - 1s 814us/step - loss: 17.6770 - porcentaje_margen: 0.1253 - val_loss: 15.0263 - val_porcentaje_margen: 0.1079
# Epoch 57/1500
# 1147/1147 [==============================] - 1s 840us/step - loss: 17.6107 - porcentaje_margen: 0.1229 - val_loss: 14.9631 - val_porcentaje_margen: 0.1027
# Epoch 58/1500
# 1147/1147 [==============================] - 1s 818us/step - loss: 17.5477 - porcentaje_margen: 0.1151 - val_loss: 14.9088 - val_porcentaje_margen: 0.1061
# Epoch 59/1500
# 1147/1147 [==============================] - 1s 845us/step - loss: 17.4914 - porcentaje_margen: 0.1107 - val_loss: 14.8541 - val_porcentaje_margen: 0.1061
# Epoch 60/1500
# 1147/1147 [==============================] - 1s 862us/step - loss: 17.4388 - porcentaje_margen: 0.1062 - val_loss: 14.8029 - val_porcentaje_margen: 0.1061
# Epoch 61/1500
# 1147/1147 [==============================] - 1s 787us/step - loss: 17.3894 - porcentaje_margen: 0.1026 - val_loss: 14.7597 - val_porcentaje_margen: 0.1061
# Epoch 62/1500
# 1147/1147 [==============================] - 1s 815us/step - loss: 17.3451 - porcentaje_margen: 0.1019 - val_loss: 14.7199 - val_porcentaje_margen: 0.1044
# Epoch 63/1500
# 1147/1147 [==============================] - 1s 805us/step - loss: 17.3052 - porcentaje_margen: 0.1031 - val_loss: 14.6824 - val_porcentaje_margen: 0.0975
# Epoch 64/1500
# 1147/1147 [==============================] - 1s 805us/step - loss: 17.2676 - porcentaje_margen: 0.0983 - val_loss: 14.6510 - val_porcentaje_margen: 0.0922
# Epoch 65/1500
# 1147/1147 [==============================] - 1s 919us/step - loss: 17.2339 - porcentaje_margen: 0.0984 - val_loss: 14.6184 - val_porcentaje_margen: 0.1009
# Epoch 66/1500
# 1147/1147 [==============================] - 1s 826us/step - loss: 17.2033 - porcentaje_margen: 0.0948 - val_loss: 14.5889 - val_porcentaje_margen: 0.0957
# Epoch 67/1500
# 1147/1147 [==============================] - 1s 803us/step - loss: 17.1734 - porcentaje_margen: 0.0951 - val_loss: 14.5659 - val_porcentaje_margen: 0.0957
# Epoch 68/1500
# 1147/1147 [==============================] - 1s 774us/step - loss: 17.1485 - porcentaje_margen: 0.0953 - val_loss: 14.5428 - val_porcentaje_margen: 0.0940
# Epoch 69/1500
# 1147/1147 [==============================] - 1s 819us/step - loss: 17.1250 - porcentaje_margen: 0.0906 - val_loss: 14.5250 - val_porcentaje_margen: 0.0922
# Epoch 70/1500
# 1147/1147 [==============================] - 1s 852us/step - loss: 17.1057 - porcentaje_margen: 0.0885 - val_loss: 14.5039 - val_porcentaje_margen: 0.0834
# Epoch 71/1500
# 1147/1147 [==============================] - 1s 846us/step - loss: 17.0850 - porcentaje_margen: 0.0837 - val_loss: 14.4895 - val_porcentaje_margen: 0.0834
# Epoch 72/1500
# 1147/1147 [==============================] - 1s 826us/step - loss: 17.0687 - porcentaje_margen: 0.0844 - val_loss: 14.4758 - val_porcentaje_margen: 0.0869
# Epoch 73/1500
# 1147/1147 [==============================] - 1s 814us/step - loss: 17.0532 - porcentaje_margen: 0.0861 - val_loss: 14.4611 - val_porcentaje_margen: 0.0938
# Epoch 74/1500
# 1147/1147 [==============================] - 1s 820us/step - loss: 17.0399 - porcentaje_margen: 0.0873 - val_loss: 14.4468 - val_porcentaje_margen: 0.0955
# Epoch 75/1500
# 1147/1147 [==============================] - 1s 807us/step - loss: 17.0262 - porcentaje_margen: 0.0906 - val_loss: 14.4386 - val_porcentaje_margen: 0.1042
# Epoch 76/1500
# 1147/1147 [==============================] - 1s 845us/step - loss: 17.0157 - porcentaje_margen: 0.0864 - val_loss: 14.4285 - val_porcentaje_margen: 0.1007
# Epoch 77/1500
# 1147/1147 [==============================] - 1s 842us/step - loss: 17.0056 - porcentaje_margen: 0.0852 - val_loss: 14.4198 - val_porcentaje_margen: 0.1043
# Epoch 78/1500
# 1147/1147 [==============================] - 1s 809us/step - loss: 16.9969 - porcentaje_margen: 0.0833 - val_loss: 14.4118 - val_porcentaje_margen: 0.0991
# Epoch 79/1500
# 1147/1147 [==============================] - 1s 820us/step - loss: 16.9885 - porcentaje_margen: 0.0848 - val_loss: 14.4069 - val_porcentaje_margen: 0.1025
# Epoch 80/1500
# 1147/1147 [==============================] - 1s 792us/step - loss: 16.9819 - porcentaje_margen: 0.0863 - val_loss: 14.4009 - val_porcentaje_margen: 0.1112
# Epoch 81/1500
# 1147/1147 [==============================] - 1s 840us/step - loss: 16.9757 - porcentaje_margen: 0.0864 - val_loss: 14.3964 - val_porcentaje_margen: 0.1112
# Epoch 82/1500
# 1147/1147 [==============================] - 1s 813us/step - loss: 16.9708 - porcentaje_margen: 0.0837 - val_loss: 14.3911 - val_porcentaje_margen: 0.1147
# Epoch 83/1500
# 1147/1147 [==============================] - 1s 818us/step - loss: 16.9656 - porcentaje_margen: 0.0857 - val_loss: 14.3875 - val_porcentaje_margen: 0.1130
# Epoch 84/1500
# 1147/1147 [==============================] - 1s 808us/step - loss: 16.9608 - porcentaje_margen: 0.0863 - val_loss: 14.3850 - val_porcentaje_margen: 0.1130
# Epoch 85/1500
# 1147/1147 [==============================] - 1s 781us/step - loss: 16.9571 - porcentaje_margen: 0.0861 - val_loss: 14.3814 - val_porcentaje_margen: 0.1095
# Epoch 86/1500
# 1147/1147 [==============================] - 1s 824us/step - loss: 16.9538 - porcentaje_margen: 0.0899 - val_loss: 14.3798 - val_porcentaje_margen: 0.1095
# Epoch 87/1500
# 1147/1147 [==============================] - 1s 853us/step - loss: 16.9520 - porcentaje_margen: 0.0906 - val_loss: 14.3764 - val_porcentaje_margen: 0.1130
# Epoch 88/1500
# 1147/1147 [==============================] - 1s 812us/step - loss: 16.9473 - porcentaje_margen: 0.0922 - val_loss: 14.3750 - val_porcentaje_margen: 0.1130
# Epoch 89/1500
# 1147/1147 [==============================] - 1s 768us/step - loss: 16.9448 - porcentaje_margen: 0.0944 - val_loss: 14.3728 - val_porcentaje_margen: 0.1130
# Epoch 90/1500
# 1147/1147 [==============================] - 1s 786us/step - loss: 16.9426 - porcentaje_margen: 0.0974 - val_loss: 14.3711 - val_porcentaje_margen: 0.1130
# Epoch 91/1500
# 1147/1147 [==============================] - 1s 877us/step - loss: 16.9413 - porcentaje_margen: 0.0984 - val_loss: 14.3694 - val_porcentaje_margen: 0.1130
# Epoch 92/1500
# 1147/1147 [==============================] - 1s 798us/step - loss: 16.9393 - porcentaje_margen: 0.0979 - val_loss: 14.3686 - val_porcentaje_margen: 0.1130
# Epoch 93/1500
# 1147/1147 [==============================] - 1s 813us/step - loss: 16.9370 - porcentaje_margen: 0.0984 - val_loss: 14.3664 - val_porcentaje_margen: 0.1112
# Epoch 94/1500
# 1147/1147 [==============================] - 1s 795us/step - loss: 16.9340 - porcentaje_margen: 0.0967 - val_loss: 14.3649 - val_porcentaje_margen: 0.1112
# Epoch 95/1500
# 1147/1147 [==============================] - 1s 853us/step - loss: 16.9319 - porcentaje_margen: 0.0972 - val_loss: 14.3631 - val_porcentaje_margen: 0.1112
# Epoch 96/1500
# 1147/1147 [==============================] - 1s 783us/step - loss: 16.9303 - porcentaje_margen: 0.0975 - val_loss: 14.3608 - val_porcentaje_margen: 0.1130
# Epoch 97/1500
# 1147/1147 [==============================] - 1s 823us/step - loss: 16.9267 - porcentaje_margen: 0.0980 - val_loss: 14.3584 - val_porcentaje_margen: 0.1130
# Epoch 98/1500
# 1147/1147 [==============================] - 1s 771us/step - loss: 16.9231 - porcentaje_margen: 0.0958 - val_loss: 14.3551 - val_porcentaje_margen: 0.1130
# Epoch 99/1500
# 1147/1147 [==============================] - 1s 838us/step - loss: 16.9191 - porcentaje_margen: 0.0965 - val_loss: 14.3510 - val_porcentaje_margen: 0.1130
# Epoch 100/1500
# 1147/1147 [==============================] - 1s 823us/step - loss: 16.9139 - porcentaje_margen: 0.0967 - val_loss: 14.3457 - val_porcentaje_margen: 0.1130
# Epoch 101/1500
# 1147/1147 [==============================] - 1s 820us/step - loss: 16.9063 - porcentaje_margen: 0.0965 - val_loss: 14.3384 - val_porcentaje_margen: 0.1130
# Epoch 102/1500
# 1147/1147 [==============================] - 1s 845us/step - loss: 16.8958 - porcentaje_margen: 0.0970 - val_loss: 14.3265 - val_porcentaje_margen: 0.1130
# Epoch 103/1500
# 1147/1147 [==============================] - 1s 778us/step - loss: 16.8765 - porcentaje_margen: 0.0980 - val_loss: 14.2981 - val_porcentaje_margen: 0.1130
# Epoch 104/1500
# 1147/1147 [==============================] - 1s 799us/step - loss: 16.8035 - porcentaje_margen: 0.0993 - val_loss: 14.1400 - val_porcentaje_margen: 0.1130
# Epoch 105/1500
# 1147/1147 [==============================] - 1s 858us/step - loss: 15.1671 - porcentaje_margen: 0.1078 - val_loss: 11.1252 - val_porcentaje_margen: 0.1147
# Epoch 106/1500
# 1147/1147 [==============================] - 1s 807us/step - loss: 12.8040 - porcentaje_margen: 0.1529 - val_loss: 10.3135 - val_porcentaje_margen: 0.1603
# Epoch 107/1500
# 1147/1147 [==============================] - 1s 858us/step - loss: 12.2567 - porcentaje_margen: 0.1889 - val_loss: 9.9509 - val_porcentaje_margen: 0.1813
# Epoch 108/1500
# 1147/1147 [==============================] - 1s 853us/step - loss: 11.8554 - porcentaje_margen: 0.1967 - val_loss: 9.5869 - val_porcentaje_margen: 0.1672
# Epoch 109/1500
# 1147/1147 [==============================] - 1s 806us/step - loss: 11.4931 - porcentaje_margen: 0.1741 - val_loss: 9.3353 - val_porcentaje_margen: 0.1601
# Epoch 110/1500
# 1147/1147 [==============================] - 1s 809us/step - loss: 11.1582 - porcentaje_margen: 0.1576 - val_loss: 8.9938 - val_porcentaje_margen: 0.1654
# Epoch 111/1500
# 1147/1147 [==============================] - 1s 856us/step - loss: 10.8220 - porcentaje_margen: 0.1522 - val_loss: 8.7539 - val_porcentaje_margen: 0.1410
# Epoch 112/1500
# 1147/1147 [==============================] - 1s 834us/step - loss: 10.5356 - porcentaje_margen: 0.1488 - val_loss: 8.5194 - val_porcentaje_margen: 0.1270
# Epoch 113/1500
# 1147/1147 [==============================] - 1s 894us/step - loss: 10.2290 - porcentaje_margen: 0.1529 - val_loss: 8.2564 - val_porcentaje_margen: 0.1339
# Epoch 114/1500
# 1147/1147 [==============================] - 1s 862us/step - loss: 9.9666 - porcentaje_margen: 0.1505 - val_loss: 7.9826 - val_porcentaje_margen: 0.1530
# Epoch 115/1500
# 1147/1147 [==============================] - 1s 857us/step - loss: 9.7129 - porcentaje_margen: 0.1623 - val_loss: 7.7702 - val_porcentaje_margen: 0.1409
# Epoch 116/1500
# 1147/1147 [==============================] - 1s 878us/step - loss: 9.4701 - porcentaje_margen: 0.1559 - val_loss: 7.5476 - val_porcentaje_margen: 0.1565
# Epoch 117/1500
# 1147/1147 [==============================] - 1s 865us/step - loss: 9.2610 - porcentaje_margen: 0.1517 - val_loss: 7.3660 - val_porcentaje_margen: 0.1495
# Epoch 118/1500
# 1147/1147 [==============================] - 1s 873us/step - loss: 9.0241 - porcentaje_margen: 0.1417 - val_loss: 7.1654 - val_porcentaje_margen: 0.1495
# Epoch 119/1500
# 1147/1147 [==============================] - 1s 779us/step - loss: 8.8177 - porcentaje_margen: 0.1548 - val_loss: 6.9886 - val_porcentaje_margen: 0.1390
# Epoch 120/1500
# 1147/1147 [==============================] - 1s 850us/step - loss: 8.6455 - porcentaje_margen: 0.1569 - val_loss: 6.8519 - val_porcentaje_margen: 0.1374
# Epoch 121/1500
# 1147/1147 [==============================] - 1s 870us/step - loss: 8.4668 - porcentaje_margen: 0.1631 - val_loss: 6.6599 - val_porcentaje_margen: 0.1425
# Epoch 122/1500
# 1147/1147 [==============================] - 1s 863us/step - loss: 8.2619 - porcentaje_margen: 0.1627 - val_loss: 6.5227 - val_porcentaje_margen: 0.1547
# Epoch 123/1500
# 1147/1147 [==============================] - 1s 856us/step - loss: 8.1064 - porcentaje_margen: 0.1716 - val_loss: 6.3540 - val_porcentaje_margen: 0.1565
# Epoch 124/1500
# 1147/1147 [==============================] - 1s 805us/step - loss: 7.9425 - porcentaje_margen: 0.1758 - val_loss: 6.2130 - val_porcentaje_margen: 0.1601
# Epoch 125/1500
# 1147/1147 [==============================] - 1s 825us/step - loss: 7.7529 - porcentaje_margen: 0.1892 - val_loss: 6.0830 - val_porcentaje_margen: 0.1742
# Epoch 126/1500
# 1147/1147 [==============================] - 1s 817us/step - loss: 7.6082 - porcentaje_margen: 0.1825 - val_loss: 5.9337 - val_porcentaje_margen: 0.1741
# Epoch 127/1500
# 1147/1147 [==============================] - 1s 810us/step - loss: 7.4676 - porcentaje_margen: 0.1819 - val_loss: 5.8195 - val_porcentaje_margen: 0.1707
# Epoch 128/1500
# 1147/1147 [==============================] - 1s 802us/step - loss: 7.3100 - porcentaje_margen: 0.1954 - val_loss: 5.6678 - val_porcentaje_margen: 0.1845
# Epoch 129/1500
# 1147/1147 [==============================] - 1s 807us/step - loss: 7.1660 - porcentaje_margen: 0.1934 - val_loss: 5.5518 - val_porcentaje_margen: 0.1863
# Epoch 130/1500
# 1147/1147 [==============================] - 1s 816us/step - loss: 7.0154 - porcentaje_margen: 0.2086 - val_loss: 5.4325 - val_porcentaje_margen: 0.1778
# Epoch 131/1500
# 1147/1147 [==============================] - 1s 796us/step - loss: 6.8754 - porcentaje_margen: 0.2249 - val_loss: 5.3044 - val_porcentaje_margen: 0.1984
# Epoch 132/1500
# 1147/1147 [==============================] - 1s 832us/step - loss: 6.7472 - porcentaje_margen: 0.2202 - val_loss: 5.1789 - val_porcentaje_margen: 0.2054
# Epoch 133/1500
# 1147/1147 [==============================] - 1s 829us/step - loss: 6.6092 - porcentaje_margen: 0.2206 - val_loss: 5.0625 - val_porcentaje_margen: 0.2090
# Epoch 134/1500
# 1147/1147 [==============================] - 1s 820us/step - loss: 6.5139 - porcentaje_margen: 0.2265 - val_loss: 4.9823 - val_porcentaje_margen: 0.2054
# Epoch 135/1500
# 1147/1147 [==============================] - ETA: 0s - loss: 6.5240 - porcentaje_margen: 0.225 - 1s 813us/step - loss: 6.4299 - porcentaje_margen: 0.2249 - val_loss: 4.9041 - val_porcentaje_margen: 0.2161
# Epoch 136/1500
# 1147/1147 [==============================] - 1s 843us/step - loss: 6.2607 - porcentaje_margen: 0.2411 - val_loss: 4.7516 - val_porcentaje_margen: 0.2279
# Epoch 137/1500
# 1147/1147 [==============================] - 1s 851us/step - loss: 6.1228 - porcentaje_margen: 0.2513 - val_loss: 4.6437 - val_porcentaje_margen: 0.2471
# Epoch 138/1500
# 1147/1147 [==============================] - 1s 867us/step - loss: 6.0432 - porcentaje_margen: 0.2419 - val_loss: 4.5590 - val_porcentaje_margen: 0.2175
# Epoch 139/1500
# 1147/1147 [==============================] - 1s 840us/step - loss: 5.9106 - porcentaje_margen: 0.2480 - val_loss: 4.4583 - val_porcentaje_margen: 0.2384
# Epoch 140/1500
# 1147/1147 [==============================] - 1s 821us/step - loss: 5.8289 - porcentaje_margen: 0.2560 - val_loss: 4.3518 - val_porcentaje_margen: 0.2627
# Epoch 141/1500
# 1147/1147 [==============================] - 1s 906us/step - loss: 5.7073 - porcentaje_margen: 0.2537 - val_loss: 4.2928 - val_porcentaje_margen: 0.2263
# Epoch 142/1500
# 1147/1147 [==============================] - 1s 974us/step - loss: 5.6048 - porcentaje_margen: 0.2784 - val_loss: 4.1808 - val_porcentaje_margen: 0.2645
# Epoch 143/1500
# 1147/1147 [==============================] - 1s 936us/step - loss: 5.5154 - porcentaje_margen: 0.2697 - val_loss: 4.1049 - val_porcentaje_margen: 0.2453
# Epoch 144/1500
# 1147/1147 [==============================] - 1s 951us/step - loss: 5.4164 - porcentaje_margen: 0.2831 - val_loss: 4.0197 - val_porcentaje_margen: 0.2943
# Epoch 145/1500
# 1147/1147 [==============================] - 1s 791us/step - loss: 5.3184 - porcentaje_margen: 0.2963 - val_loss: 3.9283 - val_porcentaje_margen: 0.2910
# Epoch 146/1500
# 1147/1147 [==============================] - 1s 824us/step - loss: 5.2302 - porcentaje_margen: 0.2811 - val_loss: 3.8516 - val_porcentaje_margen: 0.2714
# Epoch 147/1500
# 1147/1147 [==============================] - 1s 818us/step - loss: 5.1575 - porcentaje_margen: 0.2918 - val_loss: 3.7715 - val_porcentaje_margen: 0.2836
# Epoch 148/1500
# 1147/1147 [==============================] - 1s 849us/step - loss: 5.0758 - porcentaje_margen: 0.2924 - val_loss: 3.7249 - val_porcentaje_margen: 0.3138
# Epoch 149/1500
# 1147/1147 [==============================] - 1s 840us/step - loss: 4.9939 - porcentaje_margen: 0.3002 - val_loss: 3.8181 - val_porcentaje_margen: 0.2715
# Epoch 150/1500
# 1147/1147 [==============================] - 1s 826us/step - loss: 4.9182 - porcentaje_margen: 0.2971 - val_loss: 3.5678 - val_porcentaje_margen: 0.3122
# Epoch 151/1500
# 1147/1147 [==============================] - 1s 858us/step - loss: 4.8321 - porcentaje_margen: 0.3032 - val_loss: 3.4952 - val_porcentaje_margen: 0.3047
# Epoch 152/1500
# 1147/1147 [==============================] - 1s 804us/step - loss: 4.7872 - porcentaje_margen: 0.2805 - val_loss: 3.4481 - val_porcentaje_margen: 0.3346
# Epoch 153/1500
# 1147/1147 [==============================] - 1s 812us/step - loss: 4.6963 - porcentaje_margen: 0.3016 - val_loss: 3.3807 - val_porcentaje_margen: 0.3279
# Epoch 154/1500
# 1147/1147 [==============================] - 1s 771us/step - loss: 4.6164 - porcentaje_margen: 0.3240 - val_loss: 3.3323 - val_porcentaje_margen: 0.3207
# Epoch 155/1500
# 1147/1147 [==============================] - 1s 796us/step - loss: 4.5460 - porcentaje_margen: 0.3042 - val_loss: 3.2784 - val_porcentaje_margen: 0.2873
# Epoch 156/1500
# 1147/1147 [==============================] - 1s 802us/step - loss: 4.4992 - porcentaje_margen: 0.2998 - val_loss: 3.2520 - val_porcentaje_margen: 0.3137
# Epoch 157/1500
# 1147/1147 [==============================] - 1s 820us/step - loss: 4.4400 - porcentaje_margen: 0.2948 - val_loss: 3.1460 - val_porcentaje_margen: 0.3102
# Epoch 158/1500
# 1147/1147 [==============================] - 1s 809us/step - loss: 4.3579 - porcentaje_margen: 0.3226 - val_loss: 3.0868 - val_porcentaje_margen: 0.3347
# Epoch 159/1500
# 1147/1147 [==============================] - 1s 802us/step - loss: 4.3055 - porcentaje_margen: 0.3186 - val_loss: 3.0444 - val_porcentaje_margen: 0.3311
# Epoch 160/1500
# 1147/1147 [==============================] - 1s 783us/step - loss: 4.2644 - porcentaje_margen: 0.2931 - val_loss: 2.9988 - val_porcentaje_margen: 0.3101
# Epoch 161/1500
# 1147/1147 [==============================] - 1s 843us/step - loss: 4.2022 - porcentaje_margen: 0.3186 - val_loss: 2.9453 - val_porcentaje_margen: 0.3205
# Epoch 162/1500
# 1147/1147 [==============================] - 1s 807us/step - loss: 4.1286 - porcentaje_margen: 0.3160 - val_loss: 2.9066 - val_porcentaje_margen: 0.3277
# Epoch 163/1500
# 1147/1147 [==============================] - 1s 827us/step - loss: 4.0721 - porcentaje_margen: 0.3351 - val_loss: 2.8488 - val_porcentaje_margen: 0.3188
# Epoch 164/1500
# 1147/1147 [==============================] - 1s 795us/step - loss: 4.0243 - porcentaje_margen: 0.3221 - val_loss: 2.8027 - val_porcentaje_margen: 0.3310
# Epoch 165/1500
# 1147/1147 [==============================] - 1s 778us/step - loss: 3.9626 - porcentaje_margen: 0.3353 - val_loss: 2.7661 - val_porcentaje_margen: 0.3260
# Epoch 166/1500
# 1147/1147 [==============================] - 1s 802us/step - loss: 3.9164 - porcentaje_margen: 0.3283 - val_loss: 2.7173 - val_porcentaje_margen: 0.3433
# Epoch 167/1500
# 1147/1147 [==============================] - 1s 801us/step - loss: 3.8685 - porcentaje_margen: 0.3244 - val_loss: 2.6723 - val_porcentaje_margen: 0.3450
# Epoch 168/1500
# 1147/1147 [==============================] - 1s 822us/step - loss: 3.8187 - porcentaje_margen: 0.3200 - val_loss: 2.6424 - val_porcentaje_margen: 0.3331
# Epoch 169/1500
# 1147/1147 [==============================] - 1s 838us/step - loss: 3.7764 - porcentaje_margen: 0.3287 - val_loss: 2.6019 - val_porcentaje_margen: 0.3328
# Epoch 170/1500
# 1147/1147 [==============================] - 1s 874us/step - loss: 3.7232 - porcentaje_margen: 0.3272 - val_loss: 2.5612 - val_porcentaje_margen: 0.3433
# Epoch 171/1500
# 1147/1147 [==============================] - 1s 841us/step - loss: 3.6896 - porcentaje_margen: 0.3304 - val_loss: 2.6072 - val_porcentaje_margen: 0.3323
# Epoch 172/1500
# 1147/1147 [==============================] - 1s 798us/step - loss: 3.6518 - porcentaje_margen: 0.3077 - val_loss: 2.4897 - val_porcentaje_margen: 0.3471
# Epoch 173/1500
# 1147/1147 [==============================] - 1s 855us/step - loss: 3.5899 - porcentaje_margen: 0.3327 - val_loss: 2.4498 - val_porcentaje_margen: 0.3469
# Epoch 174/1500
# 1147/1147 [==============================] - 1s 831us/step - loss: 3.5463 - porcentaje_margen: 0.3374 - val_loss: 2.4289 - val_porcentaje_margen: 0.3328
# Epoch 175/1500
# 1147/1147 [==============================] - 1s 838us/step - loss: 3.5128 - porcentaje_margen: 0.3235 - val_loss: 2.4138 - val_porcentaje_margen: 0.3491
# Epoch 176/1500
# 1147/1147 [==============================] - 1s 790us/step - loss: 3.4519 - porcentaje_margen: 0.3391 - val_loss: 2.3779 - val_porcentaje_margen: 0.3525
# Epoch 177/1500
# 1147/1147 [==============================] - 1s 794us/step - loss: 3.4129 - porcentaje_margen: 0.3353 - val_loss: 2.3318 - val_porcentaje_margen: 0.3419
# Epoch 178/1500
# 1147/1147 [==============================] - 1s 808us/step - loss: 3.3656 - porcentaje_margen: 0.3381 - val_loss: 2.2967 - val_porcentaje_margen: 0.3491
# Epoch 179/1500
# 1147/1147 [==============================] - 1s 793us/step - loss: 3.3306 - porcentaje_margen: 0.3445 - val_loss: 2.2859 - val_porcentaje_margen: 0.3225
# Epoch 180/1500
# 1147/1147 [==============================] - 1s 836us/step - loss: 3.2997 - porcentaje_margen: 0.3379 - val_loss: 2.2669 - val_porcentaje_margen: 0.3207
# Epoch 181/1500
# 1147/1147 [==============================] - 1s 802us/step - loss: 3.2546 - porcentaje_margen: 0.3350 - val_loss: 2.2503 - val_porcentaje_margen: 0.3087
# Epoch 182/1500
# 1147/1147 [==============================] - 1s 812us/step - loss: 3.2115 - porcentaje_margen: 0.3480 - val_loss: 2.2037 - val_porcentaje_margen: 0.3664
# Epoch 183/1500
# 1147/1147 [==============================] - 1s 837us/step - loss: 3.1887 - porcentaje_margen: 0.3502 - val_loss: 2.1703 - val_porcentaje_margen: 0.3541
# Epoch 184/1500
# 1147/1147 [==============================] - 1s 847us/step - loss: 3.1459 - porcentaje_margen: 0.3390 - val_loss: 2.1568 - val_porcentaje_margen: 0.3557
# Epoch 185/1500
# 1147/1147 [==============================] - 1s 814us/step - loss: 3.1265 - porcentaje_margen: 0.3230 - val_loss: 2.2413 - val_porcentaje_margen: 0.2473
# Epoch 186/1500
# 1147/1147 [==============================] - 1s 836us/step - loss: 3.1039 - porcentaje_margen: 0.3211 - val_loss: 2.1755 - val_porcentaje_margen: 0.2631
# Epoch 187/1500
# 1147/1147 [==============================] - 1s 814us/step - loss: 3.0448 - porcentaje_margen: 0.3381 - val_loss: 2.1420 - val_porcentaje_margen: 0.3725
# Epoch 188/1500
# 1147/1147 [==============================] - 1s 821us/step - loss: 3.0077 - porcentaje_margen: 0.3537 - val_loss: 2.0846 - val_porcentaje_margen: 0.3730
# Epoch 189/1500
# 1147/1147 [==============================] - 1s 831us/step - loss: 2.9780 - porcentaje_margen: 0.3449 - val_loss: 2.1249 - val_porcentaje_margen: 0.3413
# Epoch 190/1500
# 1147/1147 [==============================] - 1s 840us/step - loss: 2.9445 - porcentaje_margen: 0.3464 - val_loss: 1.9998 - val_porcentaje_margen: 0.3384
# Epoch 191/1500
# 1147/1147 [==============================] - 1s 847us/step - loss: 2.9099 - porcentaje_margen: 0.3492 - val_loss: 2.0066 - val_porcentaje_margen: 0.3227
# Epoch 192/1500
# 1147/1147 [==============================] - 1s 824us/step - loss: 2.8840 - porcentaje_margen: 0.3398 - val_loss: 1.9675 - val_porcentaje_margen: 0.3296
# Epoch 193/1500
# 1147/1147 [==============================] - 1s 816us/step - loss: 2.8539 - porcentaje_margen: 0.3438 - val_loss: 1.9284 - val_porcentaje_margen: 0.3751
# Epoch 194/1500
# 1147/1147 [==============================] - 1s 829us/step - loss: 2.8199 - porcentaje_margen: 0.3375 - val_loss: 1.9134 - val_porcentaje_margen: 0.3874
# Epoch 195/1500
# 1147/1147 [==============================] - 1s 778us/step - loss: 2.7946 - porcentaje_margen: 0.3526 - val_loss: 1.8837 - val_porcentaje_margen: 0.3647
# Epoch 196/1500
# 1147/1147 [==============================] - 1s 810us/step - loss: 2.7549 - porcentaje_margen: 0.3491 - val_loss: 1.8734 - val_porcentaje_margen: 0.3803
# Epoch 197/1500
# 1147/1147 [==============================] - 1s 806us/step - loss: 2.7239 - porcentaje_margen: 0.3525 - val_loss: 1.8699 - val_porcentaje_margen: 0.3243
# Epoch 198/1500
# 1147/1147 [==============================] - 1s 794us/step - loss: 2.6926 - porcentaje_margen: 0.3624 - val_loss: 1.8620 - val_porcentaje_margen: 0.3714
# Epoch 199/1500
# 1147/1147 [==============================] - 1s 816us/step - loss: 2.6607 - porcentaje_margen: 0.3585 - val_loss: 1.8222 - val_porcentaje_margen: 0.3382
# Epoch 200/1500
# 1147/1147 [==============================] - 1s 791us/step - loss: 2.6518 - porcentaje_margen: 0.3420 - val_loss: 1.8152 - val_porcentaje_margen: 0.3295
# Epoch 201/1500
# 1147/1147 [==============================] - 1s 782us/step - loss: 2.6204 - porcentaje_margen: 0.3495 - val_loss: 1.8582 - val_porcentaje_margen: 0.2875
# Epoch 202/1500
# 1147/1147 [==============================] - 1s 853us/step - loss: 2.6193 - porcentaje_margen: 0.3445 - val_loss: 1.7956 - val_porcentaje_margen: 0.4006
# Epoch 203/1500
# 1147/1147 [==============================] - 1s 789us/step - loss: 2.5840 - porcentaje_margen: 0.3582 - val_loss: 1.7454 - val_porcentaje_margen: 0.3541
# Epoch 204/1500
# 1147/1147 [==============================] - 1s 799us/step - loss: 2.5383 - porcentaje_margen: 0.3438 - val_loss: 1.7157 - val_porcentaje_margen: 0.3855
# Epoch 205/1500
# 1147/1147 [==============================] - 1s 774us/step - loss: 2.5122 - porcentaje_margen: 0.3561 - val_loss: 1.6936 - val_porcentaje_margen: 0.3784
# Epoch 206/1500
# 1147/1147 [==============================] - 1s 818us/step - loss: 2.4814 - porcentaje_margen: 0.3462 - val_loss: 1.6937 - val_porcentaje_margen: 0.3834
# Epoch 207/1500
# 1147/1147 [==============================] - 1s 783us/step - loss: 2.4713 - porcentaje_margen: 0.3447 - val_loss: 1.6591 - val_porcentaje_margen: 0.3803
# Epoch 208/1500
# 1147/1147 [==============================] - 1s 777us/step - loss: 2.4277 - porcentaje_margen: 0.3745 - val_loss: 1.6438 - val_porcentaje_margen: 0.3682
# Epoch 209/1500
# 1147/1147 [==============================] - 1s 841us/step - loss: 2.3991 - porcentaje_margen: 0.3586 - val_loss: 1.6258 - val_porcentaje_margen: 0.3837
# Epoch 210/1500
# 1147/1147 [==============================] - 1s 828us/step - loss: 2.3984 - porcentaje_margen: 0.3502 - val_loss: 1.6141 - val_porcentaje_margen: 0.3750
# Epoch 211/1500
# 1147/1147 [==============================] - 1s 827us/step - loss: 2.3578 - porcentaje_margen: 0.3634 - val_loss: 1.5961 - val_porcentaje_margen: 0.4009
# Epoch 212/1500
# 1147/1147 [==============================] - 1s 799us/step - loss: 2.3274 - porcentaje_margen: 0.3782 - val_loss: 1.5810 - val_porcentaje_margen: 0.3872
# Epoch 213/1500
# 1147/1147 [==============================] - 1s 823us/step - loss: 2.3185 - porcentaje_margen: 0.3730 - val_loss: 1.5643 - val_porcentaje_margen: 0.3872
# Epoch 214/1500
# 1147/1147 [==============================] - 1s 820us/step - loss: 2.2820 - porcentaje_margen: 0.3695 - val_loss: 1.6034 - val_porcentaje_margen: 0.3120
# Epoch 215/1500
# 1147/1147 [==============================] - 1s 831us/step - loss: 2.2803 - porcentaje_margen: 0.3598 - val_loss: 1.5440 - val_porcentaje_margen: 0.3958
# Epoch 216/1500
# 1147/1147 [==============================] - 1s 816us/step - loss: 2.2421 - porcentaje_margen: 0.3817 - val_loss: 1.5256 - val_porcentaje_margen: 0.4008
# Epoch 217/1500
# 1147/1147 [==============================] - 1s 861us/step - loss: 2.2451 - porcentaje_margen: 0.3556 - val_loss: 1.5930 - val_porcentaje_margen: 0.2949
# Epoch 218/1500
# 1147/1147 [==============================] - 1s 817us/step - loss: 2.2367 - porcentaje_margen: 0.3656 - val_loss: 1.5010 - val_porcentaje_margen: 0.3992
# Epoch 219/1500
# 1147/1147 [==============================] - 1s 823us/step - loss: 2.1879 - porcentaje_margen: 0.3671 - val_loss: 1.4804 - val_porcentaje_margen: 0.3766
# Epoch 220/1500
# 1147/1147 [==============================] - 1s 806us/step - loss: 2.1618 - porcentaje_margen: 0.3817 - val_loss: 1.4789 - val_porcentaje_margen: 0.3661
# Epoch 221/1500
# 1147/1147 [==============================] - 1s 824us/step - loss: 2.1375 - porcentaje_margen: 0.3803 - val_loss: 1.5046 - val_porcentaje_margen: 0.3313
# Epoch 222/1500
# 1147/1147 [==============================] - 1s 803us/step - loss: 2.1273 - porcentaje_margen: 0.3723 - val_loss: 1.4415 - val_porcentaje_margen: 0.3888
# Epoch 223/1500
# 1147/1147 [==============================] - 1s 861us/step - loss: 2.1031 - porcentaje_margen: 0.3671 - val_loss: 1.4567 - val_porcentaje_margen: 0.3745
# Epoch 224/1500
# 1147/1147 [==============================] - 1s 797us/step - loss: 2.0961 - porcentaje_margen: 0.3553 - val_loss: 1.4222 - val_porcentaje_margen: 0.3819
# Epoch 225/1500
# 1147/1147 [==============================] - 1s 835us/step - loss: 2.0643 - porcentaje_margen: 0.3804 - val_loss: 1.4065 - val_porcentaje_margen: 0.3992
# Epoch 226/1500
# 1147/1147 [==============================] - 1s 820us/step - loss: 2.0528 - porcentaje_margen: 0.3679 - val_loss: 1.4135 - val_porcentaje_margen: 0.4182
# Epoch 227/1500
# 1147/1147 [==============================] - 1s 901us/step - loss: 2.0319 - porcentaje_margen: 0.3764 - val_loss: 1.3770 - val_porcentaje_margen: 0.4235
# Epoch 228/1500
# 1147/1147 [==============================] - 1s 803us/step - loss: 2.0136 - porcentaje_margen: 0.3952 - val_loss: 1.4115 - val_porcentaje_margen: 0.3417
# Epoch 229/1500
# 1147/1147 [==============================] - 1s 820us/step - loss: 2.0069 - porcentaje_margen: 0.3744 - val_loss: 1.3685 - val_porcentaje_margen: 0.4045
# Epoch 230/1500
# 1147/1147 [==============================] - 1s 812us/step - loss: 1.9871 - porcentaje_margen: 0.3838 - val_loss: 1.3511 - val_porcentaje_margen: 0.3959
# Epoch 231/1500
# 1147/1147 [==============================] - 1s 797us/step - loss: 1.9683 - porcentaje_margen: 0.3941 - val_loss: 1.3442 - val_porcentaje_margen: 0.3786
# Epoch 232/1500
# 1147/1147 [==============================] - 1s 856us/step - loss: 1.9492 - porcentaje_margen: 0.3933 - val_loss: 1.3266 - val_porcentaje_margen: 0.3961
# Epoch 233/1500
# 1147/1147 [==============================] - 1s 832us/step - loss: 1.9337 - porcentaje_margen: 0.3794 - val_loss: 1.3434 - val_porcentaje_margen: 0.3455
# Epoch 234/1500
# 1147/1147 [==============================] - 1s 872us/step - loss: 1.9113 - porcentaje_margen: 0.3945 - val_loss: 1.3149 - val_porcentaje_margen: 0.3700
# Epoch 235/1500
# 1147/1147 [==============================] - 1s 807us/step - loss: 1.8927 - porcentaje_margen: 0.3780 - val_loss: 1.3032 - val_porcentaje_margen: 0.3734
# Epoch 236/1500
# 1147/1147 [==============================] - 1s 794us/step - loss: 1.8755 - porcentaje_margen: 0.3886 - val_loss: 1.2939 - val_porcentaje_margen: 0.3906
# Epoch 237/1500
# 1147/1147 [==============================] - 1s 869us/step - loss: 1.8683 - porcentaje_margen: 0.3978 - val_loss: 1.2720 - val_porcentaje_margen: 0.4220
# Epoch 238/1500
# 1147/1147 [==============================] - 1s 802us/step - loss: 1.8600 - porcentaje_margen: 0.4021 - val_loss: 1.2657 - val_porcentaje_margen: 0.4064
# Epoch 239/1500
# 1147/1147 [==============================] - 1s 889us/step - loss: 1.8364 - porcentaje_margen: 0.3614 - val_loss: 1.3135 - val_porcentaje_margen: 0.3470
# Epoch 240/1500
# 1147/1147 [==============================] - 1s 836us/step - loss: 1.8172 - porcentaje_margen: 0.3851 - val_loss: 1.2441 - val_porcentaje_margen: 0.4340
# Epoch 241/1500
# 1147/1147 [==============================] - 1s 813us/step - loss: 1.8001 - porcentaje_margen: 0.4041 - val_loss: 1.2709 - val_porcentaje_margen: 0.3505
# Epoch 242/1500
# 1147/1147 [==============================] - 1s 821us/step - loss: 1.7999 - porcentaje_margen: 0.3912 - val_loss: 1.2318 - val_porcentaje_margen: 0.4149
# Epoch 243/1500
# 1147/1147 [==============================] - 1s 819us/step - loss: 1.7705 - porcentaje_margen: 0.3896 - val_loss: 1.2185 - val_porcentaje_margen: 0.4324
# Epoch 244/1500
# 1147/1147 [==============================] - 1s 823us/step - loss: 1.7547 - porcentaje_margen: 0.3947 - val_loss: 1.2125 - val_porcentaje_margen: 0.3924
# Epoch 245/1500
# 1147/1147 [==============================] - 1s 823us/step - loss: 1.7455 - porcentaje_margen: 0.4051 - val_loss: 1.2056 - val_porcentaje_margen: 0.3818
# Epoch 246/1500
# 1147/1147 [==============================] - 1s 846us/step - loss: 1.7362 - porcentaje_margen: 0.4026 - val_loss: 1.1897 - val_porcentaje_margen: 0.4150
# Epoch 247/1500
# 1147/1147 [==============================] - 1s 889us/step - loss: 1.7146 - porcentaje_margen: 0.3985 - val_loss: 1.1842 - val_porcentaje_margen: 0.4219
# Epoch 248/1500
# 1147/1147 [==============================] - 1s 886us/step - loss: 1.7076 - porcentaje_margen: 0.3950 - val_loss: 1.1729 - val_porcentaje_margen: 0.4204
# Epoch 249/1500
# 1147/1147 [==============================] - 1s 844us/step - loss: 1.6879 - porcentaje_margen: 0.3950 - val_loss: 1.1702 - val_porcentaje_margen: 0.4167
# Epoch 250/1500
# 1147/1147 [==============================] - 1s 839us/step - loss: 1.6913 - porcentaje_margen: 0.3869 - val_loss: 1.1678 - val_porcentaje_margen: 0.3854
# Epoch 251/1500
# 1147/1147 [==============================] - 1s 821us/step - loss: 1.6905 - porcentaje_margen: 0.3971 - val_loss: 1.1692 - val_porcentaje_margen: 0.4148
# Epoch 252/1500
# 1147/1147 [==============================] - 1s 849us/step - loss: 1.6583 - porcentaje_margen: 0.3734 - val_loss: 1.2200 - val_porcentaje_margen: 0.3382
# Epoch 253/1500
# 1147/1147 [==============================] - 1s 850us/step - loss: 1.6394 - porcentaje_margen: 0.3926 - val_loss: 1.1678 - val_porcentaje_margen: 0.4058
# Epoch 254/1500
# 1147/1147 [==============================] - 1s 902us/step - loss: 1.6410 - porcentaje_margen: 0.3894 - val_loss: 1.1244 - val_porcentaje_margen: 0.4343
# Epoch 255/1500
# 1147/1147 [==============================] - 1s 1ms/step - loss: 1.6132 - porcentaje_margen: 0.3983 - val_loss: 1.1353 - val_porcentaje_margen: 0.4200
# Epoch 256/1500
# 1147/1147 [==============================] - 1s 991us/step - loss: 1.5958 - porcentaje_margen: 0.4018 - val_loss: 1.1609 - val_porcentaje_margen: 0.3644
# Epoch 257/1500
# 1147/1147 [==============================] - 1s 1ms/step - loss: 1.5811 - porcentaje_margen: 0.4118 - val_loss: 1.1117 - val_porcentaje_margen: 0.4235
# Epoch 258/1500
# 1147/1147 [==============================] - 1s 963us/step - loss: 1.5686 - porcentaje_margen: 0.4113 - val_loss: 1.0973 - val_porcentaje_margen: 0.4289
# Epoch 259/1500
# 1147/1147 [==============================] - 1s 966us/step - loss: 1.5705 - porcentaje_margen: 0.4009 - val_loss: 1.0979 - val_porcentaje_margen: 0.4288
# Epoch 260/1500
# 1147/1147 [==============================] - 1s 806us/step - loss: 1.5400 - porcentaje_margen: 0.4128 - val_loss: 1.0833 - val_porcentaje_margen: 0.4392
# Epoch 261/1500
# 1147/1147 [==============================] - 1s 826us/step - loss: 1.5323 - porcentaje_margen: 0.4354 - val_loss: 1.1031 - val_porcentaje_margen: 0.3889
# Epoch 262/1500
# 1147/1147 [==============================] - 1s 809us/step - loss: 1.5204 - porcentaje_margen: 0.4082 - val_loss: 1.0745 - val_porcentaje_margen: 0.4221
# Epoch 263/1500
# 1147/1147 [==============================] - 1s 870us/step - loss: 1.5106 - porcentaje_margen: 0.4146 - val_loss: 1.0874 - val_porcentaje_margen: 0.3782
# Epoch 264/1500
# 1147/1147 [==============================] - 1s 872us/step - loss: 1.5081 - porcentaje_margen: 0.4056 - val_loss: 1.0634 - val_porcentaje_margen: 0.4392
# Epoch 265/1500
# 1147/1147 [==============================] - 1s 811us/step - loss: 1.4886 - porcentaje_margen: 0.4229 - val_loss: 1.0647 - val_porcentaje_margen: 0.4390
# Epoch 266/1500
# 1147/1147 [==============================] - 1s 823us/step - loss: 1.4932 - porcentaje_margen: 0.4042 - val_loss: 1.0478 - val_porcentaje_margen: 0.4375
# Epoch 267/1500
# 1147/1147 [==============================] - 1s 850us/step - loss: 1.4831 - porcentaje_margen: 0.4025 - val_loss: 1.0602 - val_porcentaje_margen: 0.3853
# Epoch 268/1500
# 1147/1147 [==============================] - 1s 830us/step - loss: 1.4614 - porcentaje_margen: 0.4273 - val_loss: 1.0386 - val_porcentaje_margen: 0.4356
# Epoch 269/1500
# 1147/1147 [==============================] - 1s 885us/step - loss: 1.4469 - porcentaje_margen: 0.4004 - val_loss: 1.0225 - val_porcentaje_margen: 0.4289
# Epoch 270/1500
# 1147/1147 [==============================] - 1s 858us/step - loss: 1.4412 - porcentaje_margen: 0.4245 - val_loss: 1.0179 - val_porcentaje_margen: 0.4271
# Epoch 271/1500
# 1147/1147 [==============================] - 1s 795us/step - loss: 1.4491 - porcentaje_margen: 0.4019 - val_loss: 1.0142 - val_porcentaje_margen: 0.4219
# Epoch 272/1500
# 1147/1147 [==============================] - 1s 820us/step - loss: 1.4050 - porcentaje_margen: 0.4195 - val_loss: 1.0074 - val_porcentaje_margen: 0.4080
# Epoch 273/1500
# 1147/1147 [==============================] - 1s 853us/step - loss: 1.4063 - porcentaje_margen: 0.4138 - val_loss: 1.0061 - val_porcentaje_margen: 0.4219
# Epoch 274/1500
# 1147/1147 [==============================] - 1s 849us/step - loss: 1.4028 - porcentaje_margen: 0.4176 - val_loss: 1.0313 - val_porcentaje_margen: 0.4094
# Epoch 275/1500
# 1147/1147 [==============================] - 1s 848us/step - loss: 1.3815 - porcentaje_margen: 0.4300 - val_loss: 0.9964 - val_porcentaje_margen: 0.4322
# Epoch 276/1500
# 1147/1147 [==============================] - 1s 843us/step - loss: 1.3688 - porcentaje_margen: 0.4288 - val_loss: 0.9991 - val_porcentaje_margen: 0.4459
# Epoch 277/1500
# 1147/1147 [==============================] - 1s 838us/step - loss: 1.3619 - porcentaje_margen: 0.4400 - val_loss: 1.0160 - val_porcentaje_margen: 0.4213
# Epoch 278/1500
# 1147/1147 [==============================] - 1s 828us/step - loss: 1.3652 - porcentaje_margen: 0.4058 - val_loss: 0.9955 - val_porcentaje_margen: 0.4422
# Epoch 279/1500
# 1147/1147 [==============================] - 1s 853us/step - loss: 1.3501 - porcentaje_margen: 0.4120 - val_loss: 0.9670 - val_porcentaje_margen: 0.4358
# Epoch 280/1500
# 1147/1147 [==============================] - 1s 865us/step - loss: 1.3303 - porcentaje_margen: 0.4216 - val_loss: 0.9690 - val_porcentaje_margen: 0.4167
# Epoch 281/1500
# 1147/1147 [==============================] - 1s 819us/step - loss: 1.3181 - porcentaje_margen: 0.4160 - val_loss: 0.9531 - val_porcentaje_margen: 0.4395
# Epoch 282/1500
# 1147/1147 [==============================] - 1s 812us/step - loss: 1.3088 - porcentaje_margen: 0.4228 - val_loss: 0.9504 - val_porcentaje_margen: 0.4394
# Epoch 283/1500
# 1147/1147 [==============================] - 1s 865us/step - loss: 1.3032 - porcentaje_margen: 0.4287 - val_loss: 0.9684 - val_porcentaje_margen: 0.4441
# Epoch 284/1500
# 1147/1147 [==============================] - 1s 853us/step - loss: 1.3022 - porcentaje_margen: 0.4270 - val_loss: 0.9385 - val_porcentaje_margen: 0.4325
# Epoch 285/1500
# ...
# Epoch 1407/1500
# 1147/1147 [==============================] - 1s 903us/step - loss: 0.5303 - porcentaje_margen: 0.5163 - val_loss: 0.4530 - val_porcentaje_margen: 0.5454
# Epoch 1408/1500
# 1147/1147 [==============================] - 1s 795us/step - loss: 0.5267 - porcentaje_margen: 0.5060 - val_loss: 0.4501 - val_porcentaje_margen: 0.5351
# Epoch 1409/1500
# 1147/1147 [==============================] - 1s 872us/step - loss: 0.5280 - porcentaje_margen: 0.5224 - val_loss: 0.4502 - val_porcentaje_margen: 0.5402
# Epoch 1410/1500
# 1147/1147 [==============================] - 1s 821us/step - loss: 0.5384 - porcentaje_margen: 0.5103 - val_loss: 0.4501 - val_porcentaje_margen: 0.5471
# Epoch 1411/1500
# 1147/1147 [==============================] - 1s 828us/step - loss: 0.5290 - porcentaje_margen: 0.5157 - val_loss: 0.4670 - val_porcentaje_margen: 0.5192
# Epoch 1412/1500
# 1147/1147 [==============================] - 1s 832us/step - loss: 0.5272 - porcentaje_margen: 0.5127 - val_loss: 0.4550 - val_porcentaje_margen: 0.5160
# Epoch 1413/1500
# 1147/1147 [==============================] - 1s 826us/step - loss: 0.5347 - porcentaje_margen: 0.4969 - val_loss: 0.4531 - val_porcentaje_margen: 0.5385
# Epoch 1414/1500
# 1147/1147 [==============================] - 1s 811us/step - loss: 0.5367 - porcentaje_margen: 0.4831 - val_loss: 0.4543 - val_porcentaje_margen: 0.5175
# Epoch 1415/1500
# 1147/1147 [==============================] - 1s 803us/step - loss: 0.5286 - porcentaje_margen: 0.5245 - val_loss: 0.4500 - val_porcentaje_margen: 0.5316
# Epoch 1416/1500
# 1147/1147 [==============================] - 1s 828us/step - loss: 0.5280 - porcentaje_margen: 0.5112 - val_loss: 0.4577 - val_porcentaje_margen: 0.5108
# Epoch 1417/1500
# 1147/1147 [==============================] - 1s 839us/step - loss: 0.5307 - porcentaje_margen: 0.4922 - val_loss: 0.4536 - val_porcentaje_margen: 0.5381
# Epoch 1418/1500
# 1147/1147 [==============================] - 1s 807us/step - loss: 0.5293 - porcentaje_margen: 0.5158 - val_loss: 0.4557 - val_porcentaje_margen: 0.5352
# Epoch 1419/1500
# 1147/1147 [==============================] - 1s 809us/step - loss: 0.5304 - porcentaje_margen: 0.5102 - val_loss: 0.4498 - val_porcentaje_margen: 0.5350
# Epoch 1420/1500
# 1147/1147 [==============================] - 1s 861us/step - loss: 0.5309 - porcentaje_margen: 0.5078 - val_loss: 0.4548 - val_porcentaje_margen: 0.5486
# Epoch 1421/1500
# 1147/1147 [==============================] - 1s 807us/step - loss: 0.5330 - porcentaje_margen: 0.5040 - val_loss: 0.4641 - val_porcentaje_margen: 0.5122
# Epoch 1422/1500
# 1147/1147 [==============================] - 1s 758us/step - loss: 0.5308 - porcentaje_margen: 0.5076 - val_loss: 0.4515 - val_porcentaje_margen: 0.5455
# Epoch 1423/1500
# 1147/1147 [==============================] - 1s 772us/step - loss: 0.5330 - porcentaje_margen: 0.5307 - val_loss: 0.4574 - val_porcentaje_margen: 0.5628
# Epoch 1424/1500
# 1147/1147 [==============================] - 1s 782us/step - loss: 0.5264 - porcentaje_margen: 0.5148 - val_loss: 0.4644 - val_porcentaje_margen: 0.5209
# Epoch 1425/1500
# 1147/1147 [==============================] - 1s 816us/step - loss: 0.5302 - porcentaje_margen: 0.5184 - val_loss: 0.4568 - val_porcentaje_margen: 0.5229
# Epoch 1426/1500
# 1147/1147 [==============================] - 1s 833us/step - loss: 0.5320 - porcentaje_margen: 0.5177 - val_loss: 0.4535 - val_porcentaje_margen: 0.5438
# Epoch 1427/1500
# 1147/1147 [==============================] - 1s 894us/step - loss: 0.5550 - porcentaje_margen: 0.4620 - val_loss: 0.4692 - val_porcentaje_margen: 0.5316
# Epoch 1428/1500
# 1147/1147 [==============================] - 1s 823us/step - loss: 0.5325 - porcentaje_margen: 0.5042 - val_loss: 0.4530 - val_porcentaje_margen: 0.5312
# Epoch 1429/1500
# 1147/1147 [==============================] - 1s 834us/step - loss: 0.5246 - porcentaje_margen: 0.5163 - val_loss: 0.4533 - val_porcentaje_margen: 0.5387
# Epoch 1430/1500
# 1147/1147 [==============================] - 1s 805us/step - loss: 0.5325 - porcentaje_margen: 0.5048 - val_loss: 0.4689 - val_porcentaje_margen: 0.5140
# Epoch 1431/1500
# 1147/1147 [==============================] - 1s 830us/step - loss: 0.5234 - porcentaje_margen: 0.5172 - val_loss: 0.4503 - val_porcentaje_margen: 0.5419
# Epoch 1432/1500
# 1147/1147 [==============================] - 1s 814us/step - loss: 0.5297 - porcentaje_margen: 0.5073 - val_loss: 0.4620 - val_porcentaje_margen: 0.5404
# Epoch 1433/1500
# 1147/1147 [==============================] - 1s 877us/step - loss: 0.5243 - porcentaje_margen: 0.5165 - val_loss: 0.4493 - val_porcentaje_margen: 0.5490
# Epoch 1434/1500
# 1147/1147 [==============================] - 1s 910us/step - loss: 0.5281 - porcentaje_margen: 0.5456 - val_loss: 0.4600 - val_porcentaje_margen: 0.5436
# Epoch 1435/1500
# 1147/1147 [==============================] - 1s 851us/step - loss: 0.5524 - porcentaje_margen: 0.4762 - val_loss: 0.5016 - val_porcentaje_margen: 0.4600
# Epoch 1436/1500
# 1147/1147 [==============================] - 1s 846us/step - loss: 0.5402 - porcentaje_margen: 0.4975 - val_loss: 0.4611 - val_porcentaje_margen: 0.5159
# Epoch 1437/1500
# 1147/1147 [==============================] - 1s 874us/step - loss: 0.5305 - porcentaje_margen: 0.4988 - val_loss: 0.4752 - val_porcentaje_margen: 0.5001
# Epoch 1438/1500
# 1147/1147 [==============================] - 1s 890us/step - loss: 0.5288 - porcentaje_margen: 0.5128 - val_loss: 0.4531 - val_porcentaje_margen: 0.5351
# Epoch 1439/1500
# 1147/1147 [==============================] - 1s 848us/step - loss: 0.5278 - porcentaje_margen: 0.5189 - val_loss: 0.4503 - val_porcentaje_margen: 0.5490
# Epoch 1440/1500
# 1147/1147 [==============================] - 1s 829us/step - loss: 0.5230 - porcentaje_margen: 0.5232 - val_loss: 0.4498 - val_porcentaje_margen: 0.5436
# Epoch 1441/1500
# 1147/1147 [==============================] - 1s 849us/step - loss: 0.5302 - porcentaje_margen: 0.5196 - val_loss: 0.4527 - val_porcentaje_margen: 0.5417
# Epoch 1442/1500
# 1147/1147 [==============================] - 1s 880us/step - loss: 0.5325 - porcentaje_margen: 0.5164 - val_loss: 0.4645 - val_porcentaje_margen: 0.4966
# Epoch 1443/1500
# 1147/1147 [==============================] - 1s 837us/step - loss: 0.5261 - porcentaje_margen: 0.5063 - val_loss: 0.4669 - val_porcentaje_margen: 0.5123
# Epoch 1444/1500
# 1147/1147 [==============================] - 1s 853us/step - loss: 0.5408 - porcentaje_margen: 0.4873 - val_loss: 0.4485 - val_porcentaje_margen: 0.5490
# Epoch 1445/1500
# 1147/1147 [==============================] - 1s 825us/step - loss: 0.5253 - porcentaje_margen: 0.5133 - val_loss: 0.4491 - val_porcentaje_margen: 0.5507
# Epoch 1446/1500
# 1147/1147 [==============================] - 1s 892us/step - loss: 0.5240 - porcentaje_margen: 0.5290 - val_loss: 0.4500 - val_porcentaje_margen: 0.5542
# Epoch 1447/1500
# 1147/1147 [==============================] - 1s 798us/step - loss: 0.5259 - porcentaje_margen: 0.5128 - val_loss: 0.4502 - val_porcentaje_margen: 0.5488
# Epoch 1448/1500
# 1147/1147 [==============================] - 1s 808us/step - loss: 0.5314 - porcentaje_margen: 0.5075 - val_loss: 0.4516 - val_porcentaje_margen: 0.5610
# Epoch 1449/1500
# 1147/1147 [==============================] - 1s 825us/step - loss: 0.5401 - porcentaje_margen: 0.5078 - val_loss: 0.4563 - val_porcentaje_margen: 0.5192
# Epoch 1450/1500
# 1147/1147 [==============================] - 1s 863us/step - loss: 0.5284 - porcentaje_margen: 0.5264 - val_loss: 0.4492 - val_porcentaje_margen: 0.5470
# Epoch 1451/1500
# 1147/1147 [==============================] - 1s 850us/step - loss: 0.5289 - porcentaje_margen: 0.5118 - val_loss: 0.4621 - val_porcentaje_margen: 0.5175
# Epoch 1452/1500
# 1147/1147 [==============================] - 1s 833us/step - loss: 0.5289 - porcentaje_margen: 0.4977 - val_loss: 0.4614 - val_porcentaje_margen: 0.4984
# Epoch 1453/1500
# 1147/1147 [==============================] - 1s 875us/step - loss: 0.5325 - porcentaje_margen: 0.4901 - val_loss: 0.4521 - val_porcentaje_margen: 0.5575
# Epoch 1454/1500
# 1147/1147 [==============================] - 1s 846us/step - loss: 0.5408 - porcentaje_margen: 0.4826 - val_loss: 0.4521 - val_porcentaje_margen: 0.5316
# Epoch 1455/1500
# 1147/1147 [==============================] - 1s 824us/step - loss: 0.5328 - porcentaje_margen: 0.5110 - val_loss: 0.4514 - val_porcentaje_margen: 0.5523
# Epoch 1456/1500
# 1147/1147 [==============================] - 1s 877us/step - loss: 0.5220 - porcentaje_margen: 0.5183 - val_loss: 0.4531 - val_porcentaje_margen: 0.5212
# Epoch 1457/1500
# 1147/1147 [==============================] - 1s 842us/step - loss: 0.5261 - porcentaje_margen: 0.5044 - val_loss: 0.4561 - val_porcentaje_margen: 0.5316
# Epoch 1458/1500
# 1147/1147 [==============================] - 1s 857us/step - loss: 0.5262 - porcentaje_margen: 0.5203 - val_loss: 0.4518 - val_porcentaje_margen: 0.5451
# Epoch 1459/1500
# 1147/1147 [==============================] - 1s 818us/step - loss: 0.5206 - porcentaje_margen: 0.5258 - val_loss: 0.4521 - val_porcentaje_margen: 0.5317
# Epoch 1460/1500
# 1147/1147 [==============================] - 1s 826us/step - loss: 0.5270 - porcentaje_margen: 0.5158 - val_loss: 0.4537 - val_porcentaje_margen: 0.5368
# Epoch 1461/1500
# 1147/1147 [==============================] - 1s 846us/step - loss: 0.5239 - porcentaje_margen: 0.4951 - val_loss: 0.4508 - val_porcentaje_margen: 0.5506
# Epoch 1462/1500
# 1147/1147 [==============================] - 1s 872us/step - loss: 0.5310 - porcentaje_margen: 0.5300 - val_loss: 0.4568 - val_porcentaje_margen: 0.5435
# Epoch 1463/1500
# 1147/1147 [==============================] - 1s 828us/step - loss: 0.5262 - porcentaje_margen: 0.5114 - val_loss: 0.4567 - val_porcentaje_margen: 0.5435
# Epoch 1464/1500
# 1147/1147 [==============================] - 1s 836us/step - loss: 0.5339 - porcentaje_margen: 0.5121 - val_loss: 0.4579 - val_porcentaje_margen: 0.5108
# Epoch 1465/1500
# 1147/1147 [==============================] - 1s 915us/step - loss: 0.5290 - porcentaje_margen: 0.5059 - val_loss: 0.4499 - val_porcentaje_margen: 0.5490
# Epoch 1466/1500
# 1147/1147 [==============================] - 1s 882us/step - loss: 0.5248 - porcentaje_margen: 0.4949 - val_loss: 0.4628 - val_porcentaje_margen: 0.5228
# Epoch 1467/1500
# 1147/1147 [==============================] - 1s 870us/step - loss: 0.5281 - porcentaje_margen: 0.5118 - val_loss: 0.4518 - val_porcentaje_margen: 0.5350
# Epoch 1468/1500
# 1147/1147 [==============================] - 1s 869us/step - loss: 0.5282 - porcentaje_margen: 0.5015 - val_loss: 0.4517 - val_porcentaje_margen: 0.5438
# Epoch 1469/1500
# 1147/1147 [==============================] - 1s 802us/step - loss: 0.5204 - porcentaje_margen: 0.5311 - val_loss: 0.4593 - val_porcentaje_margen: 0.5038
# Epoch 1470/1500
# 1147/1147 [==============================] - 1s 831us/step - loss: 0.5275 - porcentaje_margen: 0.5073 - val_loss: 0.4504 - val_porcentaje_margen: 0.5575
# Epoch 1471/1500
# 1147/1147 [==============================] - 1s 791us/step - loss: 0.5227 - porcentaje_margen: 0.5187 - val_loss: 0.4596 - val_porcentaje_margen: 0.5263
# Epoch 1472/1500
# 1147/1147 [==============================] - 1s 876us/step - loss: 0.5311 - porcentaje_margen: 0.5050 - val_loss: 0.4496 - val_porcentaje_margen: 0.5487
# Epoch 1473/1500
# 1147/1147 [==============================] - 1s 839us/step - loss: 0.5226 - porcentaje_margen: 0.5266 - val_loss: 0.4499 - val_porcentaje_margen: 0.5436
# Epoch 1474/1500
# 1147/1147 [==============================] - 1s 810us/step - loss: 0.5260 - porcentaje_margen: 0.5193 - val_loss: 0.4533 - val_porcentaje_margen: 0.5541
# Epoch 1475/1500
# 1147/1147 [==============================] - 1s 812us/step - loss: 0.5214 - porcentaje_margen: 0.5176 - val_loss: 0.4524 - val_porcentaje_margen: 0.5315
# Epoch 1476/1500
# 1147/1147 [==============================] - 1s 822us/step - loss: 0.5247 - porcentaje_margen: 0.5304 - val_loss: 0.4572 - val_porcentaje_margen: 0.5175
# Epoch 1477/1500
# 1147/1147 [==============================] - 1s 853us/step - loss: 0.5314 - porcentaje_margen: 0.4905 - val_loss: 0.4796 - val_porcentaje_margen: 0.5087
# Epoch 1478/1500
# 1147/1147 [==============================] - 1s 856us/step - loss: 0.5223 - porcentaje_margen: 0.5085 - val_loss: 0.4545 - val_porcentaje_margen: 0.5367
# Epoch 1479/1500
# 1147/1147 [==============================] - 1s 830us/step - loss: 0.5249 - porcentaje_margen: 0.5223 - val_loss: 0.4520 - val_porcentaje_margen: 0.5247
# Epoch 1480/1500
# 1147/1147 [==============================] - 1s 816us/step - loss: 0.5224 - porcentaje_margen: 0.5154 - val_loss: 0.4711 - val_porcentaje_margen: 0.5017
# Epoch 1481/1500
# 1147/1147 [==============================] - 1s 833us/step - loss: 0.5213 - porcentaje_margen: 0.5142 - val_loss: 0.4506 - val_porcentaje_margen: 0.5403
# Epoch 1482/1500
# 1147/1147 [==============================] - 1s 836us/step - loss: 0.5236 - porcentaje_margen: 0.5255 - val_loss: 0.4572 - val_porcentaje_margen: 0.5157
# Epoch 1483/1500
# 1147/1147 [==============================] - 1s 791us/step - loss: 0.5260 - porcentaje_margen: 0.5078 - val_loss: 0.4514 - val_porcentaje_margen: 0.5279
# Epoch 1484/1500
# 1147/1147 [==============================] - 1s 837us/step - loss: 0.5333 - porcentaje_margen: 0.4895 - val_loss: 0.4577 - val_porcentaje_margen: 0.5088
# Epoch 1485/1500
# 1147/1147 [==============================] - 1s 841us/step - loss: 0.5233 - porcentaje_margen: 0.5173 - val_loss: 0.4529 - val_porcentaje_margen: 0.5558
# Epoch 1486/1500
# 1147/1147 [==============================] - 1s 862us/step - loss: 0.5217 - porcentaje_margen: 0.5104 - val_loss: 0.4503 - val_porcentaje_margen: 0.5368
# Epoch 1487/1500
# 1147/1147 [==============================] - 1s 860us/step - loss: 0.5266 - porcentaje_margen: 0.5070 - val_loss: 0.4709 - val_porcentaje_margen: 0.4948
# Epoch 1488/1500
# 1147/1147 [==============================] - 1s 860us/step - loss: 0.5293 - porcentaje_margen: 0.5007 - val_loss: 0.4507 - val_porcentaje_margen: 0.5368
# Epoch 1489/1500
# 1147/1147 [==============================] - 1s 821us/step - loss: 0.5200 - porcentaje_margen: 0.5313 - val_loss: 0.4513 - val_porcentaje_margen: 0.5209
# Epoch 1490/1500
# 1147/1147 [==============================] - 1s 823us/step - loss: 0.5229 - porcentaje_margen: 0.5244 - val_loss: 0.4561 - val_porcentaje_margen: 0.5473
# Epoch 1491/1500
# 1147/1147 [==============================] - 1s 812us/step - loss: 0.5283 - porcentaje_margen: 0.5063 - val_loss: 0.4761 - val_porcentaje_margen: 0.4965
# Epoch 1492/1500
# 1147/1147 [==============================] - 1s 851us/step - loss: 0.5205 - porcentaje_margen: 0.4943 - val_loss: 0.4994 - val_porcentaje_margen: 0.4772
# Epoch 1493/1500
# 1147/1147 [==============================] - 1s 839us/step - loss: 0.5387 - porcentaje_margen: 0.4981 - val_loss: 0.4526 - val_porcentaje_margen: 0.5244
# Epoch 1494/1500
# 1147/1147 [==============================] - 1s 818us/step - loss: 0.5271 - porcentaje_margen: 0.5005 - val_loss: 0.4496 - val_porcentaje_margen: 0.5558
# Epoch 1495/1500
# 1147/1147 [==============================] - 1s 889us/step - loss: 0.5212 - porcentaje_margen: 0.5325 - val_loss: 0.4566 - val_porcentaje_margen: 0.5247
# Epoch 1496/1500
# 1147/1147 [==============================] - 1s 844us/step - loss: 0.5254 - porcentaje_margen: 0.5141 - val_loss: 0.4490 - val_porcentaje_margen: 0.5558
# Epoch 1497/1500
# 1147/1147 [==============================] - 1s 841us/step - loss: 0.5242 - porcentaje_margen: 0.5260 - val_loss: 0.4559 - val_porcentaje_margen: 0.5381
# Epoch 1498/1500
# 1147/1147 [==============================] - 1s 857us/step - loss: 0.5232 - porcentaje_margen: 0.5304 - val_loss: 0.4586 - val_porcentaje_margen: 0.5212
# Epoch 1499/1500
# 1147/1147 [==============================] - 1s 891us/step - loss: 0.5373 - porcentaje_margen: 0.4788 - val_loss: 0.4521 - val_porcentaje_margen: 0.5558
# Epoch 1500/1500
# 1147/1147 [==============================] - 1s 861us/step - loss: 0.5194 - porcentaje_margen: 0.5108 - val_loss: 0.4898 - val_porcentaje_margen: 0.4705

# %% [markdown]
# #### Si vemos que necesitamos mas epocas corremos este codigo
# history_LSTM = model.fit(X_train,
#                   y_train,
#                   initial_epoch=700,
#                   epochs=1500,
#                   verbose=1,
#                   validation_data=(X_test,y_test))

# %%
plt.plot(history_LSTM.epoch,history_LSTM.history['val_porcentaje_margen'],label='validation')
plt.plot(history_LSTM.epoch,history_LSTM.history['porcentaje_margen'],label="training")
plt.legend()
plt.title('Success Rate Evolution')
plt.xlabel('Epocs')
plt.show()

# %%
# Calculo la prediccion para mi conjunto test
predicted_stock_price = pd.DataFrame(model.predict(Xtt))

# Junto la grafica de los datos de entrenamiento y test para ver cuanto a variado en terminos generales
indicedetiempo = pd.concat((index_time,index_time_t), axis = 0)
yt = pd.DataFrame(yt) ; ytt = pd.DataFrame(ytt)
stock_real_value = pd.concat((yt,ytt),axis = 0)

# Calculo el RMSE para ver el error de prediccion
rmse = sqrt(mean_squared_error(ytt, predicted_stock_price))

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15, 5))
fig.suptitle(tickers[index],fontsize = 20)
# Plot de todo el grafico
ax1.plot(indicedetiempo,stock_real_value,label="Valor Real",color = "blue")
ax1.plot(index_time_t,predicted_stock_price, label="Valor Predicho", color = "black")
ax1.legend()

# Plot de solo la parte que hemos hecho el predict
ax2.plot(index_time_t,ytt,label="Valor Real",color = "blue")
ax2.plot(index_time_t,predicted_stock_price, label="Valor Predicho", color = "black")
ax2.legend()
ax2.annotate('RMSE = %.2f'% rmse, (index_time_t[40], ytt.iloc[40]), xytext=(50, 50), 
            textcoords='offset points',fontsize = 15)

plt.show()

# %% [markdown]
# Queremos realizar una inversion de 100000 euros en el activo que hemos estudiado, nos basamos en un margen entre la diferencia de los dos precios adyacentes para saber si comprar, vender o mantener.
# Tenemos 3 posibles caminos, comprar solo a la alza, comprar solo a la baja o comprar a la alza y a la baja.
# Ciertos actios tienen caidas o subidas muy bruscas imposibles de predecir porque no tienen que ver con los datos historicos si no con la situacion y el contexto que vive la empresa

# %%
pd.options.display.max_rows = 10000 # Para poder ver todos los movimientos

# Es un margen movil, segun lo que busquemos
margen = 0.05
diferencias = np.zeros(len(predicted_stock_price)-1)
for i in range(len(diferencias)):
    diferencias[i] = (predicted_stock_price.iloc[i+1,0]-predicted_stock_price.iloc[i,0])/max(predicted_stock_price.iloc[i+1,0],predicted_stock_price.iloc[i,0])
    if diferencias[i] > margen:
        diferencias[i] = 1
    elif diferencias[i] < -margen:
        diferencias[i] = -1
    else:
        diferencias[i] = 0
    
print(Counter(diferencias))
# Out:
# Counter({0.0: 243, 1.0: 36, -1.0: 30})

# %%
# Si solo queremos comrpar a la alza
# Estado es lo que hay que hacer ese dia
# estado = 1 comprar, estado = 0 mantener, estado = -1 vender
movimientos_alza = pd.DataFrame(columns = ["presupuesto","acciones","estado","valor","pred","dif"],index = index_time_t)
movimientos_alza.presupuesto[0] = 100000 ; movimientos_alza.acciones[0] = 0 ; movimientos_alza.estado[0] = 0
movimientos_alza.valor[0] = ytt.iloc[0,0] ; movimientos_alza.pred[0] = predicted_stock_price.iloc[0,0]

for i in range(1,len(diferencias)):
    if diferencias[i] == 1:
        if movimientos_alza.acciones[i-1] == 0:
            movimientos_alza.estado[i] = 1
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1] % ytt.iloc[i,0]
            movimientos_alza.acciones[i] = movimientos_alza.presupuesto[i-1] // ytt.iloc[i,0]
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]
        else:
            movimientos_alza.estado[i] = 0
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1]
            movimientos_alza.acciones[i] = movimientos_alza.acciones[i-1]
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]
    elif diferencias[i] == 0:
            movimientos_alza.estado[i] = 0
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1]
            movimientos_alza.acciones[i] = movimientos_alza.acciones[i-1]
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]
    elif diferencias[i] == -1:
        if movimientos_alza.acciones[i-1] > 0:
            movimientos_alza.estado[i] = -1
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1] + movimientos_alza.acciones[i-1] * ytt.iloc[i,0]
            movimientos_alza.acciones[i] = 0
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]
        else:
            movimientos_alza.estado[i] = 0
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1]
            movimientos_alza.acciones[i] = movimientos_alza.acciones[i-1]
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]

            
movimientos_alza = movimientos_alza.drop(movimientos_alza.tail(1).index)
print(movimientos_alza.tail(1))
valor_f_alza = movimientos_alza.presupuesto[len(movimientos_alza)-1] + movimientos_alza.valor[len(movimientos_alza)-1] * movimientos_alza.acciones[len(movimientos_alza)-1]
ganancia_alza = valor_f_alza - 100000
print('Valor Final = %.2f' % valor_f_alza)
print('Ganancia con margen = %.2f' % ganancia_alza)
# Out:
#            presupuesto acciones estado valor     pred dif
# 2018-03-26      220344        0      0  6.94  7.09273  -1
# Valor Final = 220343.57
# Ganancia con margen = 120343.57

# %%
print(movimientos_alza)
# Out:
#            presupuesto acciones estado  valor     pred  dif
# 2016-12-30      100000        0      0  53.58  56.3008  NaN
# 2017-01-03       44.29     1791      1  55.81  56.4817    1
# 2017-01-04      101236        0     -1   56.5  56.5125   -1
# 2017-01-05        1.72     1847      1  54.81  56.4124    1
# 2017-01-06      100996        0     -1  54.68  56.7544   -1
# 2017-01-09      100996        0      0  53.22  56.1689   -1
# 2017-01-10      100996        0      0   52.9  55.5546   -1
# 2017-01-11      100996        0      0  54.45  54.1805   -1
# 2017-01-12       27.54     1913      1  52.78  53.7514    1
# 2017-01-13       27.54     1913      0   53.7  53.8374    1
# 2017-01-17      103330        0     -1     54  54.3208   -1
# 2017-01-18       26.06     1918      1  53.86   54.298    1
# 2017-01-19      102198        0     -1  53.27  54.6275   -1
# 2017-01-20       22.61     1871      1  54.61  54.5827    1
# 2017-01-23       22.61     1871      0   54.9  54.8517    1
# 2017-01-24       22.61     1871      0  56.89  55.4445    1
# 2017-01-25       22.61     1871      0  59.86  55.8165    1
# 2017-01-26       22.61     1871      0  58.14  56.9293    1
# 2017-01-27       22.61     1871      0  54.36  58.0822    1
# 2017-01-30      105753        0     -1  56.51  58.7964   -1
# 2017-01-31      105753        0      0  56.38  57.2486   -1
# 2017-02-01      105753        0      0   56.7  56.6933   -1
# 2017-02-02      105753        0      0  56.51  55.8274   -1
# 2017-02-03       27.57     1863      1  56.75  55.3866    1
# 2017-02-06       27.57     1863      0  56.98   56.136    1
# 2017-02-07       27.57     1863      0  56.71  57.1396    1
# 2017-02-08       27.57     1863      0  56.41  58.4232    1
# 2017-02-09      105119        0     -1  56.41  59.1211   -1
# 2017-02-10      105119        0      0  56.31  58.4565   -1
# 2017-02-13      105119        0      0  56.93  58.1953   -1
# 2017-02-14      105119        0      0  57.01  57.8296   -1
# 2017-02-15       28.95     1835      1  57.27  57.8086    1
# 2017-02-16       28.95     1835      0  57.85   58.073    1
# 2017-02-17       28.95     1835      0  58.87  58.6656    1
# 2017-02-21       28.95     1835      0   58.2  58.8447    1
# 2017-02-22      104073        0     -1   56.7  59.1604   -1
# 2017-02-23      104073        0      0  56.04  58.4506   -1
# 2017-02-24      104073        0      0  55.55  56.1562   -1
# 2017-02-27       24.97     1864      1  55.82  55.2682    1
# 2017-02-28       24.97     1864      0  53.15  56.7994    1
# 2017-03-01      100196        0     -1  53.74  57.6974   -1
# 2017-03-02      100196        0      0  52.28  56.9975   -1
# 2017-03-03      100196        0      0  50.88  56.1926   -1
# 2017-03-06      100196        0      0  50.54  55.1936   -1
# 2017-03-07      100196        0      0  49.99  53.9967   -1
# 2017-03-08      100196        0      0  50.37  53.1379   -1
# 2017-03-09       45.87     1982      1  50.53  52.6684    1
# 2017-03-10       45.87     1982      0  51.03  52.7849    1
# 2017-03-13       45.87     1982      0  49.89  52.9575    1
# 2017-03-14     98016.1        0     -1  49.43  53.1466   -1
# 2017-03-15     98016.1        0      0  49.55  52.2577   -1
# 2017-03-16     98016.1        0      0  50.29   51.164   -1
# 2017-03-17     98016.1        0      0  50.71  50.4096   -1
# 2017-03-20     98016.1        0      0   51.5  50.1754   -1
# 2017-03-21           3     2063      1  47.51  49.9451    1
# 2017-03-22      100698        0     -1  48.81  50.4641   -1
# 2017-03-23       32.75     2032      1  49.54  49.6774    1
# 2017-03-24       32.75     2032      0  49.18   49.683    1
# 2017-03-27      100596        0     -1  49.49  50.1991   -1
# 2017-03-28        29.7     2057      1  48.89  50.0583    1
# 2017-03-29      100864        0     -1  49.02  50.8375   -1
# 2017-03-30       22.54     2029      1   49.7  50.6261    1
# 2017-03-31       22.54     2029      0  49.51  50.6669    1
# 2017-04-03       22.54     2029      0   48.8  51.2978    1
# 2017-04-04     98855.1        0     -1  48.71  51.4834   -1
# 2017-04-05     98855.1        0      0  48.06   51.061   -1
# 2017-04-06     98855.1        0      0  49.31  50.3386   -1
# 2017-04-07     98855.1        0      0  50.93  49.4669   -1
# 2017-04-10       31.73     1910      1  51.74  49.3258    1
# 2017-04-11       31.73     1910      0   51.8  50.6113    1
# 2017-04-12       31.73     1910      0   50.6  52.0234    1
# 2017-04-13     95550.8        0     -1  50.01  52.6119   -1
# 2017-04-17     95550.8        0      0  50.97  51.7607   -1
# 2017-04-18     95550.8        0      0  50.47  50.4633   -1
# 2017-04-19       30.05     1893      1  50.46  49.8705    1
# 2017-04-20       30.05     1893      0   51.1  51.3053    1
# 2017-04-21       30.05     1893      0  50.76  52.0004    1
# 2017-04-24     97898.1        0     -1   51.7  52.1448   -1
# 2017-04-25       16.13     1863      1  52.54  52.0412    1
# 2017-04-26       16.13     1863      0   52.5  52.1351    1
# 2017-04-27       16.13     1863      0  52.87  52.7796    1
# 2017-04-28      102053        0     -1  54.77  53.1361   -1
# 2017-05-01       10.34     1902      1  53.65  53.1203    1
# 2017-05-02       10.34     1902      0  53.69  53.8839    1
# 2017-05-03       10.34     1902      0  53.52  54.3219    1
# 2017-05-04       10.34     1902      0  53.27  54.5392    1
# 2017-05-05      104468        0     -1  54.92  54.8081   -1
# 2017-05-08      104468        0      0  54.91  54.4219   -1
# 2017-05-09      104468        0      0  57.11  54.2084   -1
# 2017-05-10       23.43     1825      1  57.23  54.0261    1
# 2017-05-11       23.43     1825      0  57.32  55.0141    1
# 2017-05-12       23.43     1825      0  56.15  56.5096    1
# 2017-05-15      102734        0     -1  56.28  57.7756   -1
# 2017-05-16      102734        0      0  56.26  57.5856   -1
# 2017-05-17      102734        0      0  54.58  57.2905   -1
# 2017-05-18      102734        0      0  54.91  57.1665   -1
# 2017-05-19      102734        0      0  55.69  56.4086   -1
# 2017-05-22       15.33     1831      1   56.1  56.2994    1
# 2017-05-23       15.33     1831      0  55.77  56.5487    1
# 2017-05-24       15.33     1831      0  56.05   56.811    1
# 2017-05-25       15.33     1831      0     56  56.9618    1
# 2017-05-26      101068        0     -1  55.19  57.0658   -1
# 2017-05-30      101068        0      0   56.4   56.449   -1
# 2017-05-31        4.58     1819      1  55.56  56.1915    1
# 2017-06-01        4.58     1819      0  57.72  56.7676    1
# 2017-06-02        4.58     1819      0  57.53  57.1501    1
# 2017-06-05        4.58     1819      0   57.8  58.3158    1
# 2017-06-06      105798        0     -1  58.16  58.5218   -1
# 2017-06-07      105798        0      0  60.82  58.4762   -1
# 2017-06-08       42.12     1646      1  64.25  57.7293    1
# 2017-06-09       42.12     1646      0  59.66  58.2839    1
# 2017-06-12       42.12     1646      0  58.79  60.3704    1
# 2017-06-13     89156.6        0     -1  54.14  60.8667   -1
# 2017-06-14     89156.6        0      0  52.25  60.2898   -1
# 2017-06-15     89156.6        0      0  52.89  57.7694   -1
# 2017-06-16     89156.6        0      0  52.27  55.8583   -1
# 2017-06-19     89156.6        0      0  54.35  55.4463   -1
# 2017-06-20       43.69     1617      1  55.11  55.3582    1
# 2017-06-21       43.69     1617      0  58.04  56.2275    1
# 2017-06-22       43.69     1617      0  59.55  57.3471    1
# 2017-06-23       43.69     1617      0  59.99  58.8666    1
# 2017-06-26       43.69     1617      0  58.36  60.0834    1
# 2017-06-27     89932.7        0     -1  55.59   60.864   -1
# 2017-06-28     89932.7        0      0  55.82  59.8591   -1
# 2017-06-29     89932.7        0      0  52.86  57.8739   -1
# 2017-06-30     89932.7        0      0  51.71  55.9075   -1
# 2017-07-03     89932.7        0      0  51.95  54.1187   -1
# 2017-07-05       13.72     1746      1   51.5  53.1571    1
# 2017-07-06     88518.5        0     -1  50.69  53.2533   -1
# 2017-07-07     88518.5        0      0  50.86  52.5533   -1
# 2017-07-10        3.46     1686      1   52.5  50.3839    1
# 2017-07-11        3.46     1686      0  52.66  51.2176    1
# 2017-07-12        3.46     1686      0  54.24  53.2316    1
# 2017-07-13        3.46     1686      0  54.47  56.0528    1
# 2017-07-14        3.46     1686      0  55.09  58.4431    1
# 2017-07-17       89058        0     -1  52.82  58.7618   -1
# 2017-07-18       89058        0      0  52.81  58.1861   -1
# 2017-07-19       89058        0      0   54.5  55.4524   -1
# 2017-07-20       89058        0      0  54.14  53.0101   -1
# 2017-07-21       89058        0      0  53.39  51.6197   -1
# 2017-07-24       89058        0      0  53.84   50.903   -1
# 2017-07-25       28.47     1649      1  53.99  50.7258    1
# 2017-07-26       28.47     1649      0  53.93  51.9995    1
# 2017-07-27       28.47     1649      0  56.31  54.2358    1
# 2017-07-28       28.47     1649      0  54.05   55.335    1
# 2017-07-31       28.47     1649      0  52.61  57.3553    1
# 2017-08-01     88926.1        0     -1  53.91  57.8127   -1
# 2017-08-02     88926.1        0      0  51.52  56.5651   -1
# 2017-08-03     88926.1        0      0  50.67  55.8399   -1
# 2017-08-04     88926.1        0      0  45.32  54.7761   -1
# 2017-08-07     88926.1        0      0  44.88  53.6545   -1
# 2017-08-08     88926.1        0      0  42.56  50.1518   -1
# 2017-08-09     88926.1        0      0  42.56  47.8339   -1
# 2017-08-10     88926.1        0      0  40.27  45.6042   -1
# 2017-08-11     88926.1        0      0  40.89  44.9585   -1
# 2017-08-14       22.62     2133      1  41.68  43.7969    1
# 2017-08-15       22.62     2133      0  42.02  44.6067    1
# 2017-08-16     90056.5        0     -1  42.21  45.5541   -1
# 2017-08-17     90056.5        0      0   40.5  44.9735   -1
# 2017-08-18     90056.5        0      0  40.36  44.1849   -1
# 2017-08-21     90056.5        0      0  39.35  42.8075   -1
# 2017-08-22     90056.5        0      0  40.29  41.4664   -1
# 2017-08-23     90056.5        0      0  39.74  40.0343   -1
# 2017-08-24     90056.5        0      0   39.7    39.79   -1
# 2017-08-25       39.99     2232      1  40.33  38.2424    1
# 2017-08-28       39.99     2232      0  41.21  38.4455    1
# 2017-08-29       39.99     2232      0  41.47  39.7178    1
# 2017-08-30       39.99     2232      0  42.38  39.9358    1
# 2017-08-31       39.99     2232      0  41.57  40.7364    1
# 2017-09-01       39.99     2232      0  41.18  41.5547    1
# 2017-09-05       39.99     2232      0  41.21  43.5215    1
# 2017-09-06       39.99     2232      0   39.7   44.022    1
# 2017-09-07     84677.4        0     -1  37.92  44.4145   -1
# 2017-09-08     84677.4        0      0  38.11  43.2647   -1
# 2017-09-11     84677.4        0      0  39.28   42.164   -1
# 2017-09-12     84677.4        0      0  40.79  41.1258   -1
# 2017-09-13       36.23     2072      1  40.85  40.6885    1
# 2017-09-14       36.23     2072      0   40.6  41.0901    1
# 2017-09-15       36.23     2072      0   40.8  41.2722    1
# 2017-09-18       36.23     2072      0  40.44    41.85    1
# 2017-09-19       36.23     2072      0  39.54  42.1672    1
# 2017-09-20     81486.5        0     -1  39.31  42.3773   -1
# 2017-09-21     81486.5        0      0   39.4   41.378   -1
# 2017-09-22     81486.5        0      0  37.98  40.7607   -1
# 2017-09-25     81486.5        0      0  37.13  40.6653   -1
# 2017-09-26     81486.5        0      0  37.57  39.7627   -1
# 2017-09-27     81486.5        0      0  39.54  38.3702   -1
# 2017-09-28        25.6     2085      1  39.07   37.842    1
# 2017-09-29        25.6     2085      0  39.18  38.4434    1
# 2017-10-02        25.6     2085      0  38.65  39.1309    1
# 2017-10-03     80047.9        0     -1  38.38  39.6404   -1
# 2017-10-04        7.98     2092      1  38.26   39.416    1
# 2017-10-05        7.98     2092      0   38.5  39.6635    1
# 2017-10-06        7.98     2092      0  38.49  40.5022    1
# 2017-10-09     77474.7        0     -1  37.03  40.8088   -1
# 2017-10-10     77474.7        0      0  36.97  40.1164   -1
# 2017-10-11     77474.7        0      0  37.07  38.0208   -1
# 2017-10-12     77474.7        0      0  37.72  36.8566   -1
# 2017-10-13        1.26     2042      1  37.94   36.803    1
# 2017-10-16        1.26     2042      0  36.72  37.3087    1
# 2017-10-17        1.26     2042      0  37.31  37.9437    1
# 2017-10-18        1.26     2042      0   38.6  37.9933    1
# 2017-10-19        1.26     2042      0  36.87  38.2066    1
# 2017-10-20        1.26     2042      0  36.72  38.8238    1
# 2017-10-23        1.26     2042      0  35.38  38.8305    1
# 2017-10-24     72553.5        0     -1  35.53  38.8636   -1
# 2017-10-25     72553.5        0      0  35.21   37.793   -1
# 2017-10-26     72553.5        0      0  36.22  36.0863   -1
# 2017-10-27       35.25     1969      1  36.83  35.3753    1
# 2017-10-30       35.25     1969      0  36.74  35.7988    1
# 2017-10-31       35.25     1969      0  37.12  36.7881    1
# 2017-11-01       35.25     1969      0  36.96  37.3667    1
# 2017-11-02     70387.6        0     -1  35.73  37.6821   -1
# 2017-11-03     70387.6        0      0  34.54  37.3706   -1
# 2017-11-06     70387.6        0      0   36.6  36.3481   -1
# 2017-11-07       12.16     1943      1  36.22  35.8273    1
# 2017-11-09       12.16     1943      0  41.29    36.81    1
# 2017-11-10       12.16     1943      0  40.27   37.207    1
# 2017-11-13       12.16     1943      0  38.95  39.5256    1
# 2017-11-14     72991.2        0     -1  37.56  40.2241   -1
# 2017-11-15     72991.2        0      0  37.85  40.0368   -1
# 2017-11-16     72991.2        0      0  37.64  38.6343   -1
# 2017-11-17       10.14     1910      1  38.21  37.2491    1
# 2017-11-20       10.14     1910      0   37.9  37.5439    1
# 2017-11-21       10.14     1910      0   40.1  38.4702    1
# 2017-11-22       10.14     1910      0  39.97   39.614    1
# 2017-11-24       10.14     1910      0  39.51  41.1414    1
# 2017-11-27     72781.1        0     -1   38.1  41.9517   -1
# 2017-11-28     72781.1        0      0  38.67  41.2881   -1
# 2017-11-29     72781.1        0      0  38.42   39.549   -1
# 2017-11-30     72781.1        0      0  37.74   38.934   -1
# 2017-12-01     72781.1        0      0  38.84  38.7253   -1
# 2017-12-04       17.62     1888      1  38.54  38.6248    1
# 2017-12-05       17.62     1888      0  36.87  39.9122    1
# 2017-12-06     66852.8        0     -1   35.4  41.1917   -1
# 2017-12-07     66852.8        0      0  36.23  39.9409   -1
# 2017-12-08     66852.8        0      0  38.91  38.2049   -1
# 2017-12-11       31.54     1752      1  38.14   35.156    1
# 2017-12-12       31.54     1752      0  39.16  36.0124    1
# 2017-12-13       31.54     1752      0  41.41  37.5754    1
# 2017-12-14       31.54     1752      0  40.78  39.6801    1
# 2017-12-15       31.54     1752      0  40.46  41.6006    1
# 2017-12-18     71951.1        0     -1  41.05  42.1161   -1
# 2017-12-19     71951.1        0      0  40.03  41.4591   -1
# 2017-12-20     71951.1        0      0  40.01  41.2547   -1
# 2017-12-21     71951.1        0      0  40.64  39.7302   -1
# 2017-12-22        2.42     1784      1  40.33  39.0982    1
# 2017-12-26        2.42     1784      0  40.05  39.8144    1
# 2017-12-27        2.42     1784      0  40.25  41.0461    1
# 2017-12-28        2.42     1784      0  40.15   41.372    1
# 2017-12-29        2.42     1784      0  39.94  41.5553    1
# 2018-01-02       73414        0     -1  41.15  41.7883   -1
# 2018-01-03       19.06     1766      1  41.56  41.2188    1
# 2018-01-04       19.06     1766      0  41.82  41.5382    1
# 2018-01-05       19.06     1766      0  42.23  42.7996    1
# 2018-01-08       19.06     1766      0  43.64  44.2773    1
# 2018-01-09     74862.1        0     -1  42.38   44.744   -1
# 2018-01-10     74862.1        0      0  41.85  44.1357   -1
# 2018-01-11     74862.1        0      0   43.9  43.4179   -1
# 2018-01-12     74862.1        0      0  49.76  42.4657   -1
# 2018-01-16       33.34     1580      1  47.36   42.166    1
# 2018-01-17       33.34     1580      0  46.82  45.3999    1
# 2018-01-18       33.34     1580      0  44.89  46.9862    1
# 2018-01-19     72065.5        0     -1  45.59   47.013   -1
# 2018-01-22     72065.5        0      0  45.35  46.2951   -1
# 2018-01-23     72065.5        0      0   44.9  46.1776   -1
# 2018-01-24       20.99     1665      1  43.27  46.0398    1
# 2018-01-25       73231        0     -1  43.97  46.0687   -1
# 2018-01-26       37.36     1624      1  45.07  45.7108    1
# 2018-01-29       37.36     1624      0  45.26  45.8826    1
# 2018-01-30       37.36     1624      0  44.31  46.7419    1
# 2018-01-31     70421.5        0     -1  43.34   47.417   -1
# 2018-02-01     70421.5        0      0  42.53  46.7571   -1
# 2018-02-02     70421.5        0      0  41.22  45.5249   -1
# 2018-02-05     70421.5        0      0  39.35  44.4571   -1
# 2018-02-06     70421.5        0      0  40.95  43.3718   -1
# 2018-02-07       24.52     1717      1     41  41.4943    1
# 2018-02-08       24.52     1717      0  43.92   42.193    1
# 2018-02-09       24.52     1717      0  44.09  43.4841    1
# 2018-02-12     76001.8        0     -1  44.25  44.6832   -1
# 2018-02-13     76001.8        0      0  44.07  42.5742   -1
# 2018-02-14       12.23     1637      1  46.42  42.2399    1
# 2018-02-15       12.23     1637      0  46.78   42.717    1
# 2018-02-16       12.23     1637      0  46.01  45.1232    1
# 2018-02-20       12.23     1637      0  46.45  46.4326    1
# 2018-02-21       12.23     1637      0  46.96   46.475    1
# 2018-02-22       12.23     1637      0   47.1  46.5335    1
# 2018-02-23       12.23     1637      0  46.59  47.4105    1
# 2018-02-26       78932        0     -1  48.21  47.7416   -1
# 2018-02-27       25.92     1676      1  47.08  47.0342    1
# 2018-02-28       25.92     1676      0  46.47  47.1082    1
# 2018-03-01       25.92     1676      0  45.51  47.2968    1
# 2018-03-02       25.92     1676      0  46.92  47.6235    1
# 2018-03-05       25.92     1676      0  48.08  47.7152    1
# 2018-03-06       25.92     1676      0  48.39  48.7783    1
# 2018-03-07       25.92     1676      0  48.15   50.621    1
# 2018-03-08     81362.2        0     -1  48.53  51.1022   -1
# 2018-03-09     81362.2        0      0  48.55  50.7686   -1
# 2018-03-12     81362.2        0      0  48.74  49.3495   -1
# 2018-03-13     81362.2        0      0  47.86  48.4797   -1
# 2018-03-14       14.08     1699      1  47.88   48.424    1
# 2018-03-15     81498.1        0     -1  47.96  48.5731   -1
# 2018-03-16     81498.1        0      0  47.82  48.0082   -1
# 2018-03-19       25.97     1739      1  46.85  47.7929    1
# 2018-03-20       82072        0     -1  47.18  48.3101   -1
# 2018-03-21       82072        0      0  47.59  48.3067   -1
# 2018-03-22       31.79     1780      1  46.09  48.2412    1
# 2018-03-23     79900.4        0     -1  44.87  48.4196   -1
# 2018-03-26     79900.4        0      0  47.09  48.1786   -1

# %%
# Compro a la alza y a la baja
# movimiento que se realizao en el dia = estado
# estado = 1 comprar, estado = 0 mantener, estado = -1 vender
movimientos_ab= pd.DataFrame(columns = ["presupuesto","acciones","acciones_debo","estado","valor","pred","dif"],index = index_time_t)
movimientos_ab.presupuesto[0] = 100000 % ytt.iloc[0,0] ; movimientos_ab.acciones[0] = 100000 // ytt.iloc[0,0] ; movimientos_ab.acciones_debo[0] = 0 ;
movimientos_ab.estado[0] = 0 ; movimientos_ab.valor[0] = ytt.iloc[0,0] ;
movimientos_ab.pred[0] = predicted_stock_price.iloc[0,0] 

for i in range(1,len(diferencias)):
    if diferencias[i] == 1:
        if movimientos_ab.acciones[i-1] == 0:
            movimientos_ab.estado[i] = 1
            movimientos_ab.presupuesto[i] = ((movimientos_ab.presupuesto[i-1] - (movimientos_ab.acciones_debo[i-1] * ytt.iloc[i,0]))
                                         % ytt.iloc[i,0])
            movimientos_ab.acciones[i] = ((movimientos_ab.presupuesto[i-1] - (movimientos_ab.acciones_debo[i-1] * ytt.iloc[i,0]))
                                         // ytt.iloc[i,0])
            movimientos_ab.acciones_debo[i] = 0
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
        else:
            movimientos_ab.estado[i] = 0
            movimientos_ab.presupuesto[i] = movimientos_ab.presupuesto[i-1]
            movimientos_ab.acciones[i] = movimientos_ab.acciones[i-1]
            movimientos_ab.acciones_debo[i] = movimientos_ab.acciones_debo[i-1]
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
    elif diferencias[i] == 0:
            movimientos_ab.estado[i] = 0
            movimientos_ab.presupuesto[i] = movimientos_ab.presupuesto[i-1]
            movimientos_ab.acciones[i] = movimientos_ab.acciones[i-1]
            movimientos_ab.acciones_debo[i] = movimientos_ab.acciones_debo[i-1]
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
    elif diferencias[i] == -1:
        if movimientos_ab.acciones_debo[i-1] == 0:
            movimientos_ab.estado[i] = -1
            movimientos_ab.presupuesto[i] = ((movimientos_ab.presupuesto[i-1] + movimientos_ab.acciones[i-1] * ytt.iloc[i,0]) +
                                          ((movimientos_ab.presupuesto[i-1] + movimientos_ab.acciones[i-1] * ytt.iloc[i,0]) //
                                           ytt.iloc[i,0]) * ytt.iloc[i,0])
            movimientos_ab.acciones[i] = 0
            movimientos_ab.acciones_debo[i] = ((movimientos_ab.presupuesto[i-1] + movimientos_ab.acciones[i-1] * ytt.iloc[i,0]) //
                                           ytt.iloc[i,0]) # Las pido prestadas
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
        else:
            movimientos_ab.estado[i] = 0
            movimientos_ab.presupuesto[i] = movimientos_ab.presupuesto[i-1]
            movimientos_ab.acciones[i] = movimientos_ab.acciones[i-1]
            movimientos_ab.acciones_debo[i] = movimientos_ab.acciones_debo[i-1]
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
            
movimientos_ab = movimientos_ab.drop(movimientos_ab.tail(1).index)
print(movimientos_ab.tail(1))
if movimientos_ab.acciones_debo[len(movimientos_ab)-1] == 0 :
    valor_f_ab = movimientos_ab.presupuesto[len(movimientos_ab)-1] + movimientos_ab.valor[len(movimientos_ab)-1] * movimientos_ab.acciones[len(movimientos_ab)-1]
else:
    valor_f_ab = movimientos_ab.presupuesto[len(movimientos_ab)-1] - movimientos_ab.valor[len(movimientos_ab)-1] * movimientos_ab.acciones_debo[len(movimientos_ab)-1]
ganancia_ab = valor_f_ab - 100000
print('Valor Final = %.2f' % valor_f_ab)
print('Ganancia con margen = %.2f' % ganancia_ab)
# Out:
#            presupuesto acciones acciones_debo estado valor     pred dif
# 2018-03-26      189252        0         12500      0  6.94  7.09273  -1
# Valor Final = 102502.23
# Ganancia con margen = 2502.23

# %%
print(movimientos_ab)

# %%
# Compro a la baja
# movimiento que se realizao en el dia = estado
# estado = 1 comprar, estado = 0 mantener, estado = -1 vender
movimientos_baja = pd.DataFrame(columns = ["presupuesto","acciones","acciones_debo","estado","valor","pred","dif"],index = index_time_t)
movimientos_baja.presupuesto[0] = 100000  ; movimientos_baja.acciones[0] = 0 ; movimientos_baja.acciones_debo[0] = 0 ;
movimientos_baja.estado[0] = 0 ; movimientos_baja.valor[0] = ytt.iloc[0,0] ;
movimientos_baja.pred[0] = predicted_stock_price.iloc[0,0] 

for i in range(1,len(diferencias)):
    if diferencias[i] == 1:
        if movimientos_baja.acciones[i-1] == 0:
            movimientos_baja.estado[i] = 1
            movimientos_baja.presupuesto[i] = ((movimientos_baja.presupuesto[i-1] - (movimientos_baja.acciones_debo[i-1] * ytt.iloc[i,0])))
            movimientos_baja.acciones[i] = 0
            movimientos_baja.acciones_debo[i] = 0
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
        else:
            movimientos_baja.estado[i] = 0
            movimientos_baja.presupuesto[i] = movimientos_baja.presupuesto[i-1]
            movimientos_baja.acciones[i] = movimientos_baja.acciones[i-1]
            movimientos_baja.acciones_debo[i] = movimientos_baja.acciones_debo[i-1]
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
    elif diferencias[i] == 0:
            movimientos_baja.estado[i] = 0
            movimientos_baja.presupuesto[i] = movimientos_baja.presupuesto[i-1]
            movimientos_baja.acciones[i] = movimientos_baja.acciones[i-1]
            movimientos_baja.acciones_debo[i] = movimientos_baja.acciones_debo[i-1]
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
    elif diferencias[i] == -1:
        if movimientos_baja.acciones_debo[i-1] == 0:
            movimientos_baja.estado[i] = -1
            movimientos_baja.presupuesto[i] = ((movimientos_baja.presupuesto[i-1]) + (movimientos_baja.presupuesto[i-1] //
                                           ytt.iloc[i,0]) * ytt.iloc[i,0])
            movimientos_baja.acciones[i] = 0
            movimientos_baja.acciones_debo[i] = (movimientos_baja.presupuesto[i-1] // ytt.iloc[i,0]) # Las pido prestadas
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
        else:
            movimientos_baja.estado[i] = 0
            movimientos_baja.presupuesto[i] = movimientos_baja.presupuesto[i-1]
            movimientos_baja.acciones[i] = movimientos_baja.acciones[i-1]
            movimientos_baja.acciones_debo[i] = movimientos_baja.acciones_debo[i-1]
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
            
movimientos_baja = movimientos_baja.drop(movimientos_baja.tail(1).index)
print(movimientos_baja.tail(1))
if movimientos_baja.acciones_debo[len(movimientos_baja)-1] == 0 :
    valor_f_baja = movimientos_baja.presupuesto[len(movimientos_baja)-1] + movimientos_baja.valor[len(movimientos_baja)-1] * movimientos_baja.acciones[len(movimientos_baja)-1]
else:
    valor_f_baja = movimientos_baja.presupuesto[len(movimientos_baja)-1] - movimientos_baja.valor[len(movimientos_baja)-1] * movimientos_baja.acciones_debo[len(movimientos_baja)-1]
ganancia_baja = valor_f_baja - 100000
print('Valor Final = %.2f' % valor_f_baja)
print('Ganancia con margen = %.2f' % ganancia_baja)
# Out:
#            presupuesto acciones acciones_debo estado valor     pred dif
# 2018-03-26     79243.9        0          5234      0  6.94  7.09273  -1
# Valor Final = 42919.93
# Ganancia con margen = -57080.07

# %%
print(movimientos_baja)
