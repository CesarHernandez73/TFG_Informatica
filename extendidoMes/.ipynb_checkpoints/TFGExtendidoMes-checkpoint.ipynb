# %% [markdown]
# ### TFG - Cesar Hernandez Rodriguez
# TFG - Extendido con prediccion basada con los datos de mes en mes, en este script se encuentran todos los datos del indice Nasdaq de los cuales solo se hace una seleccion aleatoria de 15 (valor k dentro del script) y se procede a la prediccion de uno de esos valores con una red LSTM de 4 neuronas en la primera capa y 2 en la segunda.
#
# Solo se realiza una red LSTM, pudiendo cambiarse por cualquier otra de las que se exponen en la carpeta TFG.
#
# Este script se basa en descargar datos de la bolsa de EEUU, exactamente todos los del índice Nasdaq que es uno de los índices más importantes de Estados Unidos, siendo la segunda bolsa de valores automatizada y electronica mas grande del mundo con 3800 compañias. (https://es.wikipedia.org/wiki/NASDAQ)
#
# Para ello usaré la librería QUANDL (https://www.quandl.com/tools/python) que implementa una API para poder descargar los datos de manera sencilla.
#
# El primer paso es coger los activos que tenemos ya que al ser una API de caracter gratuito no disponemos ni los datos de todos los activos ni estan actulaizados por lo que hacemos un filtrado con los 2 .csv que estan en la misma carpeta
#
# A mayores una vez descagardo los datos (ya que tarda mucho) los voy a guardar dentro de mi ordenador serializandolo con el paquete Pickle (http://pyspanishdoc.sourceforge.net/lib/module-pickle.html)
#
# A la hora de realizar el modelo creo 3 atributos, 2 medias moviles una de 10 dias y otra de 20 dias y un oscilador de la media movil de 20 dias.
#
# Depues de realizar el modelo la idea de la practica es realizar una prueba real, por ello me fio del modelo que he obtenido e imaginando una inversion inical de 100000 euros dejo que la red neuronal haga lo que deba con ese dinero, decidiendo si quiere comprar, vender o mantener. Hay 3 formas programadas, compra a la alza, compra a la alza y a la baja y compra a la baja.

# %%
# Import predefinifods
import pandas as pd
import numpy as np
import random
from math import *
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from time import time
import matplotlib.pyplot as plt
from collections import Counter

# Importa descaga de datos
import quandl

# Import serializar
import pickle

# Import red Neuronal
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
import keras.backend as K

# Conteo
from collections import Counter

# Graficos
#plt.style.use('fivethirtyeight')
#plt.style.use('dark_background')
plt.style.use('seaborn')

# %%
# Descarga de las bases los tickets de los activos que vamos a predecir con los csv de la carpeta
def get_tickers_sample_nasdaq():
    tickers_wiki_quandl = pd.read_csv('WIKI_PRICES.csv')['ticker']
    tickers_nasdaq = pd.read_csv('nasdaq-listed-symbols.csv')['Symbol']
    
    tickersQuandl = []    
    tickers = []
    for i in range(len(tickers_nasdaq)):
        word = tickers_nasdaq[i]
        for j in range(len(tickers_wiki_quandl)):
            if word == tickers_wiki_quandl[j]:
                tickers.append(word)
    # Con el k seleccionas cuantos activos quieres
    tickers = random.choices(tickers, k=15)
    
    for tick in tickers:
        tickersQuandl.append("WIKI/"+tick)
    
    return tickers, tickersQuandl

# a,b = get_tickers_sample_nasdaq()

# %%
# Descargo de los datos con la API Quandl y la key propia
# Las fechas estan elegidas a convinencia para poder concatenar las fechas y que quede de seguido
def get_data(verbose):
    quandl.ApiConfig.api_key = 'WgQVD8Npfox1MN7SV3Nm'
    tickers, tickersQuandl = get_tickers_sample_nasdaq()
    
    if verbose: print(" ****Empezamos a descargar los datos****\n")
    
    datos = {}
    start_time = time()
    long = len(tickersQuandl)
    i = 0
    for ticker in tickersQuandl:
        if i % 2 == 0 and verbose: print("LLeva descargados el ",i/long *100,"% de los datos")
        aux=quandl.get(ticker,start_date="2010-01-01",end_date="2016-12-31")
        datos[ticker[5:len(ticker)]] = aux
        i = i + 1
    
    datosClose = {}
    for key in datos:
        datosClose[key] = datos[key]["Adj. Close"]
    
    elapsed_time = time() - start_time
    if verbose: print("\nHa tardado en descargar los datos: %0.10f segundos." % elapsed_time)
    
    if verbose: print("\n ****Empezamos a descargar los datos test****\n")
    
    # Procedo a hacer las mismas operaciones para el conjunto TEST
    datos_test = {}
    i = 0
    long = len(tickersQuandl)
    start_time = time()    
    for ticker in tickersQuandl:
        if i % 2 == 0 and verbose: print("LLeva descargados el ",i/long *100,"% de los datos test")
        aux=quandl.get(ticker,start_date="2016-10-30",end_date="2020-12-31")
        datos_test[ticker[5:len(ticker)]] = aux
        i = i + 1
    
    datosClose_test = {}
    for key in datos_test:
        datosClose_test[key] = datos_test[key]["Adj. Close"]
    
        elapsed_time = time() - start_time
    if verbose: print("\nHa tardado en descargar los datos test: %0.10f segundos." % elapsed_time)
    if verbose: print("\n")
    
    # Solo cogemos los datos que nos da la aplicacion
    # ya que hay activos que no tenemos su valor en esas fechas o tenemos muy pocos datos

    quitar = []
    for key in tickers:
        if datosClose_test[key].empty:
            if verbose == True : print("Restriccion de vacio",key) 
            datos.pop(key,None)
            datosClose.pop(key,None)
            datos_test.pop(key,None)
            datosClose_test.pop(key,None)
            quitar.append(key)
        elif len(datosClose_test[key]) < 300:
            if verbose == True :  print("Restriccion de longitud",key)
            datos.pop(key,None)
            datosClose.pop(key,None)
            datos_test.pop(key,None)
            datosClose_test.pop(key,None)
            quitar.append(key)
            
    for key in quitar:
        tickers.remove(key)
    
    # Guardamos los datos y serializamos
    pickle.dump(tickers, open("datos/tickers_nasdaq.p", "wb"))
    pickle.dump(tickersQuandl, open("datos/tickersQuandl_nasdaq.p", "wb"))
    pickle.dump(datos, open("datos/nasdaq.p", "wb"))
    pickle.dump(datosClose, open("datos/nasdaqClose.p", "wb"))
    pickle.dump(datos_test, open("datos/nasdaq_test.p", "wb"))
    pickle.dump(datosClose_test, open("datos/nasdaqClose_test.p", "wb"))
    
    return tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test

# %%
# Si los datos ya han sido descargados con esta funcion los cargo gracias a la libreria pickles
def get_data_load(verbose):
    if verbose: print(" ****Empezamos a cargar los datos****\n")
    tickers = pickle.load(open("datos/tickers_nasdaq.p", "rb" ))
    tickersQuandl = pickle.load(open("datos/tickersQuandl_nasdaq.p", "rb" ))
    datos = pickle.load(open("datos/nasdaq.p", "rb" ))
    datosClose = pickle.load(open("datos/nasdaqClose.p", "rb" ))
    if verbose: print(" ****Cargados los datos****\n")
    
    if verbose: print("\n ****Empezamos a cargar los datos test****\n")
    datos_test = pickle.load(open("datos/nasdaq_test.p", "rb" ))
    datosClose_test = pickle.load(open("datos/nasdaqClose_test.p", "rb" ))
    if verbose: print(" ****Cargados los datos test****\n")
    
    return tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test

# Para imprimir cualquier conjunto tipo Serie temporal del conjunto de datos base uso esta funcion
def plot_datos(datosClose,nombre,test):
    datosClose[nombre].plot(figsize=(12,5),grid=True)
    plt.title('{} {}\n'.format(nombre,test))
    plt.ylabel('Precio de Cierre')
    plt.xlabel('Fecha')
    plt.show()

# %%
datos_descargados = True
if datos_descargados:
    tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test= get_data_load(True)
else : 
    tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test = get_data(True)
# Out:
#  ****Empezamos a cargar los datos****
#
#  ****Cargados los datos****
#
#
#  ****Empezamos a cargar los datos test****
#
#  ****Cargados los datos test****

# %%
# Grafico un activo aleatorio que luego predecire
# Se tiene el gráfico con el que se creara el modelo y los datos sobre los que se va a testear
ran = random.randint(0,len(tickers)-1)
plot_datos(datosClose,tickers[ran],"train")
plot_datos(datosClose_test,tickers[ran],"test")

# %%
# Creacion de los atributos para la Red Neuronal Recurrente
def differences(x):
    return x[-1] - x[0]

def create_features(datosClose,days1,days2):
    X = pd.DataFrame()
    data = pd.DataFrame()
    data['Adj. Close'] = datosClose.values
    
    indices = datosClose.index
    
    X['MA_{}'.format(days1)] = data['Adj. Close'].rolling(window=days1).mean()
    X['MA_{}'.format(days2)] = data['Adj. Close'].rolling(window=days2).mean()
    X['Diferencia'] = data['Adj. Close'].rolling(window=days2).apply(differences,raw=True) 
    X = X[days2:len(X)-1].reset_index()
    X.drop(['index'], axis='columns', inplace=True)

    return X, indices[(days2+1):len(indices)]

# Creo tambien timestep de 30 dias (igual que la media movil) para la RED NEURONAL
def cut_timestep(x,y,time):
    
    Xt = []
    yt = []
    index_time = []

    for i in range(timeStep, len(x)):
        Xt.append(x[i-timeStep:i,:])
        yt.append(y.iloc[i,0])
        index_time.append(time[i])

    return np.array(Xt), np.array(yt), pd.Series(index_time)

# %%
# A parte de la creacion de atributos
index = ran
timeStep = 21 # longitud de secuencias que se hacen en cada iteracion de la red

# Extraigo los atributos de los datos y los preparo para meterlos a la red neuronal

X, ind_time = create_features(datosClose[tickers[index]],10,20)
Y = pd.DataFrame(datosClose[tickers[index]].values[21:len(datosClose[tickers[index]])])
X = X.to_numpy()

# Creamos los atributos para los datos test
ticket_uso = tickers[index]
Xtesteo, ind_time_t = create_features(datosClose_test[tickers[index]],10,20)
Ytesteo = pd.DataFrame(datosClose_test[tickers[index]].values[21:len(datosClose_test[tickers[index]])])
Xtesteo = Xtesteo.to_numpy()

X_aux = np.concatenate((X,Xtesteo),axis=0)

scaler = MinMaxScaler()
X_aux_scaled = scaler.fit_transform(X_aux)
X_scaled = X_aux_scaled[0:len(X)]
Xtesteo_scaled = X_aux_scaled[len(X):len(X_aux_scaled)]

# Creacion de los timestep
Xt, yt, index_time = cut_timestep(X_scaled,Y,ind_time)
Xtt, ytt, index_time_t = cut_timestep(Xtesteo_scaled,Ytesteo,ind_time_t)

# Split de en conjunto de prueba y entrenamiento para la red neuronal
P=yt.shape[0]
indices=np.arange(P,dtype=int)
np.random.shuffle(indices)
sequences_train=indices[0:int(P*2/3)]
sequences_test=indices[int(P*2/3):]
X_train, X_test, y_train, y_test = Xt[sequences_train],Xt[sequences_test],yt[sequences_train],yt[sequences_test]


print("Voy a predecir el activo ",ticket_uso)
# Out:
# Voy a predecir el activo  BBOX

# %%
# Calculates a successfull ratio using less relative error than a maximum
def porcentaje_margen(y_true, y_pred):
    margen = 0.05
    yy = K.sum(K.cast(K.less(K.abs((y_pred/y_true)-1.0), margen), dtype=float))
    return yy/K.cast(K.shape(y_pred)[0], dtype=float)

# %%
# Creacion de la red neural LSTM

model42 = Sequential()
model42.add(LSTM(4, input_shape=(21,3),return_sequences=True))
model42.add(LSTM(units = 2,return_sequences = False))
model42.add(Dense(1)) 
model42.compile(optimizer="adam",loss='mse',metrics=[porcentaje_margen]) 
model42.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 21, 4)             128
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 2)                 56
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 187
# Trainable params: 187
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_LSTM42 = model42.fit(X_train,
                  y_train,
                  epochs=1500,
                  verbose=1,
                  validation_data=(X_test,y_test))
# Out:
# Train on 1146 samples, validate on 574 samples
# Epoch 1/1500
# 1146/1146 [==============================] - 2s 2ms/step - loss: 473.0688 - porcentaje_margen: 0.0000e+00 - val_loss: 476.8997 - val_porcentaje_margen: 0.0000e+00
# Epoch 2/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 453.4824 - porcentaje_margen: 0.0000e+00 - val_loss: 456.8821 - val_porcentaje_margen: 0.0000e+00
# Epoch 3/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 437.9265 - porcentaje_margen: 0.0000e+00 - val_loss: 445.5229 - val_porcentaje_margen: 0.0000e+00
# Epoch 4/1500
# 1146/1146 [==============================] - 1s 989us/step - loss: 428.3742 - porcentaje_margen: 0.0000e+00 - val_loss: 436.9859 - val_porcentaje_margen: 0.0000e+00
# Epoch 5/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 420.4948 - porcentaje_margen: 0.0000e+00 - val_loss: 429.4448 - val_porcentaje_margen: 0.0000e+00
# Epoch 6/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 413.4585 - porcentaje_margen: 0.0000e+00 - val_loss: 422.6179 - val_porcentaje_margen: 0.0000e+00
# Epoch 7/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 407.0161 - porcentaje_margen: 0.0000e+00 - val_loss: 416.3703 - val_porcentaje_margen: 0.0000e+00
# Epoch 8/1500
# 1146/1146 [==============================] - 1s 982us/step - loss: 401.0632 - porcentaje_margen: 0.0000e+00 - val_loss: 410.4805 - val_porcentaje_margen: 0.0000e+00
# Epoch 9/1500
# 1146/1146 [==============================] - 1s 952us/step - loss: 395.4323 - porcentaje_margen: 0.0000e+00 - val_loss: 404.8823 - val_porcentaje_margen: 0.0000e+00
# Epoch 10/1500
# 1146/1146 [==============================] - 1s 998us/step - loss: 390.0244 - porcentaje_margen: 0.0000e+00 - val_loss: 399.4945 - val_porcentaje_margen: 0.0000e+00
# Epoch 11/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 384.7636 - porcentaje_margen: 0.0000e+00 - val_loss: 394.1670 - val_porcentaje_margen: 0.0000e+00
# Epoch 12/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 379.6070 - porcentaje_margen: 0.0000e+00 - val_loss: 389.0386 - val_porcentaje_margen: 0.0000e+00
# Epoch 13/1500
# 1146/1146 [==============================] - 1s 975us/step - loss: 374.7053 - porcentaje_margen: 0.0000e+00 - val_loss: 384.1923 - val_porcentaje_margen: 0.0000e+00
# Epoch 14/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 370.0604 - porcentaje_margen: 0.0000e+00 - val_loss: 379.5719 - val_porcentaje_margen: 0.0000e+00
# Epoch 15/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 365.5977 - porcentaje_margen: 0.0000e+00 - val_loss: 375.1220 - val_porcentaje_margen: 0.0000e+00
# Epoch 16/1500
# 1146/1146 [==============================] - 1s 990us/step - loss: 361.2816 - porcentaje_margen: 0.0000e+00 - val_loss: 370.7672 - val_porcentaje_margen: 0.0000e+00
# Epoch 17/1500
# 1146/1146 [==============================] - 1s 995us/step - loss: 357.0646 - porcentaje_margen: 0.0000e+00 - val_loss: 366.5359 - val_porcentaje_margen: 0.0000e+00
# Epoch 18/1500
# 1146/1146 [==============================] - 1s 912us/step - loss: 352.9498 - porcentaje_margen: 0.0000e+00 - val_loss: 362.3718 - val_porcentaje_margen: 0.0000e+00
# Epoch 19/1500
# 1146/1146 [==============================] - 1s 986us/step - loss: 348.9038 - porcentaje_margen: 0.0000e+00 - val_loss: 358.3058 - val_porcentaje_margen: 0.0000e+00
# Epoch 20/1500
# 1146/1146 [==============================] - 1s 940us/step - loss: 344.9389 - porcentaje_margen: 0.0000e+00 - val_loss: 354.2886 - val_porcentaje_margen: 0.0000e+00
# Epoch 21/1500
# 1146/1146 [==============================] - 1s 909us/step - loss: 341.0264 - porcentaje_margen: 0.0000e+00 - val_loss: 350.3476 - val_porcentaje_margen: 0.0000e+00
# Epoch 22/1500
# 1146/1146 [==============================] - 1s 870us/step - loss: 337.1869 - porcentaje_margen: 0.0000e+00 - val_loss: 346.4396 - val_porcentaje_margen: 0.0000e+00
# Epoch 23/1500
# 1146/1146 [==============================] - 1s 896us/step - loss: 333.3890 - porcentaje_margen: 0.0000e+00 - val_loss: 342.6046 - val_porcentaje_margen: 0.0000e+00
# Epoch 24/1500
# 1146/1146 [==============================] - 1s 913us/step - loss: 329.6417 - porcentaje_margen: 0.0000e+00 - val_loss: 338.8307 - val_porcentaje_margen: 0.0000e+00
# Epoch 25/1500
# 1146/1146 [==============================] - 1s 900us/step - loss: 325.9515 - porcentaje_margen: 0.0000e+00 - val_loss: 335.0883 - val_porcentaje_margen: 0.0000e+00
# Epoch 26/1500
# 1146/1146 [==============================] - 1s 946us/step - loss: 322.3052 - porcentaje_margen: 0.0000e+00 - val_loss: 331.3813 - val_porcentaje_margen: 0.0000e+00
# Epoch 27/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 318.7002 - porcentaje_margen: 0.0000e+00 - val_loss: 327.7219 - val_porcentaje_margen: 0.0000e+00
# Epoch 28/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 315.1323 - porcentaje_margen: 0.0000e+00 - val_loss: 324.1221 - val_porcentaje_margen: 0.0000e+00
# Epoch 29/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 311.6118 - porcentaje_margen: 0.0000e+00 - val_loss: 320.5494 - val_porcentaje_margen: 0.0000e+00
# Epoch 30/1500
# 1146/1146 [==============================] - 1s 949us/step - loss: 308.1325 - porcentaje_margen: 0.0000e+00 - val_loss: 316.9990 - val_porcentaje_margen: 0.0000e+00
# Epoch 31/1500
# 1146/1146 [==============================] - 1s 896us/step - loss: 304.6779 - porcentaje_margen: 0.0000e+00 - val_loss: 313.5255 - val_porcentaje_margen: 0.0000e+00
# Epoch 32/1500
# 1146/1146 [==============================] - 1s 917us/step - loss: 301.2808 - porcentaje_margen: 0.0000e+00 - val_loss: 310.0437 - val_porcentaje_margen: 0.0000e+00
# Epoch 33/1500
# 1146/1146 [==============================] - 1s 866us/step - loss: 297.9049 - porcentaje_margen: 0.0000e+00 - val_loss: 306.6153 - val_porcentaje_margen: 0.0000e+00
# Epoch 34/1500
# 1146/1146 [==============================] - 1s 905us/step - loss: 294.5596 - porcentaje_margen: 0.0000e+00 - val_loss: 303.2520 - val_porcentaje_margen: 0.0000e+00
# Epoch 35/1500
# 1146/1146 [==============================] - 1s 901us/step - loss: 291.2668 - porcentaje_margen: 0.0000e+00 - val_loss: 299.8814 - val_porcentaje_margen: 0.0000e+00
# Epoch 36/1500
# 1146/1146 [==============================] - 1s 908us/step - loss: 287.9907 - porcentaje_margen: 0.0000e+00 - val_loss: 296.5662 - val_porcentaje_margen: 0.0000e+00
# Epoch 37/1500
# 1146/1146 [==============================] - 1s 913us/step - loss: 284.7584 - porcentaje_margen: 0.0000e+00 - val_loss: 293.2738 - val_porcentaje_margen: 0.0000e+00
# Epoch 38/1500
# 1146/1146 [==============================] - 1s 902us/step - loss: 281.5514 - porcentaje_margen: 0.0000e+00 - val_loss: 290.0300 - val_porcentaje_margen: 0.0000e+00
# Epoch 39/1500
# 1146/1146 [==============================] - 1s 927us/step - loss: 278.3809 - porcentaje_margen: 0.0000e+00 - val_loss: 286.8115 - val_porcentaje_margen: 0.0000e+00
# Epoch 40/1500
# 1146/1146 [==============================] - 1s 968us/step - loss: 275.2427 - porcentaje_margen: 0.0000e+00 - val_loss: 283.6130 - val_porcentaje_margen: 0.0000e+00
# Epoch 41/1500
# 1146/1146 [==============================] - 1s 947us/step - loss: 272.1302 - porcentaje_margen: 0.0000e+00 - val_loss: 280.4450 - val_porcentaje_margen: 0.0000e+00
# Epoch 42/1500
# 1146/1146 [==============================] - 1s 927us/step - loss: 269.0457 - porcentaje_margen: 0.0000e+00 - val_loss: 277.3185 - val_porcentaje_margen: 0.0000e+00
# Epoch 43/1500
# 1146/1146 [==============================] - 1s 923us/step - loss: 266.0005 - porcentaje_margen: 0.0000e+00 - val_loss: 274.2054 - val_porcentaje_margen: 0.0000e+00
# Epoch 44/1500
# 1146/1146 [==============================] - 1s 958us/step - loss: 262.9774 - porcentaje_margen: 8.6806e-04 - val_loss: 271.1317 - val_porcentaje_margen: 0.0000e+00
# Epoch 45/1500
# 1146/1146 [==============================] - 1s 908us/step - loss: 259.9794 - porcentaje_margen: 0.0017 - val_loss: 268.1060 - val_porcentaje_margen: 0.0000e+00
# Epoch 46/1500
# 1146/1146 [==============================] - 1s 898us/step - loss: 257.0210 - porcentaje_margen: 0.0017 - val_loss: 265.0885 - val_porcentaje_margen: 0.0000e+00
# Epoch 47/1500
# 1146/1146 [==============================] - 1s 919us/step - loss: 254.0867 - porcentaje_margen: 0.0028 - val_loss: 262.0966 - val_porcentaje_margen: 0.0000e+00
# Epoch 48/1500
# 1146/1146 [==============================] - 1s 896us/step - loss: 251.1813 - porcentaje_margen: 0.0035 - val_loss: 259.1230 - val_porcentaje_margen: 0.0000e+00
# Epoch 49/1500
# 1146/1146 [==============================] - 1s 882us/step - loss: 248.2952 - porcentaje_margen: 0.0043 - val_loss: 256.2022 - val_porcentaje_margen: 0.0052
# Epoch 50/1500
# 1146/1146 [==============================] - 1s 917us/step - loss: 245.4442 - porcentaje_margen: 0.0063 - val_loss: 253.2936 - val_porcentaje_margen: 0.0069
# Epoch 51/1500
# 1146/1146 [==============================] - 1s 892us/step - loss: 242.6183 - porcentaje_margen: 0.0061 - val_loss: 250.4176 - val_porcentaje_margen: 0.0087
# Epoch 52/1500
# 1146/1146 [==============================] - 1s 885us/step - loss: 239.8207 - porcentaje_margen: 0.0078 - val_loss: 247.5636 - val_porcentaje_margen: 0.0087
# Epoch 53/1500
# 1146/1146 [==============================] - 1s 912us/step - loss: 237.0437 - porcentaje_margen: 0.0078 - val_loss: 244.7498 - val_porcentaje_margen: 0.0087
# Epoch 54/1500
# 1146/1146 [==============================] - 1s 954us/step - loss: 234.3034 - porcentaje_margen: 0.0069 - val_loss: 241.9356 - val_porcentaje_margen: 0.0087
# Epoch 55/1500
# 1146/1146 [==============================] - 1s 923us/step - loss: 231.5761 - porcentaje_margen: 0.0087 - val_loss: 239.1701 - val_porcentaje_margen: 0.0087
# Epoch 56/1500
# 1146/1146 [==============================] - 1s 934us/step - loss: 228.8817 - porcentaje_margen: 0.0078 - val_loss: 236.4235 - val_porcentaje_margen: 0.0069
# Epoch 57/1500
# 1146/1146 [==============================] - 1s 906us/step - loss: 226.2115 - porcentaje_margen: 0.0069 - val_loss: 233.7091 - val_porcentaje_margen: 0.0069
# Epoch 58/1500
# 1146/1146 [==============================] - 1s 947us/step - loss: 223.5682 - porcentaje_margen: 0.0069 - val_loss: 231.0125 - val_porcentaje_margen: 0.0069
# Epoch 59/1500
# 1146/1146 [==============================] - 1s 891us/step - loss: 220.9495 - porcentaje_margen: 0.0045 - val_loss: 228.3311 - val_porcentaje_margen: 0.0069
# Epoch 60/1500
# 1146/1146 [==============================] - 1s 901us/step - loss: 218.3494 - porcentaje_margen: 0.0043 - val_loss: 225.6952 - val_porcentaje_margen: 0.0069
# Epoch 61/1500
# 1146/1146 [==============================] - 1s 895us/step - loss: 215.7811 - porcentaje_margen: 0.0052 - val_loss: 223.0737 - val_porcentaje_margen: 0.0069
# Epoch 62/1500
# 1146/1146 [==============================] - 1s 885us/step - loss: 213.2331 - porcentaje_margen: 0.0052 - val_loss: 220.4804 - val_porcentaje_margen: 0.0087
# Epoch 63/1500
# 1146/1146 [==============================] - 1s 869us/step - loss: 210.7097 - porcentaje_margen: 0.0043 - val_loss: 217.9041 - val_porcentaje_margen: 0.0087
# Epoch 64/1500
# 1146/1146 [==============================] - 1s 941us/step - loss: 208.2133 - porcentaje_margen: 0.0035 - val_loss: 215.3440 - val_porcentaje_margen: 0.0069
# Epoch 65/1500
# 1146/1146 [==============================] - 1s 899us/step - loss: 205.7337 - porcentaje_margen: 0.0026 - val_loss: 212.8243 - val_porcentaje_margen: 0.0087
# Epoch 66/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 203.2827 - porcentaje_margen: 0.0043 - val_loss: 210.3207 - val_porcentaje_margen: 0.0087
# Epoch 67/1500
# 1146/1146 [==============================] - 1s 938us/step - loss: 200.8548 - porcentaje_margen: 0.0052 - val_loss: 207.8355 - val_porcentaje_margen: 0.0069
# Epoch 68/1500
# 1146/1146 [==============================] - 1s 870us/step - loss: 198.4476 - porcentaje_margen: 0.0069 - val_loss: 205.3736 - val_porcentaje_margen: 0.0069
# Epoch 69/1500
# 1146/1146 [==============================] - 1s 908us/step - loss: 196.0583 - porcentaje_margen: 0.0078 - val_loss: 202.9545 - val_porcentaje_margen: 0.0087
# Epoch 70/1500
# 1146/1146 [==============================] - 1s 889us/step - loss: 193.7081 - porcentaje_margen: 0.0078 - val_loss: 200.5199 - val_porcentaje_margen: 0.0087
# Epoch 71/1500
# 1146/1146 [==============================] - 1s 889us/step - loss: 191.3626 - porcentaje_margen: 0.0087 - val_loss: 198.1405 - val_porcentaje_margen: 0.0069
# Epoch 72/1500
# 1146/1146 [==============================] - 1s 921us/step - loss: 189.0486 - porcentaje_margen: 0.0087 - val_loss: 195.7760 - val_porcentaje_margen: 0.0087
# Epoch 73/1500
# 1146/1146 [==============================] - 1s 918us/step - loss: 186.7569 - porcentaje_margen: 0.0087 - val_loss: 193.4292 - val_porcentaje_margen: 0.0069
# Epoch 74/1500
# 1146/1146 [==============================] - 1s 926us/step - loss: 184.4826 - porcentaje_margen: 0.0097 - val_loss: 191.1238 - val_porcentaje_margen: 0.0052
# Epoch 75/1500
# 1146/1146 [==============================] - 1s 921us/step - loss: 182.2385 - porcentaje_margen: 0.0095 - val_loss: 188.8241 - val_porcentaje_margen: 0.0035
# Epoch 76/1500
# 1146/1146 [==============================] - 1s 903us/step - loss: 180.0141 - porcentaje_margen: 0.0069 - val_loss: 186.5367 - val_porcentaje_margen: 0.0035
# Epoch 77/1500
# 1146/1146 [==============================] - 1s 907us/step - loss: 177.8045 - porcentaje_margen: 0.0061 - val_loss: 184.2913 - val_porcentaje_margen: 0.0052
# Epoch 78/1500
# 1146/1146 [==============================] - 1s 877us/step - loss: 175.6267 - porcentaje_margen: 0.0063 - val_loss: 182.0483 - val_porcentaje_margen: 0.0052
# Epoch 79/1500
# 1146/1146 [==============================] - 1s 935us/step - loss: 173.4634 - porcentaje_margen: 0.0035 - val_loss: 179.8290 - val_porcentaje_margen: 0.0035
# Epoch 80/1500
# 1146/1146 [==============================] - 1s 916us/step - loss: 171.3158 - porcentaje_margen: 0.0026 - val_loss: 177.6567 - val_porcentaje_margen: 0.0035
# Epoch 81/1500
# 1146/1146 [==============================] - 1s 930us/step - loss: 169.2035 - porcentaje_margen: 0.0026 - val_loss: 175.4768 - val_porcentaje_margen: 0.0035
# Epoch 82/1500
# 1146/1146 [==============================] - 1s 865us/step - loss: 167.1060 - porcentaje_margen: 0.0043 - val_loss: 173.3222 - val_porcentaje_margen: 0.0017
# Epoch 83/1500
# 1146/1146 [==============================] - 1s 864us/step - loss: 165.0289 - porcentaje_margen: 0.0052 - val_loss: 171.1957 - val_porcentaje_margen: 0.0017
# Epoch 84/1500
# 1146/1146 [==============================] - 1s 863us/step - loss: 162.9712 - porcentaje_margen: 0.0052 - val_loss: 169.0972 - val_porcentaje_margen: 0.0035
# Epoch 85/1500
# 1146/1146 [==============================] - 1s 869us/step - loss: 160.9363 - porcentaje_margen: 0.0052 - val_loss: 167.0190 - val_porcentaje_margen: 0.0069
# Epoch 86/1500
# 1146/1146 [==============================] - 1s 984us/step - loss: 158.9239 - porcentaje_margen: 0.0052 - val_loss: 164.9565 - val_porcentaje_margen: 0.0087
# Epoch 87/1500
# 1146/1146 [==============================] - 1s 924us/step - loss: 156.9338 - porcentaje_margen: 0.0080 - val_loss: 162.8986 - val_porcentaje_margen: 0.0087
# Epoch 88/1500
# 1146/1146 [==============================] - 1s 959us/step - loss: 154.9545 - porcentaje_margen: 0.0078 - val_loss: 160.8863 - val_porcentaje_margen: 0.0069
# Epoch 89/1500
# 1146/1146 [==============================] - 1s 955us/step - loss: 153.0022 - porcentaje_margen: 0.0095 - val_loss: 158.8870 - val_porcentaje_margen: 0.0087
# Epoch 90/1500
# 1146/1146 [==============================] - 1s 911us/step - loss: 151.0751 - porcentaje_margen: 0.0150 - val_loss: 156.8856 - val_porcentaje_margen: 0.0104
# Epoch 91/1500
# 1146/1146 [==============================] - 1s 971us/step - loss: 149.1498 - porcentaje_margen: 0.0167 - val_loss: 154.9539 - val_porcentaje_margen: 0.0122
# Epoch 92/1500
# 1146/1146 [==============================] - 1s 907us/step - loss: 147.2680 - porcentaje_margen: 0.0174 - val_loss: 152.9936 - val_porcentaje_margen: 0.0122
# Epoch 93/1500
# 1146/1146 [==============================] - 1s 915us/step - loss: 145.3929 - porcentaje_margen: 0.0191 - val_loss: 151.0629 - val_porcentaje_margen: 0.0139
# Epoch 94/1500
# 1146/1146 [==============================] - 1s 932us/step - loss: 143.5314 - porcentaje_margen: 0.0200 - val_loss: 149.1765 - val_porcentaje_margen: 0.0139
# Epoch 95/1500
# 1146/1146 [==============================] - 1s 890us/step - loss: 141.7062 - porcentaje_margen: 0.0214 - val_loss: 147.2766 - val_porcentaje_margen: 0.0139
# Epoch 96/1500
# 1146/1146 [==============================] - 1s 937us/step - loss: 139.8826 - porcentaje_margen: 0.0234 - val_loss: 145.4330 - val_porcentaje_margen: 0.0139
# Epoch 97/1500
# 1146/1146 [==============================] - 1s 938us/step - loss: 138.0975 - porcentaje_margen: 0.0273 - val_loss: 143.5682 - val_porcentaje_margen: 0.0122
# Epoch 98/1500
# 1146/1146 [==============================] - 1s 917us/step - loss: 136.3142 - porcentaje_margen: 0.0282 - val_loss: 141.7620 - val_porcentaje_margen: 0.0104
# Epoch 99/1500
# 1146/1146 [==============================] - 1s 907us/step - loss: 134.5627 - porcentaje_margen: 0.0304 - val_loss: 139.9540 - val_porcentaje_margen: 0.0139
# Epoch 100/1500
# 1146/1146 [==============================] - 1s 895us/step - loss: 132.8264 - porcentaje_margen: 0.0306 - val_loss: 138.1584 - val_porcentaje_margen: 0.0174
# Epoch 101/1500
# 1146/1146 [==============================] - 1s 923us/step - loss: 131.1016 - porcentaje_margen: 0.0321 - val_loss: 136.4061 - val_porcentaje_margen: 0.0174
# Epoch 102/1500
# 1146/1146 [==============================] - 1s 907us/step - loss: 129.4069 - porcentaje_margen: 0.0286 - val_loss: 134.6489 - val_porcentaje_margen: 0.0174
# Epoch 103/1500
# 1146/1146 [==============================] - 1s 933us/step - loss: 127.7252 - porcentaje_margen: 0.0308 - val_loss: 132.9153 - val_porcentaje_margen: 0.0191
# Epoch 104/1500
# 1146/1146 [==============================] - 1s 862us/step - loss: 126.0612 - porcentaje_margen: 0.0327 - val_loss: 131.2119 - val_porcentaje_margen: 0.0244
# Epoch 105/1500
# 1146/1146 [==============================] - 1s 926us/step - loss: 124.4241 - porcentaje_margen: 0.0367 - val_loss: 129.5094 - val_porcentaje_margen: 0.0296
# Epoch 106/1500
# 1146/1146 [==============================] - 1s 869us/step - loss: 122.7909 - porcentaje_margen: 0.0391 - val_loss: 127.8508 - val_porcentaje_margen: 0.0314
# Epoch 107/1500
# 1146/1146 [==============================] - 1s 922us/step - loss: 121.1906 - porcentaje_margen: 0.0410 - val_loss: 126.1845 - val_porcentaje_margen: 0.0383
# Epoch 108/1500
# 1146/1146 [==============================] - 1s 918us/step - loss: 119.6007 - porcentaje_margen: 0.0421 - val_loss: 124.5489 - val_porcentaje_margen: 0.0383
# Epoch 109/1500
# 1146/1146 [==============================] - 1s 898us/step - loss: 118.0295 - porcentaje_margen: 0.0421 - val_loss: 122.9417 - val_porcentaje_margen: 0.0400
# Epoch 110/1500
# 1146/1146 [==============================] - 1s 944us/step - loss: 116.4838 - porcentaje_margen: 0.0434 - val_loss: 121.3394 - val_porcentaje_margen: 0.0418
# Epoch 111/1500
# 1146/1146 [==============================] - 1s 918us/step - loss: 114.9426 - porcentaje_margen: 0.0455 - val_loss: 119.7815 - val_porcentaje_margen: 0.0418
# Epoch 112/1500
# 1146/1146 [==============================] - 1s 904us/step - loss: 113.4367 - porcentaje_margen: 0.0497 - val_loss: 118.2024 - val_porcentaje_margen: 0.0435
# Epoch 113/1500
# 1146/1146 [==============================] - 1s 902us/step - loss: 111.9374 - porcentaje_margen: 0.0560 - val_loss: 116.6519 - val_porcentaje_margen: 0.0487
# Epoch 114/1500
# 1146/1146 [==============================] - 1s 917us/step - loss: 110.4554 - porcentaje_margen: 0.0590 - val_loss: 115.1316 - val_porcentaje_margen: 0.0522
# Epoch 115/1500
# 1146/1146 [==============================] - 1s 965us/step - loss: 108.9942 - porcentaje_margen: 0.0616 - val_loss: 113.6287 - val_porcentaje_margen: 0.0609
# Epoch 116/1500
# 1146/1146 [==============================] - 1s 927us/step - loss: 107.5536 - porcentaje_margen: 0.0714 - val_loss: 112.1279 - val_porcentaje_margen: 0.0627
# Epoch 117/1500
# 1146/1146 [==============================] - 1s 870us/step - loss: 106.1208 - porcentaje_margen: 0.0720 - val_loss: 110.6676 - val_porcentaje_margen: 0.0697
# Epoch 118/1500
# 1146/1146 [==============================] - 1s 870us/step - loss: 104.7226 - porcentaje_margen: 0.0779 - val_loss: 109.1887 - val_porcentaje_margen: 0.0662
# Epoch 119/1500
# 1146/1146 [==============================] - 1s 890us/step - loss: 103.3248 - porcentaje_margen: 0.0827 - val_loss: 107.7581 - val_porcentaje_margen: 0.0661
# Epoch 120/1500
# 1146/1146 [==============================] - 1s 904us/step - loss: 101.9501 - porcentaje_margen: 0.0799 - val_loss: 106.3503 - val_porcentaje_margen: 0.0644
# Epoch 121/1500
# 1146/1146 [==============================] - 1s 866us/step - loss: 100.5961 - porcentaje_margen: 0.0816 - val_loss: 104.9490 - val_porcentaje_margen: 0.0662
# Epoch 122/1500
# 1146/1146 [==============================] - 1s 883us/step - loss: 99.2578 - porcentaje_margen: 0.0828 - val_loss: 103.5579 - val_porcentaje_margen: 0.0679
# Epoch 123/1500
# 1146/1146 [==============================] - 1s 907us/step - loss: 97.9352 - porcentaje_margen: 0.0811 - val_loss: 102.1832 - val_porcentaje_margen: 0.0714
# Epoch 124/1500
# 1146/1146 [==============================] - 1s 875us/step - loss: 96.6272 - porcentaje_margen: 0.0807 - val_loss: 100.8387 - val_porcentaje_margen: 0.0731
# Epoch 125/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 95.3436 - porcentaje_margen: 0.0773 - val_loss: 99.4931 - val_porcentaje_margen: 0.0731
# Epoch 126/1500
# 1146/1146 [==============================] - 1s 967us/step - loss: 94.0658 - porcentaje_margen: 0.0753 - val_loss: 98.1901 - val_porcentaje_margen: 0.0749
# Epoch 127/1500
# 1146/1146 [==============================] - 1s 887us/step - loss: 92.8166 - porcentaje_margen: 0.0724 - val_loss: 96.8859 - val_porcentaje_margen: 0.0784
# Epoch 128/1500
# 1146/1146 [==============================] - 1s 927us/step - loss: 91.5789 - porcentaje_margen: 0.0679 - val_loss: 95.6007 - val_porcentaje_margen: 0.0766
# Epoch 129/1500
# 1146/1146 [==============================] - 1s 924us/step - loss: 90.3557 - porcentaje_margen: 0.0638 - val_loss: 94.3376 - val_porcentaje_margen: 0.0697
# Epoch 130/1500
# 1146/1146 [==============================] - 1s 858us/step - loss: 89.1547 - porcentaje_margen: 0.0608 - val_loss: 93.0773 - val_porcentaje_margen: 0.0627
# Epoch 131/1500
# 1146/1146 [==============================] - 1s 885us/step - loss: 87.9625 - porcentaje_margen: 0.0584 - val_loss: 91.8480 - val_porcentaje_margen: 0.0558
# Epoch 132/1500
# 1146/1146 [==============================] - 1s 894us/step - loss: 86.7907 - porcentaje_margen: 0.0570 - val_loss: 90.6350 - val_porcentaje_margen: 0.0557
# Epoch 133/1500
# 1146/1146 [==============================] - 1s 924us/step - loss: 85.6385 - porcentaje_margen: 0.0542 - val_loss: 89.4245 - val_porcentaje_margen: 0.0522
# Epoch 134/1500
# 1146/1146 [==============================] - 1s 896us/step - loss: 84.4964 - porcentaje_margen: 0.0492 - val_loss: 88.2452 - val_porcentaje_margen: 0.0523
# Epoch 135/1500
# 1146/1146 [==============================] - 1s 894us/step - loss: 83.3760 - porcentaje_margen: 0.0464 - val_loss: 87.0796 - val_porcentaje_margen: 0.0506
# Epoch 136/1500
# 1146/1146 [==============================] - 1s 845us/step - loss: 82.2732 - porcentaje_margen: 0.0401 - val_loss: 85.9163 - val_porcentaje_margen: 0.0436
# Epoch 137/1500
# 1146/1146 [==============================] - 1s 937us/step - loss: 81.1782 - porcentaje_margen: 0.0347 - val_loss: 84.7886 - val_porcentaje_margen: 0.0455
# Epoch 138/1500
# 1146/1146 [==============================] - 1s 946us/step - loss: 80.1035 - porcentaje_margen: 0.0349 - val_loss: 83.6758 - val_porcentaje_margen: 0.0471
# Epoch 139/1500
# 1146/1146 [==============================] - 1s 890us/step - loss: 79.0472 - porcentaje_margen: 0.0330 - val_loss: 82.5686 - val_porcentaje_margen: 0.0454
# Epoch 140/1500
# 1146/1146 [==============================] - 1s 924us/step - loss: 78.0005 - porcentaje_margen: 0.0332 - val_loss: 81.4919 - val_porcentaje_margen: 0.0367
# Epoch 141/1500
# 1146/1146 [==============================] - 1s 931us/step - loss: 76.9785 - porcentaje_margen: 0.0356 - val_loss: 80.4072 - val_porcentaje_margen: 0.0350
# Epoch 142/1500
# 1146/1146 [==============================] - 1s 907us/step - loss: 75.9629 - porcentaje_margen: 0.0386 - val_loss: 79.3515 - val_porcentaje_margen: 0.0332
# Epoch 143/1500
# 1146/1146 [==============================] - 1s 928us/step - loss: 74.9642 - porcentaje_margen: 0.0373 - val_loss: 78.3185 - val_porcentaje_margen: 0.0350
# Epoch 144/1500
# 1146/1146 [==============================] - 1s 887us/step - loss: 73.9889 - porcentaje_margen: 0.0379 - val_loss: 77.2758 - val_porcentaje_margen: 0.0297
# Epoch 145/1500
# 1146/1146 [==============================] - 1s 886us/step - loss: 73.0143 - porcentaje_margen: 0.0382 - val_loss: 76.2821 - val_porcentaje_margen: 0.0263
# Epoch 146/1500
# 1146/1146 [==============================] - 1s 904us/step - loss: 72.0675 - porcentaje_margen: 0.0356 - val_loss: 75.2832 - val_porcentaje_margen: 0.0263
# Epoch 147/1500
# 1146/1146 [==============================] - 1s 921us/step - loss: 71.1355 - porcentaje_margen: 0.0358 - val_loss: 74.2902 - val_porcentaje_margen: 0.0245
# Epoch 148/1500
# 1146/1146 [==============================] - 1s 862us/step - loss: 70.2097 - porcentaje_margen: 0.0330 - val_loss: 73.3326 - val_porcentaje_margen: 0.0245
# Epoch 149/1500
# 1146/1146 [==============================] - 1s 918us/step - loss: 69.3027 - porcentaje_margen: 0.0315 - val_loss: 72.3942 - val_porcentaje_margen: 0.0228
# Epoch 150/1500
# 1146/1146 [==============================] - 1s 875us/step - loss: 68.4131 - porcentaje_margen: 0.0304 - val_loss: 71.4613 - val_porcentaje_margen: 0.0211
# Epoch 151/1500
# 1146/1146 [==============================] - 1s 880us/step - loss: 67.5342 - porcentaje_margen: 0.0252 - val_loss: 70.5455 - val_porcentaje_margen: 0.0228
# Epoch 152/1500
# 1146/1146 [==============================] - 1s 897us/step - loss: 66.6740 - porcentaje_margen: 0.0217 - val_loss: 69.6333 - val_porcentaje_margen: 0.0193
# Epoch 153/1500
# 1146/1146 [==============================] - 1s 902us/step - loss: 65.8283 - porcentaje_margen: 0.0197 - val_loss: 68.7321 - val_porcentaje_margen: 0.0175
# Epoch 154/1500
# 1146/1146 [==============================] - 1s 879us/step - loss: 64.9963 - porcentaje_margen: 0.0193 - val_loss: 67.8474 - val_porcentaje_margen: 0.0192
# Epoch 155/1500
# 1146/1146 [==============================] - 1s 883us/step - loss: 64.1714 - porcentaje_margen: 0.0191 - val_loss: 67.0062 - val_porcentaje_margen: 0.0192
# Epoch 156/1500
# 1146/1146 [==============================] - 1s 931us/step - loss: 63.3736 - porcentaje_margen: 0.0200 - val_loss: 66.1565 - val_porcentaje_margen: 0.0175
# Epoch 157/1500
# 1146/1146 [==============================] - 1s 877us/step - loss: 62.5822 - porcentaje_margen: 0.0182 - val_loss: 65.3251 - val_porcentaje_margen: 0.0156
# Epoch 158/1500
# 1146/1146 [==============================] - 1s 869us/step - loss: 61.8048 - porcentaje_margen: 0.0165 - val_loss: 64.5124 - val_porcentaje_margen: 0.0122
# Epoch 159/1500
# 1146/1146 [==============================] - 1s 885us/step - loss: 61.0462 - porcentaje_margen: 0.0148 - val_loss: 63.7008 - val_porcentaje_margen: 0.0087
# Epoch 160/1500
# 1146/1146 [==============================] - 1s 860us/step - loss: 60.2940 - porcentaje_margen: 0.0122 - val_loss: 62.9095 - val_porcentaje_margen: 0.0087
# Epoch 161/1500
# 1146/1146 [==============================] - 1s 854us/step - loss: 59.5600 - porcentaje_margen: 0.0106 - val_loss: 62.1310 - val_porcentaje_margen: 0.0087
# Epoch 162/1500
# 1146/1146 [==============================] - 1s 858us/step - loss: 58.8386 - porcentaje_margen: 0.0089 - val_loss: 61.3696 - val_porcentaje_margen: 0.0087
# Epoch 163/1500
# 1146/1146 [==============================] - 1s 885us/step - loss: 58.1286 - porcentaje_margen: 0.0078 - val_loss: 60.6365 - val_porcentaje_margen: 0.0087
# Epoch 164/1500
# 1146/1146 [==============================] - 1s 886us/step - loss: 57.4406 - porcentaje_margen: 0.0078 - val_loss: 59.8911 - val_porcentaje_margen: 0.0087
# Epoch 165/1500
# 1146/1146 [==============================] - 1s 899us/step - loss: 56.7568 - porcentaje_margen: 0.0061 - val_loss: 59.1710 - val_porcentaje_margen: 0.0069
# Epoch 166/1500
# 1146/1146 [==============================] - 1s 932us/step - loss: 56.0858 - porcentaje_margen: 0.0052 - val_loss: 58.4782 - val_porcentaje_margen: 0.0069
# Epoch 167/1500
# 1146/1146 [==============================] - 1s 894us/step - loss: 55.4353 - porcentaje_margen: 0.0061 - val_loss: 57.7765 - val_porcentaje_margen: 0.0069
# Epoch 168/1500
# 1146/1146 [==============================] - 1s 925us/step - loss: 54.7951 - porcentaje_margen: 0.0054 - val_loss: 57.0860 - val_porcentaje_margen: 0.0069
# Epoch 169/1500
# 1146/1146 [==============================] - 1s 912us/step - loss: 54.1655 - porcentaje_margen: 0.0043 - val_loss: 56.4157 - val_porcentaje_margen: 0.0069
# Epoch 170/1500
# 1146/1146 [==============================] - 1s 880us/step - loss: 53.5472 - porcentaje_margen: 0.0043 - val_loss: 55.7680 - val_porcentaje_margen: 0.0069
# Epoch 171/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 52.9477 - porcentaje_margen: 0.0052 - val_loss: 55.1152 - val_porcentaje_margen: 0.0087
# Epoch 172/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 52.3515 - porcentaje_margen: 0.0078 - val_loss: 54.4957 - val_porcentaje_margen: 0.0104
# Epoch 173/1500
# 1146/1146 [==============================] - 1s 982us/step - loss: 51.7807 - porcentaje_margen: 0.0097 - val_loss: 53.8639 - val_porcentaje_margen: 0.0104
# Epoch 174/1500
# 1146/1146 [==============================] - 1s 882us/step - loss: 51.2117 - porcentaje_margen: 0.0113 - val_loss: 53.2637 - val_porcentaje_margen: 0.0122
# Epoch 175/1500
# 1146/1146 [==============================] - 1s 938us/step - loss: 50.6585 - porcentaje_margen: 0.0158 - val_loss: 52.6812 - val_porcentaje_margen: 0.0156
# Epoch 176/1500
# 1146/1146 [==============================] - 1s 899us/step - loss: 50.1209 - porcentaje_margen: 0.0165 - val_loss: 52.0983 - val_porcentaje_margen: 0.0226
# Epoch 177/1500
# 1146/1146 [==============================] - 1s 868us/step - loss: 49.5919 - porcentaje_margen: 0.0219 - val_loss: 51.5272 - val_porcentaje_margen: 0.0226
# Epoch 178/1500
# 1146/1146 [==============================] - 1s 893us/step - loss: 49.0695 - porcentaje_margen: 0.0243 - val_loss: 50.9860 - val_porcentaje_margen: 0.0262
# Epoch 179/1500
# 1146/1146 [==============================] - 1s 885us/step - loss: 48.5711 - porcentaje_margen: 0.0278 - val_loss: 50.4285 - val_porcentaje_margen: 0.0279
# Epoch 180/1500
# 1146/1146 [==============================] - 1s 907us/step - loss: 48.0703 - porcentaje_margen: 0.0304 - val_loss: 49.9053 - val_porcentaje_margen: 0.0296
# Epoch 181/1500
# 1146/1146 [==============================] - 1s 957us/step - loss: 47.5913 - porcentaje_margen: 0.0347 - val_loss: 49.3772 - val_porcentaje_margen: 0.0314
# Epoch 182/1500
# 1146/1146 [==============================] - 1s 952us/step - loss: 47.1190 - porcentaje_margen: 0.0360 - val_loss: 48.8714 - val_porcentaje_margen: 0.0383
# Epoch 183/1500
# 1146/1146 [==============================] - 1s 928us/step - loss: 46.6590 - porcentaje_margen: 0.0367 - val_loss: 48.3828 - val_porcentaje_margen: 0.0418
# Epoch 184/1500
# 1146/1146 [==============================] - 1s 871us/step - loss: 46.2130 - porcentaje_margen: 0.0391 - val_loss: 47.8923 - val_porcentaje_margen: 0.0418
# Epoch 185/1500
# 1146/1146 [==============================] - 1s 966us/step - loss: 45.7759 - porcentaje_margen: 0.0434 - val_loss: 47.4171 - val_porcentaje_margen: 0.0453
# Epoch 186/1500
# 1146/1146 [==============================] - 1s 898us/step - loss: 45.3493 - porcentaje_margen: 0.0481 - val_loss: 46.9554 - val_porcentaje_margen: 0.0523
# Epoch 187/1500
# 1146/1146 [==============================] - 1s 930us/step - loss: 44.9343 - porcentaje_margen: 0.0488 - val_loss: 46.5041 - val_porcentaje_margen: 0.0523
# Epoch 188/1500
# 1146/1146 [==============================] - 1s 907us/step - loss: 44.5312 - porcentaje_margen: 0.0505 - val_loss: 46.0613 - val_porcentaje_margen: 0.0593
# Epoch 189/1500
# 1146/1146 [==============================] - 1s 907us/step - loss: 44.1380 - porcentaje_margen: 0.0521 - val_loss: 45.6309 - val_porcentaje_margen: 0.0645
# Epoch 190/1500
# 1146/1146 [==============================] - 1s 907us/step - loss: 43.7510 - porcentaje_margen: 0.0570 - val_loss: 45.2294 - val_porcentaje_margen: 0.0698
# Epoch 191/1500
# 1146/1146 [==============================] - 1s 870us/step - loss: 43.3847 - porcentaje_margen: 0.0575 - val_loss: 44.8061 - val_porcentaje_margen: 0.0802
# Epoch 192/1500
# 1146/1146 [==============================] - 1s 893us/step - loss: 43.0165 - porcentaje_margen: 0.0631 - val_loss: 44.4163 - val_porcentaje_margen: 0.0872
# Epoch 193/1500
# 1146/1146 [==============================] - 1s 870us/step - loss: 42.6650 - porcentaje_margen: 0.0670 - val_loss: 44.0319 - val_porcentaje_margen: 0.0872
# Epoch 194/1500
# 1146/1146 [==============================] - 1s 899us/step - loss: 42.3233 - porcentaje_margen: 0.0714 - val_loss: 43.6548 - val_porcentaje_margen: 0.0959
# Epoch 195/1500
# 1146/1146 [==============================] - 1s 884us/step - loss: 41.9904 - porcentaje_margen: 0.0783 - val_loss: 43.2871 - val_porcentaje_margen: 0.0994
# Epoch 196/1500
# 1146/1146 [==============================] - 1s 899us/step - loss: 41.6691 - porcentaje_margen: 0.0807 - val_loss: 42.9185 - val_porcentaje_margen: 0.1013
# Epoch 197/1500
# 1146/1146 [==============================] - 1s 843us/step - loss: 41.3515 - porcentaje_margen: 0.0861 - val_loss: 42.5736 - val_porcentaje_margen: 0.1065
# Epoch 198/1500
# 1146/1146 [==============================] - 1s 894us/step - loss: 41.0442 - porcentaje_margen: 0.0922 - val_loss: 42.2476 - val_porcentaje_margen: 0.1152
# Epoch 199/1500
# 1146/1146 [==============================] - 1s 906us/step - loss: 40.7545 - porcentaje_margen: 0.0974 - val_loss: 41.9029 - val_porcentaje_margen: 0.1238
# Epoch 200/1500
# 1146/1146 [==============================] - 1s 940us/step - loss: 40.4654 - porcentaje_margen: 0.1002 - val_loss: 41.5825 - val_porcentaje_margen: 0.1309
# Epoch 201/1500
# 1146/1146 [==============================] - 1s 915us/step - loss: 40.1857 - porcentaje_margen: 0.1037 - val_loss: 41.2831 - val_porcentaje_margen: 0.1344
# Epoch 202/1500
# 1146/1146 [==============================] - 1s 913us/step - loss: 39.9229 - porcentaje_margen: 0.1060 - val_loss: 40.9681 - val_porcentaje_margen: 0.1414
# Epoch 203/1500
# 1146/1146 [==============================] - 1s 909us/step - loss: 39.6602 - porcentaje_margen: 0.1100 - val_loss: 40.6797 - val_porcentaje_margen: 0.1432
# Epoch 204/1500
# 1146/1146 [==============================] - 1s 905us/step - loss: 39.4084 - porcentaje_margen: 0.1112 - val_loss: 40.4027 - val_porcentaje_margen: 0.1432
# Epoch 205/1500
# 1146/1146 [==============================] - 1s 938us/step - loss: 39.1675 - porcentaje_margen: 0.1143 - val_loss: 40.1272 - val_porcentaje_margen: 0.1466
# Epoch 206/1500
# 1146/1146 [==============================] - 1s 903us/step - loss: 38.9306 - porcentaje_margen: 0.1206 - val_loss: 39.8692 - val_porcentaje_margen: 0.1485
# Epoch 207/1500
# 1146/1146 [==============================] - 1s 871us/step - loss: 38.7051 - porcentaje_margen: 0.1215 - val_loss: 39.6094 - val_porcentaje_margen: 0.1450
# Epoch 208/1500
# 1146/1146 [==============================] - 1s 848us/step - loss: 38.4866 - porcentaje_margen: 0.1269 - val_loss: 39.3537 - val_porcentaje_margen: 0.1450
# Epoch 209/1500
# 1146/1146 [==============================] - 1s 905us/step - loss: 38.2723 - porcentaje_margen: 0.1303 - val_loss: 39.1181 - val_porcentaje_margen: 0.1466
# Epoch 210/1500
# 1146/1146 [==============================] - 1s 902us/step - loss: 38.0708 - porcentaje_margen: 0.1325 - val_loss: 38.8765 - val_porcentaje_margen: 0.1519
# Epoch 211/1500
# 1146/1146 [==============================] - 1s 872us/step - loss: 37.8700 - porcentaje_margen: 0.1371 - val_loss: 38.6592 - val_porcentaje_margen: 0.1572
# Epoch 212/1500
# 1146/1146 [==============================] - 1s 852us/step - loss: 37.6832 - porcentaje_margen: 0.1395 - val_loss: 38.4384 - val_porcentaje_margen: 0.1624
# Epoch 213/1500
# 1146/1146 [==============================] - 1s 923us/step - loss: 37.5003 - porcentaje_margen: 0.1417 - val_loss: 38.2273 - val_porcentaje_margen: 0.1624
# Epoch 214/1500
# 1146/1146 [==============================] - 1s 909us/step - loss: 37.3248 - porcentaje_margen: 0.1447 - val_loss: 38.0241 - val_porcentaje_margen: 0.1676
# Epoch 215/1500
# 1146/1146 [==============================] - 1s 883us/step - loss: 37.1626 - porcentaje_margen: 0.1462 - val_loss: 37.8100 - val_porcentaje_margen: 0.1641
# Epoch 216/1500
# 1146/1146 [==============================] - 1s 882us/step - loss: 36.9924 - porcentaje_margen: 0.1524 - val_loss: 37.6378 - val_porcentaje_margen: 0.1624
# Epoch 217/1500
# 1146/1146 [==============================] - 1s 866us/step - loss: 36.8415 - porcentaje_margen: 0.1503 - val_loss: 37.4531 - val_porcentaje_margen: 0.1641
# Epoch 218/1500
# 1146/1146 [==============================] - 1s 858us/step - loss: 36.6914 - porcentaje_margen: 0.1494 - val_loss: 37.2806 - val_porcentaje_margen: 0.1676
# Epoch 219/1500
# 1146/1146 [==============================] - 1s 913us/step - loss: 36.5503 - porcentaje_margen: 0.1479 - val_loss: 37.1022 - val_porcentaje_margen: 0.1693
# Epoch 220/1500
# 1146/1146 [==============================] - 1s 887us/step - loss: 36.4104 - porcentaje_margen: 0.1548 - val_loss: 36.9457 - val_porcentaje_margen: 0.1693
# Epoch 221/1500
# 1146/1146 [==============================] - 1s 887us/step - loss: 36.2807 - porcentaje_margen: 0.1571 - val_loss: 36.7852 - val_porcentaje_margen: 0.1623
# Epoch 222/1500
# 1146/1146 [==============================] - 1s 1ms/step - loss: 36.1523 - porcentaje_margen: 0.1636 - val_loss: 36.6171 - val_porcentaje_margen: 0.1640
# Epoch 223/1500
# 1146/1146 [==============================] - 1s 927us/step - loss: 28.3772 - porcentaje_margen: 0.1761 - val_loss: 26.5908 - val_porcentaje_margen: 0.1918
# Epoch 224/1500
# 1146/1146 [==============================] - 1s 956us/step - loss: 23.6717 - porcentaje_margen: 0.2167 - val_loss: 24.9475 - val_porcentaje_margen: 0.1986
# Epoch 225/1500
# 1146/1146 [==============================] - 1s 856us/step - loss: 22.8050 - porcentaje_margen: 0.2366 - val_loss: 24.2607 - val_porcentaje_margen: 0.2178
# Epoch 226/1500
# 1146/1146 [==============================] - 1s 887us/step - loss: 22.2044 - porcentaje_margen: 0.2473 - val_loss: 23.6297 - val_porcentaje_margen: 0.2284
# Epoch 227/1500
# 1146/1146 [==============================] - 1s 882us/step - loss: 21.6613 - porcentaje_margen: 0.2581 - val_loss: 23.1005 - val_porcentaje_margen: 0.2512
# Epoch 228/1500
# 1146/1146 [==============================] - 1s 905us/step - loss: 21.1016 - porcentaje_margen: 0.2714 - val_loss: 22.5801 - val_porcentaje_margen: 0.2647
# Epoch 229/1500
# 1146/1146 [==============================] - 1s 947us/step - loss: 20.6318 - porcentaje_margen: 0.2736 - val_loss: 22.0467 - val_porcentaje_margen: 0.2668
# Epoch 230/1500
# 1146/1146 [==============================] - 1s 912us/step - loss: 20.1304 - porcentaje_margen: 0.2872 - val_loss: 21.7871 - val_porcentaje_margen: 0.2981
# Epoch 231/1500
# 1146/1146 [==============================] - 1s 877us/step - loss: 19.7357 - porcentaje_margen: 0.2981 - val_loss: 21.1787 - val_porcentaje_margen: 0.2753
# Epoch 232/1500
# 1146/1146 [==============================] - 1s 954us/step - loss: 19.3235 - porcentaje_margen: 0.3026 - val_loss: 20.6870 - val_porcentaje_margen: 0.2910
# Epoch 233/1500
# 1146/1146 [==============================] - 1s 946us/step - loss: 18.9343 - porcentaje_margen: 0.3022 - val_loss: 20.4340 - val_porcentaje_margen: 0.2878
# Epoch 234/1500
# 1146/1146 [==============================] - 1s 893us/step - loss: 18.5435 - porcentaje_margen: 0.3087 - val_loss: 20.0005 - val_porcentaje_margen: 0.2911
# Epoch 235/1500
# 1146/1146 [==============================] - 1s 937us/step - loss: 18.1392 - porcentaje_margen: 0.3145 - val_loss: 19.5071 - val_porcentaje_margen: 0.3031
# Epoch 236/1500
# 1146/1146 [==============================] - 1s 999us/step - loss: 17.7381 - porcentaje_margen: 0.3216 - val_loss: 19.2787 - val_porcentaje_margen: 0.3103
# Epoch 237/1500
# 1146/1146 [==============================] - 1s 932us/step - loss: 17.4288 - porcentaje_margen: 0.3262 - val_loss: 18.7739 - val_porcentaje_margen: 0.2927
# Epoch 238/1500
# 1146/1146 [==============================] - 1s 917us/step - loss: 17.0797 - porcentaje_margen: 0.3146 - val_loss: 18.4349 - val_porcentaje_margen: 0.2892
# Epoch 239/1500
# 1146/1146 [==============================] - 1s 916us/step - loss: 16.7649 - porcentaje_margen: 0.3149 - val_loss: 18.0863 - val_porcentaje_margen: 0.2981
# Epoch 240/1500
# 1146/1146 [==============================] - 1s 958us/step - loss: 16.4387 - porcentaje_margen: 0.3235 - val_loss: 17.8142 - val_porcentaje_margen: 0.3065
# Epoch 241/1500
# 1146/1146 [==============================] - 1s 934us/step - loss: 16.1372 - porcentaje_margen: 0.3297 - val_loss: 17.4196 - val_porcentaje_margen: 0.2998
# Epoch 242/1500
# 1146/1146 [==============================] - 1s 951us/step - loss: 15.8641 - porcentaje_margen: 0.3241 - val_loss: 17.2168 - val_porcentaje_margen: 0.2946
# Epoch 243/1500
# 1146/1146 [==============================] - 1s 900us/step - loss: 15.5353 - porcentaje_margen: 0.3246 - val_loss: 16.8105 - val_porcentaje_margen: 0.3101
# Epoch 244/1500
# 1146/1146 [==============================] - 1s 901us/step - loss: 15.2237 - porcentaje_margen: 0.3261 - val_loss: 16.5281 - val_porcentaje_margen: 0.3118
# Epoch 245/1500
# 1146/1146 [==============================] - 1s 902us/step - loss: 14.9730 - porcentaje_margen: 0.3245 - val_loss: 16.3282 - val_porcentaje_margen: 0.3225
# Epoch 246/1500
# 1146/1146 [==============================] - 1s 941us/step - loss: 14.6918 - porcentaje_margen: 0.3434 - val_loss: 15.9162 - val_porcentaje_margen: 0.3381
# Epoch 247/1500
# 1146/1146 [==============================] - 1s 893us/step - loss: 14.4028 - porcentaje_margen: 0.3442 - val_loss: 15.6004 - val_porcentaje_margen: 0.3417
# Epoch 248/1500
# 1146/1146 [==============================] - 1s 934us/step - loss: 14.1112 - porcentaje_margen: 0.3587 - val_loss: 15.3223 - val_porcentaje_margen: 0.3521
# Epoch 249/1500
# 1146/1146 [==============================] - 1s 877us/step - loss: 13.8894 - porcentaje_margen: 0.3602 - val_loss: 15.0539 - val_porcentaje_margen: 0.3644
# Epoch 250/1500
# 1146/1146 [==============================] - 1s 903us/step - loss: 13.5904 - porcentaje_margen: 0.3663 - val_loss: 14.7686 - val_porcentaje_margen: 0.3696
# Epoch 251/1500
# 1146/1146 [==============================] - 1s 906us/step - loss: 13.3318 - porcentaje_margen: 0.3763 - val_loss: 14.4907 - val_porcentaje_margen: 0.3642
# Epoch 252/1500
# 1146/1146 [==============================] - 1s 910us/step - loss: 13.1134 - porcentaje_margen: 0.3663 - val_loss: 14.2169 - val_porcentaje_margen: 0.3642
# Epoch 253/1500
# 1146/1146 [==============================] - 1s 904us/step - loss: 12.8428 - porcentaje_margen: 0.3741 - val_loss: 14.0032 - val_porcentaje_margen: 0.3729
# Epoch 254/1500
# 1146/1146 [==============================] - 1s 885us/step - loss: 12.6126 - porcentaje_margen: 0.3775 - val_loss: 13.7246 - val_porcentaje_margen: 0.3521
# Epoch 255/1500
# 1146/1146 [==============================] - 1s 877us/step - loss: 12.3663 - porcentaje_margen: 0.3775 - val_loss: 13.4930 - val_porcentaje_margen: 0.3605
# Epoch 256/1500
# 1146/1146 [==============================] - 1s 909us/step - loss: 12.1269 - porcentaje_margen: 0.3770 - val_loss: 13.2166 - val_porcentaje_margen: 0.3553
# Epoch 257/1500
# 1146/1146 [==============================] - 1s 888us/step - loss: 11.9065 - porcentaje_margen: 0.3868 - val_loss: 13.0983 - val_porcentaje_margen: 0.3416
# Epoch 258/1500
# 1146/1146 [==============================] - 1s 941us/step - loss: 11.7184 - porcentaje_margen: 0.3799 - val_loss: 12.8000 - val_porcentaje_margen: 0.3729
# Epoch 259/1500
# 1146/1146 [==============================] - 1s 896us/step - loss: 11.4693 - porcentaje_margen: 0.4004 - val_loss: 12.4720 - val_porcentaje_margen: 0.3992
# Epoch 260/1500
# 1146/1146 [==============================] - 1s 906us/step - loss: 11.2573 - porcentaje_margen: 0.3920 - val_loss: 12.2377 - val_porcentaje_margen: 0.4044
# Epoch 261/1500
# 1146/1146 [==============================] - 1s 880us/step - loss: 11.0401 - porcentaje_margen: 0.4024 - val_loss: 12.0045 - val_porcentaje_margen: 0.3922
# Epoch 262/1500
# 1146/1146 [==============================] - 1s 891us/step - loss: 10.8254 - porcentaje_margen: 0.4175 - val_loss: 11.8521 - val_porcentaje_margen: 0.3887
# Epoch 263/1500
# 1146/1146 [==============================] - 1s 919us/step - loss: 10.6203 - porcentaje_margen: 0.4221 - val_loss: 11.5643 - val_porcentaje_margen: 0.4288
# Epoch 264/1500
# 1146/1146 [==============================] - 1s 896us/step - loss: 10.4173 - porcentaje_margen: 0.4167 - val_loss: 11.3366 - val_porcentaje_margen: 0.4216
# Epoch 265/1500
# 1146/1146 [==============================] - 1s 934us/step - loss: 10.2183 - porcentaje_margen: 0.4180 - val_loss: 11.1121 - val_porcentaje_margen: 0.4323
# Epoch 266/1500
# 1146/1146 [==============================] - 1s 938us/step - loss: 10.0231 - porcentaje_margen: 0.4267 - val_loss: 10.9286 - val_porcentaje_margen: 0.4306
# Epoch 267/1500
# 1146/1146 [==============================] - 1s 879us/step - loss: 9.8576 - porcentaje_margen: 0.4282 - val_loss: 10.7057 - val_porcentaje_margen: 0.4410
# Epoch 268/1500
# 1146/1146 [==============================] - 1s 887us/step - loss: 9.6506 - porcentaje_margen: 0.4391 - val_loss: 10.4881 - val_porcentaje_margen: 0.4530
# Epoch 269/1500
# 1146/1146 [==============================] - 1s 884us/step - loss: 9.4865 - porcentaje_margen: 0.4336 - val_loss: 10.2815 - val_porcentaje_margen: 0.4602
# Epoch 270/1500
# 1146/1146 [==============================] - 1s 888us/step - loss: 9.2957 - porcentaje_margen: 0.4437 - val_loss: 10.1427 - val_porcentaje_margen: 0.4306
# Epoch 271/1500
# 1146/1146 [==============================] - 1s 909us/step - loss: 9.1322 - porcentaje_margen: 0.4472 - val_loss: 9.9114 - val_porcentaje_margen: 0.4550
# Epoch 272/1500
# 1146/1146 [==============================] - 1s 903us/step - loss: 8.9291 - porcentaje_margen: 0.4633 - val_loss: 9.8088 - val_porcentaje_margen: 0.4271
# Epoch 273/1500
# 1146/1146 [==============================] - 1s 942us/step - loss: 8.7696 - porcentaje_margen: 0.4658 - val_loss: 9.5210 - val_porcentaje_margen: 0.4723
# Epoch 274/1500
# 1146/1146 [==============================] - 1s 924us/step - loss: 8.5992 - porcentaje_margen: 0.4716 - val_loss: 9.3354 - val_porcentaje_margen: 0.4775
# Epoch 275/1500
# 1146/1146 [==============================] - 1s 922us/step - loss: 8.4432 - porcentaje_margen: 0.4800 - val_loss: 9.2727 - val_porcentaje_margen: 0.4479
# Epoch 276/1500
# 1146/1146 [==============================] - 1s 883us/step - loss: 8.2972 - porcentaje_margen: 0.4815 - val_loss: 9.0276 - val_porcentaje_margen: 0.4914
# Epoch 277/1500
# 1146/1146 [==============================] - 1s 895us/step - loss: 8.1191 - porcentaje_margen: 0.4842 - val_loss: 8.8358 - val_porcentaje_margen: 0.4966
# Epoch 278/1500
# 1146/1146 [==============================] - 1s 913us/step - loss: 7.9816 - porcentaje_margen: 0.4915 - val_loss: 8.6448 - val_porcentaje_margen: 0.5019
# Epoch 279/1500
# 1146/1146 [==============================] - 1s 878us/step - loss: 7.8327 - porcentaje_margen: 0.5011 - val_loss: 8.5424 - val_porcentaje_margen: 0.5089
# Epoch 280/1500
# ...
# Epoch 1407/1500
# 1146/1146 [==============================] - 1s 876us/step - loss: 0.7002 - porcentaje_margen: 0.8341 - val_loss: 0.6671 - val_porcentaje_margen: 0.8258
# Epoch 1408/1500
# 1146/1146 [==============================] - 1s 923us/step - loss: 0.7005 - porcentaje_margen: 0.8278 - val_loss: 0.6840 - val_porcentaje_margen: 0.8066
# Epoch 1409/1500
# 1146/1146 [==============================] - 1s 919us/step - loss: 0.7044 - porcentaje_margen: 0.8241 - val_loss: 0.6446 - val_porcentaje_margen: 0.8381
# Epoch 1410/1500
# 1146/1146 [==============================] - 1s 909us/step - loss: 0.7105 - porcentaje_margen: 0.8427 - val_loss: 0.6671 - val_porcentaje_margen: 0.8503
# Epoch 1411/1500
# 1146/1146 [==============================] - 1s 905us/step - loss: 0.7019 - porcentaje_margen: 0.8425 - val_loss: 0.6439 - val_porcentaje_margen: 0.8416
# Epoch 1412/1500
# 1146/1146 [==============================] - 1s 912us/step - loss: 0.7217 - porcentaje_margen: 0.8200 - val_loss: 0.6573 - val_porcentaje_margen: 0.8240
# Epoch 1413/1500
# 1146/1146 [==============================] - 1s 890us/step - loss: 0.7064 - porcentaje_margen: 0.8386 - val_loss: 0.7037 - val_porcentaje_margen: 0.8117
# Epoch 1414/1500
# 1146/1146 [==============================] - 1s 860us/step - loss: 0.7012 - porcentaje_margen: 0.8369 - val_loss: 0.6469 - val_porcentaje_margen: 0.8310
# Epoch 1415/1500
# 1146/1146 [==============================] - 1s 862us/step - loss: 0.7015 - porcentaje_margen: 0.8291 - val_loss: 0.6500 - val_porcentaje_margen: 0.8399
# Epoch 1416/1500
# 1146/1146 [==============================] - 1s 922us/step - loss: 0.7053 - porcentaje_margen: 0.8293 - val_loss: 0.6841 - val_porcentaje_margen: 0.8083
# Epoch 1417/1500
# 1146/1146 [==============================] - 1s 916us/step - loss: 0.7183 - porcentaje_margen: 0.8231 - val_loss: 0.7076 - val_porcentaje_margen: 0.8135
# Epoch 1418/1500
# 1146/1146 [==============================] - 1s 875us/step - loss: 0.7889 - porcentaje_margen: 0.8100 - val_loss: 0.6918 - val_porcentaje_margen: 0.8101
# Epoch 1419/1500
# 1146/1146 [==============================] - 1s 894us/step - loss: 0.7202 - porcentaje_margen: 0.8210 - val_loss: 0.7837 - val_porcentaje_margen: 0.8207
# Epoch 1420/1500
# 1146/1146 [==============================] - 1s 910us/step - loss: 0.7054 - porcentaje_margen: 0.8373 - val_loss: 0.6460 - val_porcentaje_margen: 0.8346
# Epoch 1421/1500
# 1146/1146 [==============================] - 1s 934us/step - loss: 0.6979 - porcentaje_margen: 0.8289 - val_loss: 0.6815 - val_porcentaje_margen: 0.8118
# Epoch 1422/1500
# 1146/1146 [==============================] - 1s 911us/step - loss: 0.7018 - porcentaje_margen: 0.8351 - val_loss: 0.6419 - val_porcentaje_margen: 0.8521
# Epoch 1423/1500
# 1146/1146 [==============================] - 1s 903us/step - loss: 0.7130 - porcentaje_margen: 0.8319 - val_loss: 0.6820 - val_porcentaje_margen: 0.8416
# Epoch 1424/1500
# 1146/1146 [==============================] - 1s 881us/step - loss: 0.7158 - porcentaje_margen: 0.8237 - val_loss: 0.6636 - val_porcentaje_margen: 0.8469
# Epoch 1425/1500
# 1146/1146 [==============================] - 1s 887us/step - loss: 0.7389 - porcentaje_margen: 0.8163 - val_loss: 0.6583 - val_porcentaje_margen: 0.8451
# Epoch 1426/1500
# 1146/1146 [==============================] - 1s 916us/step - loss: 0.7240 - porcentaje_margen: 0.8212 - val_loss: 0.6537 - val_porcentaje_margen: 0.8258
# Epoch 1427/1500
# 1146/1146 [==============================] - 1s 885us/step - loss: 0.7120 - porcentaje_margen: 0.8312 - val_loss: 0.6753 - val_porcentaje_margen: 0.8398
# Epoch 1428/1500
# 1146/1146 [==============================] - 1s 895us/step - loss: 0.7074 - porcentaje_margen: 0.8362 - val_loss: 0.6537 - val_porcentaje_margen: 0.8451
# Epoch 1429/1500
# 1146/1146 [==============================] - 1s 861us/step - loss: 0.7029 - porcentaje_margen: 0.8273 - val_loss: 0.6953 - val_porcentaje_margen: 0.8101
# Epoch 1430/1500
# 1146/1146 [==============================] - 1s 872us/step - loss: 0.7196 - porcentaje_margen: 0.8280 - val_loss: 0.6614 - val_porcentaje_margen: 0.8294
# Epoch 1431/1500
# 1146/1146 [==============================] - 1s 894us/step - loss: 0.7034 - porcentaje_margen: 0.8429 - val_loss: 0.6521 - val_porcentaje_margen: 0.8450
# Epoch 1432/1500
# 1146/1146 [==============================] - 1s 915us/step - loss: 0.6945 - porcentaje_margen: 0.8332 - val_loss: 0.6492 - val_porcentaje_margen: 0.8275
# Epoch 1433/1500
# 1146/1146 [==============================] - 1s 850us/step - loss: 0.7096 - porcentaje_margen: 0.8293 - val_loss: 0.6473 - val_porcentaje_margen: 0.8398
# Epoch 1434/1500
# 1146/1146 [==============================] - 1s 872us/step - loss: 0.7285 - porcentaje_margen: 0.8228 - val_loss: 0.6712 - val_porcentaje_margen: 0.8311
# Epoch 1435/1500
# 1146/1146 [==============================] - 1s 859us/step - loss: 0.6995 - porcentaje_margen: 0.8328 - val_loss: 0.6463 - val_porcentaje_margen: 0.8311
# Epoch 1436/1500
# 1146/1146 [==============================] - 1s 882us/step - loss: 0.7002 - porcentaje_margen: 0.8371 - val_loss: 0.7122 - val_porcentaje_margen: 0.8347
# Epoch 1437/1500
# 1146/1146 [==============================] - 1s 909us/step - loss: 0.7353 - porcentaje_margen: 0.8241 - val_loss: 0.7057 - val_porcentaje_margen: 0.8118
# Epoch 1438/1500
# 1146/1146 [==============================] - 1s 899us/step - loss: 0.7140 - porcentaje_margen: 0.8362 - val_loss: 0.6472 - val_porcentaje_margen: 0.8258
# Epoch 1439/1500
# 1146/1146 [==============================] - 1s 881us/step - loss: 0.7153 - porcentaje_margen: 0.8173 - val_loss: 0.6815 - val_porcentaje_margen: 0.8135
# Epoch 1440/1500
# 1146/1146 [==============================] - 1s 900us/step - loss: 0.7004 - porcentaje_margen: 0.8323 - val_loss: 0.6666 - val_porcentaje_margen: 0.8345
# Epoch 1441/1500
# 1146/1146 [==============================] - 1s 894us/step - loss: 0.6959 - porcentaje_margen: 0.8334 - val_loss: 0.6820 - val_porcentaje_margen: 0.8154
# Epoch 1442/1500
# 1146/1146 [==============================] - 1s 912us/step - loss: 0.7034 - porcentaje_margen: 0.8293 - val_loss: 0.6481 - val_porcentaje_margen: 0.8417
# Epoch 1443/1500
# 1146/1146 [==============================] - 1s 861us/step - loss: 0.6953 - porcentaje_margen: 0.8363 - val_loss: 0.6438 - val_porcentaje_margen: 0.8363
# Epoch 1444/1500
# 1146/1146 [==============================] - 1s 902us/step - loss: 0.6949 - porcentaje_margen: 0.8347 - val_loss: 0.7001 - val_porcentaje_margen: 0.8118
# Epoch 1445/1500
# 1146/1146 [==============================] - 1s 852us/step - loss: 0.7182 - porcentaje_margen: 0.8224 - val_loss: 0.6432 - val_porcentaje_margen: 0.8434
# Epoch 1446/1500
# 1146/1146 [==============================] - 1s 861us/step - loss: 0.7105 - porcentaje_margen: 0.8237 - val_loss: 0.6657 - val_porcentaje_margen: 0.8451
# Epoch 1447/1500
# 1146/1146 [==============================] - 1s 877us/step - loss: 0.6960 - porcentaje_margen: 0.8301 - val_loss: 0.6557 - val_porcentaje_margen: 0.8189
# Epoch 1448/1500
# 1146/1146 [==============================] - 1s 919us/step - loss: 0.7025 - porcentaje_margen: 0.8297 - val_loss: 0.6636 - val_porcentaje_margen: 0.8258
# Epoch 1449/1500
# 1146/1146 [==============================] - 1s 903us/step - loss: 0.6927 - porcentaje_margen: 0.8315 - val_loss: 0.6574 - val_porcentaje_margen: 0.8397
# Epoch 1450/1500
# 1146/1146 [==============================] - 1s 863us/step - loss: 0.7108 - porcentaje_margen: 0.8367 - val_loss: 0.6416 - val_porcentaje_margen: 0.8363
# Epoch 1451/1500
# 1146/1146 [==============================] - 1s 895us/step - loss: 0.7253 - porcentaje_margen: 0.8193 - val_loss: 0.7186 - val_porcentaje_margen: 0.8242
# Epoch 1452/1500
# 1146/1146 [==============================] - 1s 877us/step - loss: 0.7048 - porcentaje_margen: 0.8293 - val_loss: 0.6815 - val_porcentaje_margen: 0.8398
# Epoch 1453/1500
# 1146/1146 [==============================] - 1s 860us/step - loss: 0.6973 - porcentaje_margen: 0.8317 - val_loss: 0.6594 - val_porcentaje_margen: 0.8520
# Epoch 1454/1500
# 1146/1146 [==============================] - 1s 935us/step - loss: 0.6958 - porcentaje_margen: 0.8332 - val_loss: 0.6675 - val_porcentaje_margen: 0.8258
# Epoch 1455/1500
# 1146/1146 [==============================] - 1s 909us/step - loss: 0.7014 - porcentaje_margen: 0.8383 - val_loss: 0.7271 - val_porcentaje_margen: 0.8347
# Epoch 1456/1500
# 1146/1146 [==============================] - 1s 864us/step - loss: 0.7234 - porcentaje_margen: 0.8210 - val_loss: 0.8623 - val_porcentaje_margen: 0.7750
# Epoch 1457/1500
# 1146/1146 [==============================] - 1s 913us/step - loss: 0.7232 - porcentaje_margen: 0.8141 - val_loss: 0.6432 - val_porcentaje_margen: 0.8381
# Epoch 1458/1500
# 1146/1146 [==============================] - 1s 880us/step - loss: 0.7050 - porcentaje_margen: 0.8319 - val_loss: 0.6689 - val_porcentaje_margen: 0.8223
# Epoch 1459/1500
# 1146/1146 [==============================] - 1s 944us/step - loss: 0.7130 - porcentaje_margen: 0.8235 - val_loss: 0.6594 - val_porcentaje_margen: 0.8450
# Epoch 1460/1500
# 1146/1146 [==============================] - 1s 889us/step - loss: 0.6917 - porcentaje_margen: 0.8395 - val_loss: 0.6808 - val_porcentaje_margen: 0.8206
# Epoch 1461/1500
# 1146/1146 [==============================] - 1s 890us/step - loss: 0.7018 - porcentaje_margen: 0.8293 - val_loss: 0.6792 - val_porcentaje_margen: 0.8311
# Epoch 1462/1500
# 1146/1146 [==============================] - 1s 869us/step - loss: 0.6961 - porcentaje_margen: 0.8337 - val_loss: 0.6763 - val_porcentaje_margen: 0.8347
# Epoch 1463/1500
# 1146/1146 [==============================] - 1s 929us/step - loss: 0.6969 - porcentaje_margen: 0.8347 - val_loss: 0.6691 - val_porcentaje_margen: 0.8259
# Epoch 1464/1500
# 1146/1146 [==============================] - 1s 891us/step - loss: 0.7179 - porcentaje_margen: 0.8271 - val_loss: 0.6648 - val_porcentaje_margen: 0.8119
# Epoch 1465/1500
# 1146/1146 [==============================] - 1s 887us/step - loss: 0.7007 - porcentaje_margen: 0.8336 - val_loss: 0.6544 - val_porcentaje_margen: 0.8293
# Epoch 1466/1500
# 1146/1146 [==============================] - 1s 872us/step - loss: 0.7261 - porcentaje_margen: 0.8208 - val_loss: 0.6652 - val_porcentaje_margen: 0.8503
# Epoch 1467/1500
# 1146/1146 [==============================] - 1s 917us/step - loss: 0.7194 - porcentaje_margen: 0.8291 - val_loss: 0.6439 - val_porcentaje_margen: 0.8277
# Epoch 1468/1500
# 1146/1146 [==============================] - 1s 842us/step - loss: 0.7110 - porcentaje_margen: 0.8362 - val_loss: 0.6773 - val_porcentaje_margen: 0.8397
# Epoch 1469/1500
# 1146/1146 [==============================] - 1s 907us/step - loss: 0.7163 - porcentaje_margen: 0.8284 - val_loss: 0.6411 - val_porcentaje_margen: 0.8486
# Epoch 1470/1500
# 1146/1146 [==============================] - 1s 904us/step - loss: 0.7102 - porcentaje_margen: 0.8256 - val_loss: 0.6796 - val_porcentaje_margen: 0.8154
# Epoch 1471/1500
# 1146/1146 [==============================] - 1s 890us/step - loss: 0.6965 - porcentaje_margen: 0.8403 - val_loss: 0.7384 - val_porcentaje_margen: 0.8100
# Epoch 1472/1500
# 1146/1146 [==============================] - 1s 892us/step - loss: 0.7173 - porcentaje_margen: 0.8287 - val_loss: 0.7292 - val_porcentaje_margen: 0.8134
# Epoch 1473/1500
# 1146/1146 [==============================] - 1s 913us/step - loss: 0.7070 - porcentaje_margen: 0.8342 - val_loss: 0.6536 - val_porcentaje_margen: 0.8468
# Epoch 1474/1500
# 1146/1146 [==============================] - 1s 859us/step - loss: 0.7134 - porcentaje_margen: 0.8269 - val_loss: 0.6503 - val_porcentaje_margen: 0.8311
# Epoch 1475/1500
# 1146/1146 [==============================] - 1s 916us/step - loss: 0.7122 - porcentaje_margen: 0.8247 - val_loss: 0.6451 - val_porcentaje_margen: 0.8294
# Epoch 1476/1500
# 1146/1146 [==============================] - 1s 880us/step - loss: 0.7191 - porcentaje_margen: 0.8243 - val_loss: 0.6546 - val_porcentaje_margen: 0.8223
# Epoch 1477/1500
# 1146/1146 [==============================] - 1s 870us/step - loss: 0.7052 - porcentaje_margen: 0.8319 - val_loss: 0.6636 - val_porcentaje_margen: 0.8521
# Epoch 1478/1500
# 1146/1146 [==============================] - 1s 935us/step - loss: 0.7014 - porcentaje_margen: 0.8252 - val_loss: 0.6470 - val_porcentaje_margen: 0.8485
# Epoch 1479/1500
# 1146/1146 [==============================] - 1s 913us/step - loss: 0.7152 - porcentaje_margen: 0.8215 - val_loss: 0.6704 - val_porcentaje_margen: 0.8468
# Epoch 1480/1500
# 1146/1146 [==============================] - 1s 881us/step - loss: 0.7002 - porcentaje_margen: 0.8249 - val_loss: 0.7027 - val_porcentaje_margen: 0.8049
# Epoch 1481/1500
# 1146/1146 [==============================] - 1s 901us/step - loss: 0.7209 - porcentaje_margen: 0.8287 - val_loss: 0.8105 - val_porcentaje_margen: 0.7943
# Epoch 1482/1500
# 1146/1146 [==============================] - 1s 861us/step - loss: 0.7219 - porcentaje_margen: 0.8353 - val_loss: 0.6624 - val_porcentaje_margen: 0.8329
# Epoch 1483/1500
# 1146/1146 [==============================] - 1s 909us/step - loss: 0.7133 - porcentaje_margen: 0.8306 - val_loss: 0.6771 - val_porcentaje_margen: 0.8066
# Epoch 1484/1500
# 1146/1146 [==============================] - 1s 883us/step - loss: 0.7086 - porcentaje_margen: 0.8332 - val_loss: 0.6517 - val_porcentaje_margen: 0.8486
# Epoch 1485/1500
# 1146/1146 [==============================] - 1s 892us/step - loss: 0.6961 - porcentaje_margen: 0.8355 - val_loss: 0.7073 - val_porcentaje_margen: 0.8365
# Epoch 1486/1500
# 1146/1146 [==============================] - 1s 902us/step - loss: 0.7248 - porcentaje_margen: 0.8373 - val_loss: 0.7144 - val_porcentaje_margen: 0.8082
# Epoch 1487/1500
# 1146/1146 [==============================] - 1s 980us/step - loss: 0.6903 - porcentaje_margen: 0.8393 - val_loss: 0.6523 - val_porcentaje_margen: 0.8451
# Epoch 1488/1500
# 1146/1146 [==============================] - 1s 896us/step - loss: 0.7022 - porcentaje_margen: 0.8367 - val_loss: 0.6523 - val_porcentaje_margen: 0.8469
# Epoch 1489/1500
# 1146/1146 [==============================] - 1s 882us/step - loss: 0.7165 - porcentaje_margen: 0.8259 - val_loss: 0.6435 - val_porcentaje_margen: 0.8241
# Epoch 1490/1500
# 1146/1146 [==============================] - 1s 890us/step - loss: 0.7112 - porcentaje_margen: 0.8261 - val_loss: 0.6385 - val_porcentaje_margen: 0.8398
# Epoch 1491/1500
# 1146/1146 [==============================] - 1s 890us/step - loss: 0.6864 - porcentaje_margen: 0.8286 - val_loss: 0.6663 - val_porcentaje_margen: 0.8399
# Epoch 1492/1500
# 1146/1146 [==============================] - 1s 876us/step - loss: 0.7105 - porcentaje_margen: 0.8291 - val_loss: 0.6667 - val_porcentaje_margen: 0.8469
# Epoch 1493/1500
# 1146/1146 [==============================] - 1s 915us/step - loss: 0.7052 - porcentaje_margen: 0.8291 - val_loss: 0.6809 - val_porcentaje_margen: 0.8416
# Epoch 1494/1500
# 1146/1146 [==============================] - 1s 915us/step - loss: 0.7128 - porcentaje_margen: 0.8276 - val_loss: 0.6405 - val_porcentaje_margen: 0.8521
# Epoch 1495/1500
# 1146/1146 [==============================] - 1s 913us/step - loss: 0.7039 - porcentaje_margen: 0.8274 - val_loss: 0.6716 - val_porcentaje_margen: 0.8118
# Epoch 1496/1500
# 1146/1146 [==============================] - 1s 920us/step - loss: 0.7026 - porcentaje_margen: 0.8308 - val_loss: 0.6901 - val_porcentaje_margen: 0.8434
# Epoch 1497/1500
# 1146/1146 [==============================] - 1s 882us/step - loss: 0.7042 - porcentaje_margen: 0.8287 - val_loss: 0.6899 - val_porcentaje_margen: 0.8102
# Epoch 1498/1500
# 1146/1146 [==============================] - 1s 886us/step - loss: 0.7211 - porcentaje_margen: 0.8321 - val_loss: 0.6439 - val_porcentaje_margen: 0.8486
# Epoch 1499/1500
# 1146/1146 [==============================] - 1s 928us/step - loss: 0.6930 - porcentaje_margen: 0.8436 - val_loss: 0.6507 - val_porcentaje_margen: 0.8329
# Epoch 1500/1500
# 1146/1146 [==============================] - 1s 894us/step - loss: 0.6992 - porcentaje_margen: 0.8359 - val_loss: 0.6483 - val_porcentaje_margen: 0.8275

# %% [markdown]
# #### Si vemos que necesitamos mas epocas corremos este codigo
# history_LSTM = model.fit(X_train,
#                   y_train,
#                   initial_epoch=700,
#                   epochs=1500,
#                   verbose=1,
#                   validation_data=(X_test,y_test))

# %%
plt.plot(history_LSTM42.epoch,history_LSTM42.history['val_porcentaje_margen'],label='validation')
plt.plot(history_LSTM42.epoch,history_LSTM42.history['porcentaje_margen'],label="training")
plt.legend()
plt.title('Success Rate Evolution')
plt.xlabel('Epocs')
plt.show()

# %%
# Calculo la prediccion para mi conjunto test
predicted_stock_price = pd.DataFrame(model.predict(Xtt))

# Junto la grafica de los datos de entrenamiento y test para ver cuanto a variado en terminos generales
indicedetiempo = pd.concat((index_time,index_time_t), axis = 0)
yt = pd.DataFrame(yt) ; ytt = pd.DataFrame(ytt)
stock_real_value = pd.concat((yt,ytt),axis = 0)

# Calculo el RMSE para ver el error de prediccion
rmse = sqrt(mean_squared_error(ytt, predicted_stock_price))

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15, 5))
fig.suptitle(tickers[index],fontsize = 20)
# Plot de todo el grafico
ax1.plot(indicedetiempo,stock_real_value,label="Valor Real",color = "blue")
ax1.plot(index_time_t,predicted_stock_price, label="Valor Predicho", color = "black")
ax1.legend()

# Plot de solo la parte que hemos hecho el predict
ax2.plot(index_time_t,ytt,label="Valor Real",color = "blue")
ax2.plot(index_time_t,predicted_stock_price, label="Valor Predicho", color = "black")
ax2.legend()
ax2.annotate('RMSE = %.2f'% rmse, (index_time_t[40], ytt.iloc[40]), xytext=(50, 50), 
            textcoords='offset points',fontsize = 15)

plt.show()

# %% [markdown]
# Queremos realizar una inversion de 100000 euros en el activo que hemos estudiado, nos basamos en un margen entre la diferencia de los dos precios adyacentes para saber si comprar, vender o mantener.
# Tenemos 3 posibles caminos, comprar solo a la alza, comprar solo a la baja o comprar a la alza y a la baja.
# Ciertos actios tienen caidas o subidas muy bruscas imposibles de predecir porque no tienen que ver con los datos historicos si no con la situacion y el contexto que vive la empresa

# %%
pd.options.display.max_rows = 10000 # Para poder ver todos los movimientos

# Es un margen movil, segun lo que busquemos
margen = 0.00
diferencias = np.zeros(len(predicted_stock_price)-1)
for i in range(len(diferencias)):
    diferencias[i] = (predicted_stock_price.iloc[i+1,0]-predicted_stock_price.iloc[i,0])/max(predicted_stock_price.iloc[i+1,0],predicted_stock_price.iloc[i,0])
    if diferencias[i] > margen:
        diferencias[i] = 1
    elif diferencias[i] < -margen:
        diferencias[i] = -1
    else:
        diferencias[i] = 0
    
print(Counter(diferencias))
# Out:
# Counter({-1.0: 163, 1.0: 146})

# %%
# Si solo queremos comrpar a la alza
# Estado es lo que hay que hacer ese dia
# estado = 1 comprar, estado = 0 mantener, estado = -1 vender
movimientos_alza = pd.DataFrame(columns = ["presupuesto","acciones","estado","valor","pred","dif"],index = index_time_t)
movimientos_alza.presupuesto[0] = 100000 ; movimientos_alza.acciones[0] = 0 ; movimientos_alza.estado[0] = 0
movimientos_alza.valor[0] = ytt.iloc[0,0] ; movimientos_alza.pred[0] = predicted_stock_price.iloc[0,0]

for i in range(1,len(diferencias)):
    if diferencias[i] == 1:
        if movimientos_alza.acciones[i-1] == 0:
            movimientos_alza.estado[i] = 1
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1] % ytt.iloc[i,0]
            movimientos_alza.acciones[i] = movimientos_alza.presupuesto[i-1] // ytt.iloc[i,0]
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]
        else:
            movimientos_alza.estado[i] = 0
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1]
            movimientos_alza.acciones[i] = movimientos_alza.acciones[i-1]
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]
    elif diferencias[i] == 0:
            movimientos_alza.estado[i] = 0
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1]
            movimientos_alza.acciones[i] = movimientos_alza.acciones[i-1]
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]
    elif diferencias[i] == -1:
        if movimientos_alza.acciones[i-1] > 0:
            movimientos_alza.estado[i] = -1
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1] + movimientos_alza.acciones[i-1] * ytt.iloc[i,0]
            movimientos_alza.acciones[i] = 0
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]
        else:
            movimientos_alza.estado[i] = 0
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1]
            movimientos_alza.acciones[i] = movimientos_alza.acciones[i-1]
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]

            
movimientos_alza = movimientos_alza.drop(movimientos_alza.tail(1).index)
print(movimientos_alza.tail(1))
valor_f_alza = movimientos_alza.presupuesto[len(movimientos_alza)-1] + movimientos_alza.valor[len(movimientos_alza)-1] * movimientos_alza.acciones[len(movimientos_alza)-1]
ganancia_alza = valor_f_alza - 100000
print('Valor Final = %.2f' % valor_f_alza)
print('Ganancia con margen = %.2f' % ganancia_alza)
# Out:
#            presupuesto acciones estado  valor     pred dif
# 2018-03-26       72042        0     -1  2.125  4.30573  -1
# Valor Final = 72042.00
# Ganancia con margen = -27958.00

# %%
print(movimientos_alza)
# Out:
#            presupuesto acciones estado    valor     pred  dif
# 2016-12-30      100000        0      0   20.044  20.1318  NaN
# 2017-01-03      100000        0      0  20.2124  20.2899    0
# 2017-01-04      100000        0      0   20.371  20.3034    0
# 2017-01-05      100000        0      0  20.1827  20.2005    0
# 2017-01-06      100000        0      0  20.1728    20.11    0
# 2017-01-09      100000        0      0  20.3512  20.3616    0
# 2017-01-10      100000        0      0  21.0844  20.3085    0
# 2017-01-11      100000        0      0  20.9952  20.2538    0
# 2017-01-12      100000        0      0  20.2917  20.5418    0
# 2017-01-13      100000        0      0  20.5493  20.6095    0
# 2017-01-17      100000        0      0  19.9945  20.4652    0
# 2017-01-18      100000        0      0  20.0737  20.4477    0
# 2017-01-19      100000        0      0  19.4693  20.2109    0
# 2017-01-20      100000        0      0  19.7269  20.2375    0
# 2017-01-23      100000        0      0  19.6972  19.9328    0
# 2017-01-24      100000        0      0   19.618  19.9782    0
# 2017-01-25      100000        0      0  19.9449  19.8985    0
# 2017-01-26      100000        0      0  19.5882  19.7148    0
# 2017-01-27      100000        0      0  19.8855  19.8004    0
# 2017-01-30      100000        0      0  19.3604  19.6441    0
# 2017-01-31      100000        0      0  20.0341  19.7527    0
# 2017-02-01      100000        0      0  20.0242   19.553    0
# 2017-02-02      100000        0      0  19.8954  19.8607    0
# 2017-02-03      100000        0      0  19.8855  19.9136    0
# 2017-02-06      100000        0      0  19.7864  20.0541    0
# 2017-02-07      100000        0      0   18.429  20.1322    0
# 2017-02-08      100000        0      0  18.1714  20.0222   -1
# 2017-02-09      100000        0      0  18.2209  18.9167    0
# 2017-02-10      100000        0      0  18.2903  18.4304    0
# 2017-02-13      100000        0      0  18.4191  18.4819    0
# 2017-02-14      100000        0      0  18.2705  18.3326    0
# 2017-02-15      100000        0      0  18.2705  18.5547    0
# 2017-02-16      100000        0      0  17.8741   18.339    0
# 2017-02-17      100000        0      0  18.0822  18.4584    0
# 2017-02-21      100000        0      0  18.0921  18.0123    0
# 2017-02-22      100000        0      0  18.2209   18.045    0
# 2017-02-23      100000        0      0  18.4983  18.1261    0
# 2017-02-24      100000        0      0  18.5281  18.1704    0
# 2017-02-27      100000        0      0  18.7659  18.6454    0
# 2017-02-28      100000        0      0  18.4092  18.6691    0
# 2017-03-01      100000        0      0  18.5677  19.1185    0
# 2017-03-02      100000        0      0    18.32  18.6337    0
# 2017-03-03      100000        0      0  18.0525  18.5658    0
# 2017-03-06      100000        0      0  17.7156  18.3342    0
# 2017-03-07      100000        0      0  17.6264  18.0113    0
# 2017-03-08      100000        0      0  17.8444  17.6376    0
# 2017-03-09      100000        0      0  17.8543  17.9524    0
# 2017-03-10      100000        0      0  17.8741  18.1119    0
# 2017-03-13      100000        0      0  17.9732  18.0021    0
# 2017-03-14      100000        0      0   17.894  17.8595    0
# 2017-03-15      100000        0      0  18.0327  17.7621    0
# 2017-03-16      100000        0      0  18.0921  17.7808    0
# 2017-03-17      100000        0      0  18.2705  17.8902    0
# 2017-03-20      100000        0      0  17.9039  18.2179    0
# 2017-03-21      100000        0      0  17.9633  18.3554    0
# 2017-03-22      100000        0      0  17.8543  18.2752    0
# 2017-03-23      100000        0      0  17.9339   18.288    0
# 2017-03-24      100000        0      0  18.0531  18.0916    0
# 2017-03-27      100000        0      0  18.0531  18.0498    0
# 2017-03-28      100000        0      0  17.8742  17.9296    0
# 2017-03-29      100000        0      0  18.0333  18.0177    0
# 2017-03-30      100000        0      0  18.1128  17.7987    0
# 2017-03-31      100000        0      0  18.2619  17.8925    0
# 2017-04-03      100000        0      0  17.9239   18.021    0
# 2017-04-04      100000        0      0  17.9239  18.2632    0
# 2017-04-05      100000        0      0  17.8245  18.1626    0
# 2017-04-06      100000        0      0  18.1029  18.0486    0
# 2017-04-07      100000        0      0  18.3812  17.9792    0
# 2017-04-10      100000        0      0  18.3713  18.1185    0
# 2017-04-11      100000        0      0  18.3911    18.27    0
# 2017-04-12      100000        0      0  17.9537  18.3738    0
# 2017-04-13      100000        0      0  17.9438  18.3753    0
# 2017-04-17      100000        0      0  18.2619  18.1248    0
# 2017-04-18      100000        0      0  18.1824  17.9666    0
# 2017-04-19      100000        0      0   18.252  18.2469    0
# 2017-04-20      100000        0      0  18.3414  18.2267    0
# 2017-04-21      100000        0      0  18.1426  18.3324    0
# 2017-04-24      100000        0      0  18.3514  18.3692    0
# 2017-04-25      100000        0      0  18.4409   18.209    0
# 2017-04-26      100000        0      0  18.9081  18.2813    0
# 2017-04-27      100000        0      0  18.8286  18.4336    0
# 2017-04-28      100000        0      0  18.7192  18.6693    0
# 2017-05-01      100000        0      0  18.8186  18.6905    0
# 2017-05-02      100000        0      0   20.111  18.6092    0
# 2017-05-03      100000        0      0   20.439  18.8358    0
# 2017-05-04      100000        0      0  21.1647  19.6319    0
# 2017-05-05      100000        0      0  20.6975  20.1007    0
# 2017-05-08      100000        0      0  20.7571  20.5514    0
# 2017-05-09      100000        0      0  21.1548  20.3336    0
# 2017-05-10      100000        0      0  20.9858  20.3699    0
# 2017-05-11      100000        0      0  20.9361   20.592    0
# 2017-05-12      100000        0      0  20.7074  20.8341    0
# 2017-05-15      100000        0      0  21.3337  20.9787    0
# 2017-05-16      100000        0      0  21.2045  20.8539    0
# 2017-05-17      100000        0      0  20.7969  21.2641    0
# 2017-05-18      100000        0      0  20.6776  21.3859    0
# 2017-05-19      100000        0      0  20.5881  21.2505    0
# 2017-05-22      100000        0      0  20.1507  21.2356    0
# 2017-05-23      100000        0      0  20.1607  21.0606    0
# 2017-05-24      100000        0      0  20.0811  20.6872    0
# 2017-05-25      100000        0      0  20.2999  20.2832    0
# 2017-05-26      100000        0      0  20.2899  20.1507    0
# 2017-05-30      100000        0      0  19.9121  20.3418    0
# 2017-05-31      100000        0      0  20.1408  20.4649    0
# 2017-06-01      100000        0      0  20.6577  19.8235    0
# 2017-06-02      100000        0      0  20.7273  19.9169    0
# 2017-06-05      100000        0      0   20.618  20.0377    0
# 2017-06-06      100000        0      0  20.4291  20.5025    0
# 2017-06-07      100000        0      0   20.787  20.6468    0
# 2017-06-08      100000        0      0  20.5881  20.4824    0
# 2017-06-09      100000        0      0  20.7969  20.7177    0
# 2017-06-12      100000        0      0  20.5285  20.6993    0
# 2017-06-13      100000        0      0  20.3297  20.8998    0
# 2017-06-14      100000        0      0  20.3197  20.4971    0
# 2017-06-15      100000        0      0  20.3197  20.2912    0
# 2017-06-16      100000        0      0  20.6279   20.346    0
# 2017-06-19      100000        0      0  20.4589  20.3667    0
# 2017-06-20      100000        0      0  20.6776    20.52    0
# 2017-06-21      100000        0      0  20.9063  20.6088    0
# 2017-06-22      100000        0      0  20.9561  20.6623    0
# 2017-06-23      100000        0      0  21.0757  20.7764    0
# 2017-06-26      100000        0      0  21.1555  20.7129    0
# 2017-06-27      100000        0      0  20.8564  20.7927    0
# 2017-06-28      100000        0      0   21.315  21.0892    0
# 2017-06-29      100000        0      0  21.2353  20.9669    0
# 2017-06-30      100000        0      0  21.0558  21.0208    0
# 2017-07-03      100000        0      0  20.9661  21.0254    0
# 2017-07-05      100000        0      0  21.0558   21.037    0
# 2017-07-06      100000        0      0  20.6869  21.1207    0
# 2017-07-07      100000        0      0  20.9561  21.0507    0
# 2017-07-10      100000        0      0  20.5075  20.9462    0
# 2017-07-11      100000        0      0  20.5075  20.9339    0
# 2017-07-12      100000        0      0  20.6471  20.7956    0
# 2017-07-13      100000        0      0  20.8464  20.7863    0
# 2017-07-14      100000        0      0  20.6969  20.7982    0
# 2017-07-17      100000        0      0  20.9262   20.846    0
# 2017-07-18      100000        0      0  20.5872  20.5927    0
# 2017-07-19      100000        0      0  20.7767  20.7737    0
# 2017-07-20      100000        0      0  20.8265  20.5933    0
# 2017-07-21      100000        0      0  20.6471  20.6379    0
# 2017-07-24      100000        0      0  20.6371  20.7427    0
# 2017-07-25      100000        0      0  20.4875  20.6868    0
# 2017-07-26      100000        0      0  20.4277  20.6818    0
# 2017-07-27      100000        0      0  20.2184  20.7651    0
# 2017-07-28      100000        0      0   20.333   20.531    0
# 2017-07-31      100000        0      0  20.3679  20.3664    0
# 2017-08-01      100000        0      0  20.1585  20.4205    0
# 2017-08-02      100000        0      0  20.1386  20.4596    0
# 2017-08-03      100000        0      0  20.1386  20.2736    0
# 2017-08-04      100000        0      0  19.9891  20.3213    0
# 2017-08-07      100000        0      0  19.7996  20.1228    0
# 2017-08-08      100000        0      0  20.2483  20.1726    0
# 2017-08-09      100000        0      0  19.8894  20.0438    0
# 2017-08-10      100000        0      0  19.1516  20.1938    0
# 2017-08-11      100000        0      0  19.1317  19.9479    0
# 2017-08-14      100000        0      0  19.3709  19.5812    0
# 2017-08-15      100000        0      0  19.2413  19.3367    0
# 2017-08-16      100000        0      0  19.1317  19.5418    0
# 2017-08-17      100000        0      0  18.9522  19.4051    0
# 2017-08-18      100000        0      0  18.8924  19.2655    0
# 2017-08-21      100000        0      0  19.1716  19.1636    0
# 2017-08-22      100000        0      0   19.032  19.0455    0
# 2017-08-23      100000        0      0  18.8226  19.1915    0
# 2017-08-24      100000        0      0  18.8126  19.1174    0
# 2017-08-25      100000        0      0  18.8326  19.0554    0
# 2017-08-28      100000        0      0  18.9123  18.9637    0
# 2017-08-29      100000        0      0  18.8126   18.921    0
# 2017-08-30      100000        0      0  18.9123  19.0232    0
# 2017-08-31      100000        0      0  19.2712  18.9604    0
# 2017-09-01      100000        0      0  19.1716  18.9624    0
# 2017-09-05      100000        0      0  19.0918  19.1855    0
# 2017-09-06      100000        0      0  19.3111  19.2305    0
# 2017-09-07      100000        0      0  19.1815  18.9096    0
# 2017-09-08      100000        0      0  19.0818  19.0654    0
# 2017-09-11      100000        0      0  19.2314  19.3262    0
# 2017-09-12      100000        0      0  19.6601  19.2891    0
# 2017-09-13      100000        0      0  19.9591  19.1992    0
# 2017-09-14      100000        0      0  19.7598  19.4382    0
# 2017-09-15      100000        0      0    19.67  19.6889    0
# 2017-09-18      100000        0      0  19.7498   19.724    0
# 2017-09-19      100000        0      0  19.4806  19.6992    0
# 2017-09-20      100000        0      0  19.4407  19.5827    0
# 2017-09-21      100000        0      0    19.68   19.475    0
# 2017-09-22      100000        0      0    19.94  19.5201    0
# 2017-09-25      100000        0      0    20.11  19.6739    0
# 2017-09-26      100000        0      0    19.94   19.874    0
# 2017-09-27      100000        0      0    20.25  20.0079    0
# 2017-09-28      100000        0      0    20.24  20.0164    0
# 2017-09-29      100000        0      0    20.33  20.1509    0
# 2017-10-02      100000        0      0    20.78  20.0298    0
# 2017-10-03      100000        0      0    20.75  20.1529    0
# 2017-10-04      100000        0      0    20.77  20.5181    0
# 2017-10-05      100000        0      0    20.66  20.5641    0
# 2017-10-06      100000        0      0    20.56  20.7334    0
# 2017-10-09      100000        0      0    20.47  20.8181    0
# 2017-10-10      100000        0      0    20.56  20.7607    0
# 2017-10-11      100000        0      0    20.56  20.5245    0
# 2017-10-12      100000        0      0    20.79  20.3934    0
# 2017-10-13      100000        0      0    20.55  20.4834    0
# 2017-10-16      100000        0      0    20.42  20.7212    0
# 2017-10-17      100000        0      0    20.31  20.6581    0
# 2017-10-18      100000        0      0    20.43  20.6912    0
# 2017-10-19      100000        0      0    20.26  20.6267    0
# 2017-10-20      100000        0      0    20.46  20.5384    0
# 2017-10-23      100000        0      0    20.37  20.3031    0
# 2017-10-24      100000        0      0    20.34  20.3071    0
# 2017-10-25      100000        0      0    19.96  20.4057    0
# 2017-10-26      100000        0      0    20.09  20.3315    0
# 2017-10-27      100000        0      0    20.31  20.1864    0
# 2017-10-30      100000        0      0    20.34  20.2217    0
# 2017-10-31      100000        0      0    21.35  20.1782    0
# 2017-11-01      100000        0      0    21.48    20.25    0
# 2017-11-02      100000        0      0    21.36  20.8325    0
# 2017-11-03      100000        0      0    21.47  21.1508    0
# 2017-11-06      100000        0      0    21.51  21.2548    0
# 2017-11-07      100000        0      0    21.46  21.3716    0
# 2017-11-09      100000        0      0    21.51  21.3742    0
# 2017-11-10      100000        0      0    20.91  21.3578    0
# 2017-11-13      100000        0      0    20.97   21.292    0
# 2017-11-14      100000        0      0    21.28  21.1014    0
# 2017-11-15      100000        0      0    21.53  21.1354    0
# 2017-11-16      100000        0      0    21.74  21.3736    0
# 2017-11-17      100000        0      0    21.51  21.5241    0
# 2017-11-20      100000        0      0    21.54  21.7254    0
# 2017-11-21      100000        0      0     22.1  21.5168    0
# 2017-11-22      100000        0      0    21.69  21.4262    0
# 2017-11-24      100000        0      0     21.9  21.6244    0
# 2017-11-27      100000        0      0    21.68  21.6246    0
# 2017-11-28      100000        0      0    21.85  21.6963    0
# 2017-11-29      100000        0      0    21.58  21.6174    0
# 2017-11-30      100000        0      0    21.36  21.8305    0
# 2017-12-01      100000        0      0    21.23   21.458    0
# 2017-12-04      100000        0      0    20.88  21.3091    0
# 2017-12-05      100000        0      0    20.56  21.3136    0
# 2017-12-06      100000        0      0    20.55  21.1657    0
# 2017-12-07      100000        0      0    20.54  20.9836    0
# 2017-12-08      100000        0      0    20.54  20.9304    0
# 2017-12-11      100000        0      0    20.27    20.85    0
# 2017-12-12      100000        0      0    20.39  21.0339    0
# 2017-12-13      100000        0      0    20.52  20.8021    0
# 2017-12-14      100000        0      0    20.37  20.5625    0
# 2017-12-15      100000        0      0    20.55  20.4414    0
# 2017-12-18      100000        0      0    20.65  20.3025    0
# 2017-12-19      100000        0      0    20.59  20.5945    0
# 2017-12-20      100000        0      0    20.53  20.7969    0
# 2017-12-21      100000        0      0    20.32  20.6289    0
# 2017-12-22      100000        0      0    19.98  20.7589    0
# 2017-12-26      100000        0      0    19.84  20.5283    0
# 2017-12-27      100000        0      0    19.68  20.3231    0
# 2017-12-28      100000        0      0    19.78  20.0131    0
# 2017-12-29      100000        0      0     19.7  19.8695    0
# 2018-01-02      100000        0      0    20.33  19.8804    0
# 2018-01-03      100000        0      0    20.24  19.8086    0
# 2018-01-04      100000        0      0    20.12  20.1831    0
# 2018-01-05      100000        0      0     20.5  20.2631    0
# 2018-01-08      100000        0      0    20.68   20.117    0
# 2018-01-09      100000        0      0    20.76  20.2431    0
# 2018-01-10      100000        0      0    20.46  20.3763    0
# 2018-01-11      100000        0      0    20.51  20.6439    0
# 2018-01-12      100000        0      0    20.73  20.5335    0
# 2018-01-16      100000        0      0    20.56  20.5114    0
# 2018-01-17      100000        0      0    20.81  20.6976    0
# 2018-01-18      100000        0      0    20.64  20.5745    0
# 2018-01-19      100000        0      0    20.56  20.6096    0
# 2018-01-22      100000        0      0    20.56  20.5367    0
# 2018-01-23      100000        0      0    20.47  20.4839    0
# 2018-01-24      100000        0      0    20.54  20.5322    0
# 2018-01-25      100000        0      0    20.63   20.612    0
# 2018-01-26      100000        0      0    20.68  20.6714    0
# 2018-01-29      100000        0      0    20.46  20.7486    0
# 2018-01-30      100000        0      0     20.1  20.6959    0
# 2018-01-31      100000        0      0    20.19  20.5913    0
# 2018-02-01      100000        0      0    20.27  20.0799    0
# 2018-02-02      100000        0      0    20.13  20.1175    0
# 2018-02-05      100000        0      0    19.39  20.2978    0
# 2018-02-06      100000        0      0    19.35  20.1672    0
# 2018-02-07      100000        0      0     19.4  19.7123    0
# 2018-02-08      100000        0      0    18.77  19.5415    0
# 2018-02-09      100000        0      0    19.05  19.6549    0
# 2018-02-12      100000        0      0    19.31  19.3037    0
# 2018-02-13      100000        0      0    19.38  19.2175    0
# 2018-02-14      100000        0      0     19.6  19.3792    0
# 2018-02-15      100000        0      0    19.74  19.3103    0
# 2018-02-16      100000        0      0    19.72   19.499    0
# 2018-02-20      100000        0      0    19.84  19.6542    0
# 2018-02-21      100000        0      0    20.33   19.702    0
# 2018-02-22      100000        0      0    20.37  19.8715    0
# 2018-02-23      100000        0      0    20.35  20.1654    0
# 2018-02-26      100000        0      0    20.29  20.2133    0
# 2018-02-27      100000        0      0    19.93  20.1802    0
# 2018-02-28      100000        0      0    19.61  20.1857    0
# 2018-03-01      100000        0      0    19.38  20.0911    0
# 2018-03-02      100000        0      0    19.42  19.7681    0
# 2018-03-05      100000        0      0    19.69  19.4209    0
# 2018-03-06      100000        0      0     20.2  19.3023    0
# 2018-03-07      100000        0      0    20.69  19.6999    0
# 2018-03-08      100000        0      0    21.06   20.038    0
# 2018-03-09      100000        0      0    21.73  20.2778    0
# 2018-03-12      100000        0      0    21.98  20.7844    0
# 2018-03-13      100000        0      0    21.55  21.1093    0
# 2018-03-14      100000        0      0    21.36  21.2989    0
# 2018-03-15      100000        0      0    21.39   21.257    0
# 2018-03-16      100000        0      0    21.48  21.2033    0
# 2018-03-19      100000        0      0    21.66  21.2554    0
# 2018-03-20      100000        0      0    21.61  21.4229    0
# 2018-03-21      100000        0      0    21.57  21.6183    0
# 2018-03-22      100000        0      0   21.305  21.5537    0
# 2018-03-23      100000        0      0    20.96  21.5816    0
# 2018-03-26      100000        0      0    21.17  21.5417    0

# %%
# Compro a la alza y a la baja
# movimiento que se realizao en el dia = estado
# estado = 1 comprar, estado = 0 mantener, estado = -1 vender
movimientos_ab= pd.DataFrame(columns = ["presupuesto","acciones","acciones_debo","estado","valor","pred","dif"],index = index_time_t)
movimientos_ab.presupuesto[0] = 100000 % ytt.iloc[0,0] ; movimientos_ab.acciones[0] = 100000 // ytt.iloc[0,0] ; movimientos_ab.acciones_debo[0] = 0 ;
movimientos_ab.estado[0] = 0 ; movimientos_ab.valor[0] = ytt.iloc[0,0] ;
movimientos_ab.pred[0] = predicted_stock_price.iloc[0,0] 

for i in range(1,len(diferencias)):
    if diferencias[i] == 1:
        if movimientos_ab.acciones[i-1] == 0:
            movimientos_ab.estado[i] = 1
            movimientos_ab.presupuesto[i] = ((movimientos_ab.presupuesto[i-1] - (movimientos_ab.acciones_debo[i-1] * ytt.iloc[i,0]))
                                         % ytt.iloc[i,0])
            movimientos_ab.acciones[i] = ((movimientos_ab.presupuesto[i-1] - (movimientos_ab.acciones_debo[i-1] * ytt.iloc[i,0]))
                                         // ytt.iloc[i,0])
            movimientos_ab.acciones_debo[i] = 0
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
        else:
            movimientos_ab.estado[i] = 0
            movimientos_ab.presupuesto[i] = movimientos_ab.presupuesto[i-1]
            movimientos_ab.acciones[i] = movimientos_ab.acciones[i-1]
            movimientos_ab.acciones_debo[i] = movimientos_ab.acciones_debo[i-1]
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
    elif diferencias[i] == 0:
            movimientos_ab.estado[i] = 0
            movimientos_ab.presupuesto[i] = movimientos_ab.presupuesto[i-1]
            movimientos_ab.acciones[i] = movimientos_ab.acciones[i-1]
            movimientos_ab.acciones_debo[i] = movimientos_ab.acciones_debo[i-1]
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
    elif diferencias[i] == -1:
        if movimientos_ab.acciones_debo[i-1] == 0:
            movimientos_ab.estado[i] = -1
            movimientos_ab.presupuesto[i] = ((movimientos_ab.presupuesto[i-1] + movimientos_ab.acciones[i-1] * ytt.iloc[i,0]) +
                                          ((movimientos_ab.presupuesto[i-1] + movimientos_ab.acciones[i-1] * ytt.iloc[i,0]) //
                                           ytt.iloc[i,0]) * ytt.iloc[i,0])
            movimientos_ab.acciones[i] = 0
            movimientos_ab.acciones_debo[i] = ((movimientos_ab.presupuesto[i-1] + movimientos_ab.acciones[i-1] * ytt.iloc[i,0]) //
                                           ytt.iloc[i,0]) # Las pido prestadas
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
        else:
            movimientos_ab.estado[i] = 0
            movimientos_ab.presupuesto[i] = movimientos_ab.presupuesto[i-1]
            movimientos_ab.acciones[i] = movimientos_ab.acciones[i-1]
            movimientos_ab.acciones_debo[i] = movimientos_ab.acciones_debo[i-1]
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
            
movimientos_ab = movimientos_ab.drop(movimientos_ab.tail(1).index)
print(movimientos_ab.tail(1))
if movimientos_ab.acciones_debo[len(movimientos_ab)-1] == 0 :
    valor_f_ab = movimientos_ab.presupuesto[len(movimientos_ab)-1] + movimientos_ab.valor[len(movimientos_ab)-1] * movimientos_ab.acciones[len(movimientos_ab)-1]
else:
    valor_f_ab = movimientos_ab.presupuesto[len(movimientos_ab)-1] - movimientos_ab.valor[len(movimientos_ab)-1] * movimientos_ab.acciones_debo[len(movimientos_ab)-1]
ganancia_ab = valor_f_ab - 100000
print('Valor Final = %.2f' % valor_f_ab)
print('Ganancia con margen = %.2f' % ganancia_ab)
# Out:
#            presupuesto acciones acciones_debo estado  valor     pred dif
# 2018-03-26      309861        0         72908     -1  2.125  4.30573  -1
# Valor Final = 154931.21
# Ganancia con margen = 54931.21

# %%
print(movimientos_ab)

# %%
# Compro a la baja
# movimiento que se realizao en el dia = estado
# estado = 1 comprar, estado = 0 mantener, estado = -1 vender
movimientos_baja = pd.DataFrame(columns = ["presupuesto","acciones","acciones_debo","estado","valor","pred","dif"],index = index_time_t)
movimientos_baja.presupuesto[0] = 100000  ; movimientos_baja.acciones[0] = 0 ; movimientos_baja.acciones_debo[0] = 0 ;
movimientos_baja.estado[0] = 0 ; movimientos_baja.valor[0] = ytt.iloc[0,0] ;
movimientos_baja.pred[0] = predicted_stock_price.iloc[0,0] 

for i in range(1,len(diferencias)):
    if diferencias[i] == 1:
        if movimientos_baja.acciones[i-1] == 0:
            movimientos_baja.estado[i] = 1
            movimientos_baja.presupuesto[i] = ((movimientos_baja.presupuesto[i-1] - (movimientos_baja.acciones_debo[i-1] * ytt.iloc[i,0])))
            movimientos_baja.acciones[i] = 0
            movimientos_baja.acciones_debo[i] = 0
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
        else:
            movimientos_baja.estado[i] = 0
            movimientos_baja.presupuesto[i] = movimientos_baja.presupuesto[i-1]
            movimientos_baja.acciones[i] = movimientos_baja.acciones[i-1]
            movimientos_baja.acciones_debo[i] = movimientos_baja.acciones_debo[i-1]
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
    elif diferencias[i] == 0:
            movimientos_baja.estado[i] = 0
            movimientos_baja.presupuesto[i] = movimientos_baja.presupuesto[i-1]
            movimientos_baja.acciones[i] = movimientos_baja.acciones[i-1]
            movimientos_baja.acciones_debo[i] = movimientos_baja.acciones_debo[i-1]
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
    elif diferencias[i] == -1:
        if movimientos_baja.acciones_debo[i-1] == 0:
            movimientos_baja.estado[i] = -1
            movimientos_baja.presupuesto[i] = ((movimientos_baja.presupuesto[i-1]) + (movimientos_baja.presupuesto[i-1] //
                                           ytt.iloc[i,0]) * ytt.iloc[i,0])
            movimientos_baja.acciones[i] = 0
            movimientos_baja.acciones_debo[i] = (movimientos_baja.presupuesto[i-1] // ytt.iloc[i,0]) # Las pido prestadas
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
        else:
            movimientos_baja.estado[i] = 0
            movimientos_baja.presupuesto[i] = movimientos_baja.presupuesto[i-1]
            movimientos_baja.acciones[i] = movimientos_baja.acciones[i-1]
            movimientos_baja.acciones_debo[i] = movimientos_baja.acciones_debo[i-1]
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
            
movimientos_baja = movimientos_baja.drop(movimientos_baja.tail(1).index)
print(movimientos_baja.tail(1))
if movimientos_baja.acciones_debo[len(movimientos_baja)-1] == 0 :
    valor_f_baja = movimientos_baja.presupuesto[len(movimientos_baja)-1] + movimientos_baja.valor[len(movimientos_baja)-1] * movimientos_baja.acciones[len(movimientos_baja)-1]
else:
    valor_f_baja = movimientos_baja.presupuesto[len(movimientos_baja)-1] - movimientos_baja.valor[len(movimientos_baja)-1] * movimientos_baja.acciones_debo[len(movimientos_baja)-1]
ganancia_baja = valor_f_baja - 100000
print('Valor Final = %.2f' % valor_f_baja)
print('Ganancia con margen = %.2f' % ganancia_baja)
# Out:
#            presupuesto acciones acciones_debo estado  valor     pred dif
# 2018-03-26      428706        0        100872     -1  2.125  4.30573  -1
# Valor Final = 214353.32
# Ganancia con margen = 114353.32

# %%
print(movimientos_baja)
