# %% [markdown]
# ### TFG - Cesar Hernandez Rodriguez
# TFG - Extendido con prediccion basada con los datos de año en año, en este script se encuentran todos los datos del indice Nasdaq de los cuales solo se hace una seleccion aleatoria de 15 (valor k dentro del script) y se procede a la prediccion de uno de esos valores con una red LSTM de 4 neuronas en la primera capa y 2 en la segunda.
#
# Solo se realiza una red LSTM, pudiendo cambiarse por cualquier otra de las que se exponen en la carpeta TFG.
#
# Este script se basa en descargar datos de la bolsa de EEUU, exactamente todos los del índice Nasdaq que es uno de los índices más importantes de Estados Unidos, siendo la segunda bolsa de valores automatizada y electronica mas grande del mundo con 3800 compañias. (https://es.wikipedia.org/wiki/NASDAQ)
#
# Para ello usaré la librería QUANDL (https://www.quandl.com/tools/python) que implementa una API para poder descargar los datos de manera sencilla.
#
# El primer paso es coger los activos que tenemos ya que al ser una API de caracter gratuito no disponemos ni los datos de todos los activos ni estan actulaizados por lo que hacemos un filtrado con los 2 .csv que estan en la misma carpeta
#
# A mayores una vez descagardo los datos (ya que tarda mucho) los voy a guardar dentro de mi ordenador serializandolo con el paquete Pickle (http://pyspanishdoc.sourceforge.net/lib/module-pickle.html)
#
# A la hora de realizar el modelo creo 3 atributos, 2 medias moviles una de 10 dias y otra de 20 dias y un oscilador de la media movil de 20 dias.
#
# Depues de realizar el modelo la idea de la practica es realizar una prueba real, por ello me fio del modelo que he obtenido e imaginando una inversion inical de 100000 euros dejo que la red neuronal haga lo que deba con ese dinero, decidiendo si quiere comprar, vender o mantener. Hay 3 formas programadas, compra a la alza, compra a la alza y a la baja y compra a la baja.

# %%
# Import predefinifods
import pandas as pd
import numpy as np
import random
from math import *
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from time import time
import matplotlib.pyplot as plt
from collections import Counter

# Importa descaga de datos
import quandl

# Import serializar
import pickle

# Import red Neuronal
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
import keras.backend as K

# Conteo
from collections import Counter

# Graficos
#plt.style.use('fivethirtyeight')
#plt.style.use('dark_background')
plt.style.use('seaborn')

# %%
# Descarga de las bases los tickets de los activos que vamos a predecir con los csv de la carpeta
def get_tickers_sample_nasdaq():
    tickers_wiki_quandl = pd.read_csv('WIKI_PRICES.csv')['ticker']
    tickers_nasdaq = pd.read_csv('nasdaq-listed-symbols.csv')['Symbol']
    
    tickersQuandl = []    
    tickers = []
    for i in range(len(tickers_nasdaq)):
        word = tickers_nasdaq[i]
        for j in range(len(tickers_wiki_quandl)):
            if word == tickers_wiki_quandl[j]:
                tickers.append(word)
    
    tickers = random.choices(tickers, k=15)
    
    for tick in tickers:
        tickersQuandl.append("WIKI/"+tick)
    
    return tickers, tickersQuandl

# a,b = get_tickers_sample_nasdaq()

# %%
# Descargo de los datos con la API Quandl y la key propia
# Las fechas estan elegidas a convinencia para poder concatenar las fechas y que quede de seguido

def get_data(verbose):
    quandl.ApiConfig.api_key = 'WgQVD8Npfox1MN7SV3Nm'
    tickers, tickersQuandl = get_tickers_sample_nasdaq()
    
    if verbose: print(" ****Empezamos a descargar los datos****\n")
    
    datos = {}
    start_time = time()
    long = len(tickersQuandl)
    i = 0

    for ticker in tickersQuandl:
        if i % 2 == 0 and verbose: print("LLeva descargados el ",i/long *100,"% de los datos")
        #aux=quandl.get(ticker,start_date="2000-01-01",end_date="2016-12-31")
        aux=quandl.get(ticker,start_date="2010-01-01",end_date="2016-12-31")
        datos[ticker[5:len(ticker)]] = aux
        i = i + 1
    
    datosClose = {}
    for key in datos:
        datosClose[key] = datos[key]["Adj. Close"]
    
    elapsed_time = time() - start_time
    if verbose: print("\nHa tardado en descargar los datos: %0.10f segundos." % elapsed_time)
    
    if verbose: print("\n ****Empezamos a descargar los datos test****\n")
    
    # Procedo a hacer las mismas operaciones para el conjunto TEST
    datos_test = {}
    i = 0
    long = len(tickersQuandl)
    start_time = time()    
    for ticker in tickersQuandl:
        if i % 2 == 0 and verbose: print("LLeva descargados el ",i/long *100,"% de los datos test")
        aux=quandl.get(ticker,start_date="2015-12-01",end_date="2020-12-31")
        datos_test[ticker[5:len(ticker)]] = aux
        i = i + 1
    
    datosClose_test = {}
    for key in datos_test:
        datosClose_test[key] = datos_test[key]["Adj. Close"]
    
        elapsed_time = time() - start_time
    if verbose: print("\nHa tardado en descargar los datos test: %0.10f segundos." % elapsed_time)
    if verbose: print("\n")
    
    # Solo cogemos los datos que nos da la aplicacion
    # ya que hay activos que no tenemos su valor en esas fechas o tenemos muy pocos datos

    quitar = []
    for key in tickers:
        if datosClose_test[key].empty:
            if verbose == True : print("Restriccion de vacio",key) 
            datos.pop(key,None)
            datosClose.pop(key,None)
            datos_test.pop(key,None)
            datosClose_test.pop(key,None)
            quitar.append(key)
        elif len(datosClose_test[key]) < 300:
            if verbose == True :  print("Restriccion de longitud",key)
            datos.pop(key,None)
            datosClose.pop(key,None)
            datos_test.pop(key,None)
            datosClose_test.pop(key,None)
            quitar.append(key)
            
    for key in quitar:
        tickers.remove(key)
    
    # Guardamos los datos y serializamos
    pickle.dump(tickers, open("datos/tickers_nasdaq.p", "wb"))
    pickle.dump(tickersQuandl, open("datos/tickersQuandl_nasdaq.p", "wb"))
    pickle.dump(datos, open("datos/nasdaq.p", "wb"))
    pickle.dump(datosClose, open("datos/nasdaqClose.p", "wb"))
    pickle.dump(datos_test, open("datos/nasdaq_test.p", "wb"))
    pickle.dump(datosClose_test, open("datos/nasdaqClose_test.p", "wb"))
    
    return tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test

# %%
# Si los datos ya han sido descargados con esta funcion los cargo gracias a la libreria pickles
def get_data_load(verbose):
    if verbose: print(" ****Empezamos a cargar los datos****\n")
    tickers = pickle.load(open("datos/tickers_nasdaq.p", "rb" ))
    tickersQuandl = pickle.load(open("datos/tickersQuandl_nasdaq.p", "rb" ))
    datos = pickle.load(open("datos/nasdaq.p", "rb" ))
    datosClose = pickle.load(open("datos/nasdaqClose.p", "rb" ))
    if verbose: print(" ****Cargados los datos****\n")
    
    if verbose: print("\n ****Empezamos a cargar los datos test****\n")
    datos_test = pickle.load(open("datos/nasdaq_test.p", "rb" ))
    datosClose_test = pickle.load(open("datos/nasdaqClose_test.p", "rb" ))
    if verbose: print(" ****Cargados los datos test****\n")
    
    return tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test

# Para imprimir cualquier conjunto tipo Serie temporal del conjunto de datos base uso esta funcion
def plot_datos(datosClose,nombre,test):
    datosClose[nombre].plot(figsize=(12,5),grid=True)
    plt.title('{} {}\n'.format(nombre,test))
    plt.ylabel('Precio de Cierre')
    plt.xlabel('Fecha')
    plt.show()

# %%
datos_descargados = True
if datos_descargados:
    tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test= get_data_load(True)
else : 
    tickers, tickersQuandl, datos, datosClose, datos_test, datosClose_test = get_data(True)
# Out:
#  ****Empezamos a cargar los datos****
#
#  ****Cargados los datos****
#
#
#  ****Empezamos a cargar los datos test****
#
#  ****Cargados los datos test****

# %%
# Grafico un activo aleatorio que luego predecire
# Se tiene el gráfico con el que se creara el modelo y los datos sobre los que se va a testear
ran = random.randint(0,len(tickers)-1)
plot_datos(datosClose,tickers[ran],"train")
plot_datos(datosClose_test,tickers[ran],"test")

# %%
# Creacion de los atributos para la Red Neuronal Recurrente
def differences(x):
    return x[-1] - x[0]

def create_features(datosClose,days1,days2):
    X = pd.DataFrame()
    data = pd.DataFrame()
    data['Adj. Close'] = datosClose.values
    
    indices = datosClose.index
    
    X['MA_{}'.format(days1)] = data['Adj. Close'].rolling(window=days1).mean()
    X['MA_{}'.format(days2)] = data['Adj. Close'].rolling(window=days2).mean()
    X['Diferencia'] = data['Adj. Close'].rolling(window=days2).apply(differences,raw=True) 
    X = X[days2:len(X)-1].reset_index()
    X.drop(['index'], axis='columns', inplace=True)

    return X, indices[(days2+1):len(indices)]

# Creo tambien timestep de 30 dias (igual que la media movil) para la RED NEURONAL
def cut_timestep(x,y,time):
    
    Xt = []
    yt = []
    index_time = []

    for i in range(timeStep, len(x)):
        Xt.append(x[i-timeStep:i,:])
        yt.append(y.iloc[i,0])
        index_time.append(time[i])

    return np.array(Xt), np.array(yt), pd.Series(index_time)

# %%
# A parte de la creacion de atributos
index = ran
timeStep = 252 # longitud de secuencias que se hacen en cada iteracion de la red

# Extraigo los atributos de los datos y los preparo para meterlos a la red neuronal

X, ind_time = create_features(datosClose[tickers[index]],10,20)
Y = pd.DataFrame(datosClose[tickers[index]].values[21:len(datosClose[tickers[index]])])
X = X.to_numpy()

# Creamos los atributos para los datos test
ticket_uso = tickers[index]
Xtesteo, ind_time_t = create_features(datosClose_test[tickers[index]],10,20)
Ytesteo = pd.DataFrame(datosClose_test[tickers[index]].values[21:len(datosClose_test[tickers[index]])])
Xtesteo = Xtesteo.to_numpy()

X_aux = np.concatenate((X,Xtesteo),axis=0)

scaler = MinMaxScaler()
X_aux_scaled = scaler.fit_transform(X_aux)
X_scaled = X_aux_scaled[0:len(X)]
Xtesteo_scaled = X_aux_scaled[len(X):len(X_aux_scaled)]

# Creacion de los timestep
Xt, yt, index_time = cut_timestep(X_scaled,Y,ind_time)
Xtt, ytt, index_time_t = cut_timestep(Xtesteo_scaled,Ytesteo,ind_time_t)

# Split de en conjunto de prueba y entrenamiento para la red neuronal
P=yt.shape[0]
indices=np.arange(P,dtype=int)
np.random.shuffle(indices)
sequences_train=indices[0:int(P*2/3)]
sequences_test=indices[int(P*2/3):]
X_train, X_test, y_train, y_test = Xt[sequences_train],Xt[sequences_test],yt[sequences_train],yt[sequences_test]


print("Voy a predecir el activo ",ticket_uso)
# Out:
# Voy a predecir el activo  UEIC

# %%
# Calculates a successfull ratio using less relative error than a maximum
def porcentaje_margen(y_true, y_pred):
    margen = 0.05
    yy = K.sum(K.cast(K.less(K.abs((y_pred/y_true)-1.0), margen), dtype=float))
    return yy/K.cast(K.shape(y_pred)[0], dtype=float)

# %%
# Creacion de la red neural LSTM

model105 = Sequential()
model105.add(LSTM(10, input_shape=(252,3),return_sequences=True))
model105.add(LSTM(units = 5,return_sequences = False))
model105.add(Dense(1)) 
model105.compile(optimizer="adam",loss='mse',metrics=[porcentaje_margen]) 
model105.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 252, 10)           560
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 5)                 320
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 886
# Trainable params: 886
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_LSTM105 = model105.fit(X_train,
                  y_train,
                  epochs=1500,
                  verbose=1,
                  validation_data=(X_test,y_test))
# Out:
# Train on 992 samples, validate on 497 samples
# Epoch 1/1500
# 992/992 [==============================] - 15s 15ms/step - loss: 345.6437 - porcentaje_margen: 0.0000e+00 - val_loss: 320.3761 - val_porcentaje_margen: 0.0000e+00
# Epoch 2/1500
# 992/992 [==============================] - 12s 13ms/step - loss: 312.2354 - porcentaje_margen: 0.0000e+00 - val_loss: 294.6915 - val_porcentaje_margen: 0.0000e+00
# Epoch 3/1500
# 992/992 [==============================] - 13s 13ms/step - loss: 291.8982 - porcentaje_margen: 0.0000e+00 - val_loss: 277.7680 - val_porcentaje_margen: 0.0000e+00
# Epoch 4/1500
# 992/992 [==============================] - 13s 13ms/step - loss: 275.7254 - porcentaje_margen: 0.0000e+00 - val_loss: 262.8010 - val_porcentaje_margen: 0.0000e+00
# Epoch 5/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 262.0158 - porcentaje_margen: 0.0000e+00 - val_loss: 250.9947 - val_porcentaje_margen: 0.0000e+00
# Epoch 6/1500
# 992/992 [==============================] - 13s 13ms/step - loss: 251.4414 - porcentaje_margen: 0.0000e+00 - val_loss: 241.8144 - val_porcentaje_margen: 0.0000e+00
# Epoch 7/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 242.8772 - porcentaje_margen: 0.0000e+00 - val_loss: 234.0031 - val_porcentaje_margen: 0.0000e+00
# Epoch 8/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 235.3910 - porcentaje_margen: 0.0000e+00 - val_loss: 227.0054 - val_porcentaje_margen: 0.0000e+00
# Epoch 9/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 228.5580 - porcentaje_margen: 0.0000e+00 - val_loss: 220.5565 - val_porcentaje_margen: 0.0000e+00
# Epoch 10/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 222.1939 - porcentaje_margen: 0.0000e+00 - val_loss: 214.4623 - val_porcentaje_margen: 0.0000e+00
# Epoch 11/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 216.1504 - porcentaje_margen: 0.0000e+00 - val_loss: 208.6833 - val_porcentaje_margen: 0.0000e+00
# Epoch 12/1500
# 992/992 [==============================] - 11s 12ms/step - loss: 210.3948 - porcentaje_margen: 0.0000e+00 - val_loss: 203.1079 - val_porcentaje_margen: 0.0000e+00
# Epoch 13/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 204.8508 - porcentaje_margen: 0.0000e+00 - val_loss: 197.7476 - val_porcentaje_margen: 0.0000e+00
# Epoch 14/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 199.5014 - porcentaje_margen: 0.0000e+00 - val_loss: 192.5793 - val_porcentaje_margen: 0.0000e+00
# Epoch 15/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 194.3273 - porcentaje_margen: 0.0000e+00 - val_loss: 187.5759 - val_porcentaje_margen: 0.0000e+00
# Epoch 16/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 189.3069 - porcentaje_margen: 0.0000e+00 - val_loss: 182.7276 - val_porcentaje_margen: 0.0000e+00
# Epoch 17/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 184.4383 - porcentaje_margen: 0.0000e+00 - val_loss: 177.9977 - val_porcentaje_margen: 0.0000e+00
# Epoch 18/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 179.7053 - porcentaje_margen: 0.0000e+00 - val_loss: 173.3789 - val_porcentaje_margen: 0.0000e+00
# Epoch 19/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 175.0741 - porcentaje_margen: 0.0000e+00 - val_loss: 168.9295 - val_porcentaje_margen: 0.0000e+00
# Epoch 20/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 170.5792 - porcentaje_margen: 0.0000e+00 - val_loss: 164.5830 - val_porcentaje_margen: 0.0000e+00
# Epoch 21/1500
# 992/992 [==============================] - 11s 12ms/step - loss: 166.1995 - porcentaje_margen: 0.0000e+00 - val_loss: 160.3279 - val_porcentaje_margen: 0.0000e+00
# Epoch 22/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 161.9217 - porcentaje_margen: 0.0000e+00 - val_loss: 156.1804 - val_porcentaje_margen: 0.0000e+00
# Epoch 23/1500
# 992/992 [==============================] - 13s 13ms/step - loss: 157.7528 - porcentaje_margen: 0.0000e+00 - val_loss: 152.1215 - val_porcentaje_margen: 0.0000e+00
# Epoch 24/1500
# 992/992 [==============================] - 13s 13ms/step - loss: 153.6730 - porcentaje_margen: 0.0000e+00 - val_loss: 148.1796 - val_porcentaje_margen: 0.0000e+00
# Epoch 25/1500
# 992/992 [==============================] - 13s 13ms/step - loss: 149.6931 - porcentaje_margen: 0.0000e+00 - val_loss: 144.3367 - val_porcentaje_margen: 0.0000e+00
# Epoch 26/1500
# 992/992 [==============================] - 13s 13ms/step - loss: 145.8191 - porcentaje_margen: 0.0000e+00 - val_loss: 140.5541 - val_porcentaje_margen: 0.0000e+00
# Epoch 27/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 142.0212 - porcentaje_margen: 0.0000e+00 - val_loss: 136.8756 - val_porcentaje_margen: 0.0000e+00
# Epoch 28/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 138.3061 - porcentaje_margen: 0.0000e+00 - val_loss: 133.3107 - val_porcentaje_margen: 0.0000e+00
# Epoch 29/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 134.6933 - porcentaje_margen: 0.0000e+00 - val_loss: 129.8053 - val_porcentaje_margen: 0.0000e+00
# Epoch 30/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 131.1583 - porcentaje_margen: 0.0000e+00 - val_loss: 126.3767 - val_porcentaje_margen: 0.0000e+00
# Epoch 31/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 127.7023 - porcentaje_margen: 0.0000e+00 - val_loss: 123.0312 - val_porcentaje_margen: 0.0000e+00
# Epoch 32/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 124.3282 - porcentaje_margen: 0.0000e+00 - val_loss: 119.7619 - val_porcentaje_margen: 0.0000e+00
# Epoch 33/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 121.0303 - porcentaje_margen: 0.0000e+00 - val_loss: 116.5719 - val_porcentaje_margen: 0.0000e+00
# Epoch 34/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 117.8074 - porcentaje_margen: 0.0000e+00 - val_loss: 113.4619 - val_porcentaje_margen: 0.0000e+00
# Epoch 35/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 114.6641 - porcentaje_margen: 0.0000e+00 - val_loss: 110.4167 - val_porcentaje_margen: 0.0000e+00
# Epoch 36/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 111.5871 - porcentaje_margen: 0.0000e+00 - val_loss: 107.4548 - val_porcentaje_margen: 0.0000e+00
# Epoch 37/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 108.5839 - porcentaje_margen: 0.0000e+00 - val_loss: 104.5671 - val_porcentaje_margen: 0.0000e+00
# Epoch 38/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 105.6529 - porcentaje_margen: 0.0000e+00 - val_loss: 101.7447 - val_porcentaje_margen: 0.0000e+00
# Epoch 39/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 102.7938 - porcentaje_margen: 0.0000e+00 - val_loss: 98.9766 - val_porcentaje_margen: 0.0000e+00
# Epoch 40/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 99.9907 - porcentaje_margen: 0.0000e+00 - val_loss: 96.2971 - val_porcentaje_margen: 0.0000e+00
# Epoch 41/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 97.2743 - porcentaje_margen: 0.0000e+00 - val_loss: 93.6441 - val_porcentaje_margen: 0.0000e+00
# Epoch 42/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 94.5994 - porcentaje_margen: 0.0000e+00 - val_loss: 91.0888 - val_porcentaje_margen: 0.0000e+00
# Epoch 43/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 92.0074 - porcentaje_margen: 0.0000e+00 - val_loss: 88.5736 - val_porcentaje_margen: 0.0000e+00
# Epoch 44/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 89.4678 - porcentaje_margen: 0.0000e+00 - val_loss: 86.1296 - val_porcentaje_margen: 0.0000e+00
# Epoch 45/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 86.9934 - porcentaje_margen: 0.0000e+00 - val_loss: 83.7467 - val_porcentaje_margen: 0.0000e+00
# Epoch 46/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 84.5785 - porcentaje_margen: 0.0000e+00 - val_loss: 81.4274 - val_porcentaje_margen: 0.0000e+00
# Epoch 47/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 82.2321 - porcentaje_margen: 0.0000e+00 - val_loss: 79.1471 - val_porcentaje_margen: 0.0059
# Epoch 48/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 79.9237 - porcentaje_margen: 0.0010 - val_loss: 76.9625 - val_porcentaje_margen: 0.0095
# Epoch 49/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 77.6897 - porcentaje_margen: 0.0030 - val_loss: 74.8219 - val_porcentaje_margen: 0.0095
# Epoch 50/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 75.5119 - porcentaje_margen: 0.0040 - val_loss: 72.7254 - val_porcentaje_margen: 0.0115
# Epoch 51/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 73.3813 - porcentaje_margen: 0.0091 - val_loss: 70.6966 - val_porcentaje_margen: 0.0173
# Epoch 52/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 71.3145 - porcentaje_margen: 0.0161 - val_loss: 68.7069 - val_porcentaje_margen: 0.0288
# Epoch 53/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 69.2947 - porcentaje_margen: 0.0282 - val_loss: 66.7756 - val_porcentaje_margen: 0.0327
# Epoch 54/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 67.3265 - porcentaje_margen: 0.0403 - val_loss: 64.9052 - val_porcentaje_margen: 0.0425
# Epoch 55/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 65.4211 - porcentaje_margen: 0.0423 - val_loss: 63.0624 - val_porcentaje_margen: 0.0484
# Epoch 56/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 63.5515 - porcentaje_margen: 0.0494 - val_loss: 61.2913 - val_porcentaje_margen: 0.0523
# Epoch 57/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 61.7391 - porcentaje_margen: 0.0544 - val_loss: 59.5685 - val_porcentaje_margen: 0.0506
# Epoch 58/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 59.9790 - porcentaje_margen: 0.0554 - val_loss: 57.8838 - val_porcentaje_margen: 0.0564
# Epoch 59/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 58.2622 - porcentaje_margen: 0.0615 - val_loss: 56.2508 - val_porcentaje_margen: 0.0681
# Epoch 60/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 56.5943 - porcentaje_margen: 0.0645 - val_loss: 54.6641 - val_porcentaje_margen: 0.0662
# Epoch 61/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 54.9777 - porcentaje_margen: 0.0665 - val_loss: 53.1101 - val_porcentaje_margen: 0.0703
# Epoch 62/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 53.3989 - porcentaje_margen: 0.0655 - val_loss: 51.6129 - val_porcentaje_margen: 0.0798
# Epoch 63/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 51.8681 - porcentaje_margen: 0.0665 - val_loss: 50.1619 - val_porcentaje_margen: 0.0913
# Epoch 64/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 50.3843 - porcentaje_margen: 0.0716 - val_loss: 48.7479 - val_porcentaje_margen: 0.0950
# Epoch 65/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 48.9385 - porcentaje_margen: 0.0736 - val_loss: 47.3857 - val_porcentaje_margen: 0.1028
# Epoch 66/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 47.5401 - porcentaje_margen: 0.0726 - val_loss: 46.0603 - val_porcentaje_margen: 0.1028
# Epoch 67/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 46.1833 - porcentaje_margen: 0.0766 - val_loss: 44.7705 - val_porcentaje_margen: 0.1009
# Epoch 68/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 44.8650 - porcentaje_margen: 0.0756 - val_loss: 43.5233 - val_porcentaje_margen: 0.1106
# Epoch 69/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 43.5862 - porcentaje_margen: 0.0726 - val_loss: 42.3202 - val_porcentaje_margen: 0.1048
# Epoch 70/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 42.3445 - porcentaje_margen: 0.0746 - val_loss: 41.1657 - val_porcentaje_margen: 0.1106
# Epoch 71/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 41.1509 - porcentaje_margen: 0.0746 - val_loss: 40.0308 - val_porcentaje_margen: 0.1145
# Epoch 72/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 39.9901 - porcentaje_margen: 0.0756 - val_loss: 38.9308 - val_porcentaje_margen: 0.1048
# Epoch 73/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 38.8594 - porcentaje_margen: 0.0716 - val_loss: 37.8844 - val_porcentaje_margen: 0.0991
# Epoch 74/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 37.7793 - porcentaje_margen: 0.0726 - val_loss: 36.8499 - val_porcentaje_margen: 0.0991
# Epoch 75/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 36.7218 - porcentaje_margen: 0.0726 - val_loss: 35.8650 - val_porcentaje_margen: 0.0913
# Epoch 76/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 35.7080 - porcentaje_margen: 0.0726 - val_loss: 34.9045 - val_porcentaje_margen: 0.0877
# Epoch 77/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 34.7176 - porcentaje_margen: 0.0746 - val_loss: 33.9974 - val_porcentaje_margen: 0.0740
# Epoch 78/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 33.7720 - porcentaje_margen: 0.0766 - val_loss: 33.1101 - val_porcentaje_margen: 0.0759
# Epoch 79/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 32.8527 - porcentaje_margen: 0.0766 - val_loss: 32.2595 - val_porcentaje_margen: 0.0818
# Epoch 80/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 31.9701 - porcentaje_margen: 0.0806 - val_loss: 31.4315 - val_porcentaje_margen: 0.0877
# Epoch 81/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 31.1142 - porcentaje_margen: 0.0786 - val_loss: 30.6386 - val_porcentaje_margen: 0.0857
# Epoch 82/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 30.2913 - porcentaje_margen: 0.0786 - val_loss: 29.8737 - val_porcentaje_margen: 0.0779
# Epoch 83/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 29.4973 - porcentaje_margen: 0.0766 - val_loss: 29.1386 - val_porcentaje_margen: 0.0720
# Epoch 84/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 28.7350 - porcentaje_margen: 0.0776 - val_loss: 28.4260 - val_porcentaje_margen: 0.0759
# Epoch 85/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 27.9931 - porcentaje_margen: 0.0766 - val_loss: 27.7571 - val_porcentaje_margen: 0.0798
# Epoch 86/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 27.2889 - porcentaje_margen: 0.0756 - val_loss: 27.1036 - val_porcentaje_margen: 0.0779
# Epoch 87/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 26.6047 - porcentaje_margen: 0.0736 - val_loss: 26.4845 - val_porcentaje_margen: 0.0759
# Epoch 88/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 25.9564 - porcentaje_margen: 0.0726 - val_loss: 25.8722 - val_porcentaje_margen: 0.0798
# Epoch 89/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 25.3210 - porcentaje_margen: 0.0685 - val_loss: 25.3038 - val_porcentaje_margen: 0.0838
# Epoch 90/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 24.7204 - porcentaje_margen: 0.0746 - val_loss: 24.7500 - val_porcentaje_margen: 0.0762
# Epoch 91/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 24.1434 - porcentaje_margen: 0.0726 - val_loss: 24.2146 - val_porcentaje_margen: 0.0781
# Epoch 92/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 23.5845 - porcentaje_margen: 0.0796 - val_loss: 23.7124 - val_porcentaje_margen: 0.0877
# Epoch 93/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 23.0518 - porcentaje_margen: 0.0766 - val_loss: 23.2341 - val_porcentaje_margen: 0.0857
# Epoch 94/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 22.5434 - porcentaje_margen: 0.0796 - val_loss: 22.7753 - val_porcentaje_margen: 0.0838
# Epoch 95/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 22.0552 - porcentaje_margen: 0.0776 - val_loss: 22.3377 - val_porcentaje_margen: 0.0838
# Epoch 96/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 21.5888 - porcentaje_margen: 0.0716 - val_loss: 21.9196 - val_porcentaje_margen: 0.0759
# Epoch 97/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 21.1433 - porcentaje_margen: 0.0736 - val_loss: 21.5200 - val_porcentaje_margen: 0.0759
# Epoch 98/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 20.7171 - porcentaje_margen: 0.0756 - val_loss: 21.1397 - val_porcentaje_margen: 0.0720
# Epoch 99/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 20.3098 - porcentaje_margen: 0.0786 - val_loss: 20.7801 - val_porcentaje_margen: 0.0759
# Epoch 100/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 19.9204 - porcentaje_margen: 0.0806 - val_loss: 20.4439 - val_porcentaje_margen: 0.0798
# Epoch 101/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 19.5591 - porcentaje_margen: 0.0796 - val_loss: 20.1014 - val_porcentaje_margen: 0.0818
# Epoch 102/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 19.2004 - porcentaje_margen: 0.0806 - val_loss: 19.7942 - val_porcentaje_margen: 0.0779
# Epoch 103/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 18.8680 - porcentaje_margen: 0.0756 - val_loss: 19.4973 - val_porcentaje_margen: 0.0779
# Epoch 104/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 18.5464 - porcentaje_margen: 0.0766 - val_loss: 19.2272 - val_porcentaje_margen: 0.0798
# Epoch 105/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 18.2480 - porcentaje_margen: 0.0796 - val_loss: 18.9599 - val_porcentaje_margen: 0.0818
# Epoch 106/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 17.9609 - porcentaje_margen: 0.0847 - val_loss: 18.7095 - val_porcentaje_margen: 0.0896
# Epoch 107/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 17.6908 - porcentaje_margen: 0.0877 - val_loss: 18.4692 - val_porcentaje_margen: 0.0952
# Epoch 108/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 17.4297 - porcentaje_margen: 0.0907 - val_loss: 18.2521 - val_porcentaje_margen: 0.0933
# Epoch 109/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 17.1885 - porcentaje_margen: 0.0938 - val_loss: 18.0416 - val_porcentaje_margen: 0.0972
# Epoch 110/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 16.9557 - porcentaje_margen: 0.0927 - val_loss: 17.8490 - val_porcentaje_margen: 0.1011
# Epoch 111/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 16.7394 - porcentaje_margen: 0.1008 - val_loss: 17.6642 - val_porcentaje_margen: 0.1011
# Epoch 112/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 16.5329 - porcentaje_margen: 0.0998 - val_loss: 17.4934 - val_porcentaje_margen: 0.1070
# Epoch 113/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 16.3397 - porcentaje_margen: 0.1038 - val_loss: 17.3309 - val_porcentaje_margen: 0.1109
# Epoch 114/1500
# 992/992 [==============================] - 12s 12ms/step - loss: 16.1575 - porcentaje_margen: 0.1069 - val_loss: 17.1773 - val_porcentaje_margen: 0.1070
# Epoch 115/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 15.9871 - porcentaje_margen: 0.1058 - val_loss: 17.0319 - val_porcentaje_margen: 0.1052
# Epoch 116/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 15.8212 - porcentaje_margen: 0.1179 - val_loss: 16.9062 - val_porcentaje_margen: 0.1072
# Epoch 117/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 15.6735 - porcentaje_margen: 0.1220 - val_loss: 16.7791 - val_porcentaje_margen: 0.1189
# Epoch 118/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 15.5305 - porcentaje_margen: 0.1321 - val_loss: 16.6632 - val_porcentaje_margen: 0.1209
# Epoch 119/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 15.3939 - porcentaje_margen: 0.1371 - val_loss: 16.5665 - val_porcentaje_margen: 0.1287
# Epoch 120/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 15.2722 - porcentaje_margen: 0.1462 - val_loss: 16.4654 - val_porcentaje_margen: 0.1365
# Epoch 121/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 15.1557 - porcentaje_margen: 0.1522 - val_loss: 16.3702 - val_porcentaje_margen: 0.1423
# Epoch 122/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 15.0447 - porcentaje_margen: 0.1562 - val_loss: 16.2871 - val_porcentaje_margen: 0.1519
# Epoch 123/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.9448 - porcentaje_margen: 0.1603 - val_loss: 16.2063 - val_porcentaje_margen: 0.1636
# Epoch 124/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.8476 - porcentaje_margen: 0.1683 - val_loss: 16.1380 - val_porcentaje_margen: 0.1770
# Epoch 125/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.7604 - porcentaje_margen: 0.1724 - val_loss: 16.0724 - val_porcentaje_margen: 0.1770
# Epoch 126/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.6802 - porcentaje_margen: 0.1744 - val_loss: 16.0087 - val_porcentaje_margen: 0.1810
# Epoch 127/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.6025 - porcentaje_margen: 0.1804 - val_loss: 15.9544 - val_porcentaje_margen: 0.1946
# Epoch 128/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.5321 - porcentaje_margen: 0.1825 - val_loss: 15.9051 - val_porcentaje_margen: 0.2003
# Epoch 129/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.4668 - porcentaje_margen: 0.1855 - val_loss: 15.8601 - val_porcentaje_margen: 0.2061
# Epoch 130/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.4064 - porcentaje_margen: 0.1875 - val_loss: 15.8195 - val_porcentaje_margen: 0.2042
# Epoch 131/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.3508 - porcentaje_margen: 0.1915 - val_loss: 15.7826 - val_porcentaje_margen: 0.2022
# Epoch 132/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.2993 - porcentaje_margen: 0.1986 - val_loss: 15.7495 - val_porcentaje_margen: 0.2061
# Epoch 133/1500
# 992/992 [==============================] - 11s 12ms/step - loss: 14.2540 - porcentaje_margen: 0.2046 - val_loss: 15.7166 - val_porcentaje_margen: 0.2120
# Epoch 134/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.2084 - porcentaje_margen: 0.2077 - val_loss: 15.6908 - val_porcentaje_margen: 0.2139
# Epoch 135/1500
# 992/992 [==============================] - 11s 12ms/step - loss: 14.1691 - porcentaje_margen: 0.2097 - val_loss: 15.6662 - val_porcentaje_margen: 0.2159
# Epoch 136/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.1328 - porcentaje_margen: 0.2137 - val_loss: 15.6439 - val_porcentaje_margen: 0.2159
# Epoch 137/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.0985 - porcentaje_margen: 0.2188 - val_loss: 15.6259 - val_porcentaje_margen: 0.2139
# Epoch 138/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.0690 - porcentaje_margen: 0.2258 - val_loss: 15.6084 - val_porcentaje_margen: 0.2139
# Epoch 139/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.0402 - porcentaje_margen: 0.2278 - val_loss: 15.5952 - val_porcentaje_margen: 0.2139
# Epoch 140/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 14.0166 - porcentaje_margen: 0.2319 - val_loss: 15.5807 - val_porcentaje_margen: 0.2120
# Epoch 141/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.9915 - porcentaje_margen: 0.2339 - val_loss: 15.5706 - val_porcentaje_margen: 0.2120
# Epoch 142/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.9719 - porcentaje_margen: 0.2389 - val_loss: 15.5603 - val_porcentaje_margen: 0.2139
# Epoch 143/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.9516 - porcentaje_margen: 0.2379 - val_loss: 15.5542 - val_porcentaje_margen: 0.2159
# Epoch 144/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.9367 - porcentaje_margen: 0.2369 - val_loss: 15.5458 - val_porcentaje_margen: 0.2198
# Epoch 145/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.9189 - porcentaje_margen: 0.2399 - val_loss: 15.5412 - val_porcentaje_margen: 0.2256
# Epoch 146/1500
# 992/992 [==============================] - 11s 12ms/step - loss: 13.9058 - porcentaje_margen: 0.2399 - val_loss: 15.5369 - val_porcentaje_margen: 0.2276
# Epoch 147/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8939 - porcentaje_margen: 0.2440 - val_loss: 15.5333 - val_porcentaje_margen: 0.2276
# Epoch 148/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8824 - porcentaje_margen: 0.2450 - val_loss: 15.5305 - val_porcentaje_margen: 0.2237
# Epoch 149/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8722 - porcentaje_margen: 0.2440 - val_loss: 15.5287 - val_porcentaje_margen: 0.2217
# Epoch 150/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8626 - porcentaje_margen: 0.2450 - val_loss: 15.5277 - val_porcentaje_margen: 0.2217
# Epoch 151/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8555 - porcentaje_margen: 0.2480 - val_loss: 15.5270 - val_porcentaje_margen: 0.2237
# Epoch 152/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8473 - porcentaje_margen: 0.2490 - val_loss: 15.5269 - val_porcentaje_margen: 0.2217
# Epoch 153/1500
# 992/992 [==============================] - 11s 12ms/step - loss: 13.8418 - porcentaje_margen: 0.2480 - val_loss: 15.5272 - val_porcentaje_margen: 0.2217
# Epoch 154/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8358 - porcentaje_margen: 0.2480 - val_loss: 15.5278 - val_porcentaje_margen: 0.2220
# Epoch 155/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8305 - porcentaje_margen: 0.2500 - val_loss: 15.5288 - val_porcentaje_margen: 0.2220
# Epoch 156/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8268 - porcentaje_margen: 0.2520 - val_loss: 15.5298 - val_porcentaje_margen: 0.2239
# Epoch 157/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8219 - porcentaje_margen: 0.2560 - val_loss: 15.5313 - val_porcentaje_margen: 0.2239
# Epoch 158/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8190 - porcentaje_margen: 0.2560 - val_loss: 15.5328 - val_porcentaje_margen: 0.2278
# Epoch 159/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8162 - porcentaje_margen: 0.2581 - val_loss: 15.5349 - val_porcentaje_margen: 0.2298
# Epoch 160/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8129 - porcentaje_margen: 0.2591 - val_loss: 15.5362 - val_porcentaje_margen: 0.2298
# Epoch 161/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8107 - porcentaje_margen: 0.2611 - val_loss: 15.5382 - val_porcentaje_margen: 0.2298
# Epoch 162/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8085 - porcentaje_margen: 0.2611 - val_loss: 15.5399 - val_porcentaje_margen: 0.2278
# Epoch 163/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8067 - porcentaje_margen: 0.2611 - val_loss: 15.5419 - val_porcentaje_margen: 0.2298
# Epoch 164/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8062 - porcentaje_margen: 0.2611 - val_loss: 15.5432 - val_porcentaje_margen: 0.2298
# Epoch 165/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8036 - porcentaje_margen: 0.2621 - val_loss: 15.5454 - val_porcentaje_margen: 0.2298
# Epoch 166/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8030 - porcentaje_margen: 0.2661 - val_loss: 15.5484 - val_porcentaje_margen: 0.2356
# Epoch 167/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8016 - porcentaje_margen: 0.2671 - val_loss: 15.5502 - val_porcentaje_margen: 0.2356
# Epoch 168/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8008 - porcentaje_margen: 0.2681 - val_loss: 15.5517 - val_porcentaje_margen: 0.2356
# Epoch 169/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8003 - porcentaje_margen: 0.2681 - val_loss: 15.5529 - val_porcentaje_margen: 0.2376
# Epoch 170/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.7999 - porcentaje_margen: 0.2671 - val_loss: 15.5559 - val_porcentaje_margen: 0.2376
# Epoch 171/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.7991 - porcentaje_margen: 0.2681 - val_loss: 15.5563 - val_porcentaje_margen: 0.2376
# Epoch 172/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7992 - porcentaje_margen: 0.2681 - val_loss: 15.5580 - val_porcentaje_margen: 0.2376
# Epoch 173/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7987 - porcentaje_margen: 0.2681 - val_loss: 15.5584 - val_porcentaje_margen: 0.2376
# Epoch 174/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7980 - porcentaje_margen: 0.2692 - val_loss: 15.5608 - val_porcentaje_margen: 0.2376
# Epoch 175/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7980 - porcentaje_margen: 0.2702 - val_loss: 15.5605 - val_porcentaje_margen: 0.2376
# Epoch 176/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7978 - porcentaje_margen: 0.2692 - val_loss: 15.5630 - val_porcentaje_margen: 0.2435
# Epoch 177/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7974 - porcentaje_margen: 0.2692 - val_loss: 15.5628 - val_porcentaje_margen: 0.2435
# Epoch 178/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7976 - porcentaje_margen: 0.2692 - val_loss: 15.5663 - val_porcentaje_margen: 0.2435
# Epoch 179/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7972 - porcentaje_margen: 0.2692 - val_loss: 15.5654 - val_porcentaje_margen: 0.2435
# Epoch 180/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7971 - porcentaje_margen: 0.2712 - val_loss: 15.5673 - val_porcentaje_margen: 0.2454
# Epoch 181/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7971 - porcentaje_margen: 0.2702 - val_loss: 15.5671 - val_porcentaje_margen: 0.2454
# Epoch 182/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7968 - porcentaje_margen: 0.2742 - val_loss: 15.5698 - val_porcentaje_margen: 0.2454
# Epoch 183/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7980 - porcentaje_margen: 0.2772 - val_loss: 15.5725 - val_porcentaje_margen: 0.2474
# Epoch 184/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7974 - porcentaje_margen: 0.2742 - val_loss: 15.5691 - val_porcentaje_margen: 0.2454
# Epoch 185/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7973 - porcentaje_margen: 0.2752 - val_loss: 15.5691 - val_porcentaje_margen: 0.2454
# Epoch 186/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7965 - porcentaje_margen: 0.2752 - val_loss: 15.5712 - val_porcentaje_margen: 0.2474
# Epoch 187/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7968 - porcentaje_margen: 0.2762 - val_loss: 15.5702 - val_porcentaje_margen: 0.2454
# Epoch 188/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7972 - porcentaje_margen: 0.2772 - val_loss: 15.5738 - val_porcentaje_margen: 0.2474
# Epoch 189/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7961 - porcentaje_margen: 0.2772 - val_loss: 15.5730 - val_porcentaje_margen: 0.2474
# Epoch 190/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7967 - porcentaje_margen: 0.2772 - val_loss: 15.5743 - val_porcentaje_margen: 0.2474
# Epoch 191/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7970 - porcentaje_margen: 0.2772 - val_loss: 15.5733 - val_porcentaje_margen: 0.2474
# Epoch 192/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7966 - porcentaje_margen: 0.2772 - val_loss: 15.5718 - val_porcentaje_margen: 0.2474
# Epoch 193/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7962 - porcentaje_margen: 0.2762 - val_loss: 15.5723 - val_porcentaje_margen: 0.2474
# Epoch 194/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7970 - porcentaje_margen: 0.2772 - val_loss: 15.5716 - val_porcentaje_margen: 0.2474
# Epoch 195/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7962 - porcentaje_margen: 0.2772 - val_loss: 15.5750 - val_porcentaje_margen: 0.2474
# Epoch 196/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7970 - porcentaje_margen: 0.2772 - val_loss: 15.5754 - val_porcentaje_margen: 0.2474
# Epoch 197/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7962 - porcentaje_margen: 0.2772 - val_loss: 15.5743 - val_porcentaje_margen: 0.2474
# Epoch 198/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7963 - porcentaje_margen: 0.2772 - val_loss: 15.5744 - val_porcentaje_margen: 0.2474
# Epoch 199/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7970 - porcentaje_margen: 0.2772 - val_loss: 15.5738 - val_porcentaje_margen: 0.2474
# Epoch 200/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7967 - porcentaje_margen: 0.2772 - val_loss: 15.5758 - val_porcentaje_margen: 0.2474
# Epoch 201/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7968 - porcentaje_margen: 0.2772 - val_loss: 15.5732 - val_porcentaje_margen: 0.2474
# Epoch 202/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7977 - porcentaje_margen: 0.2762 - val_loss: 15.5739 - val_porcentaje_margen: 0.2474
# Epoch 203/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7969 - porcentaje_margen: 0.2772 - val_loss: 15.5742 - val_porcentaje_margen: 0.2474
# Epoch 204/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7971 - porcentaje_margen: 0.2772 - val_loss: 15.5781 - val_porcentaje_margen: 0.2454
# Epoch 205/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7965 - porcentaje_margen: 0.2772 - val_loss: 15.5783 - val_porcentaje_margen: 0.2454
# Epoch 206/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.7972 - porcentaje_margen: 0.2772 - val_loss: 15.5736 - val_porcentaje_margen: 0.2474
# Epoch 207/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.8000 - porcentaje_margen: 0.2772 - val_loss: 15.5806 - val_porcentaje_margen: 0.2474
# Epoch 208/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7967 - porcentaje_margen: 0.2772 - val_loss: 15.5769 - val_porcentaje_margen: 0.2454
# Epoch 209/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7974 - porcentaje_margen: 0.2772 - val_loss: 15.5745 - val_porcentaje_margen: 0.2474
# Epoch 210/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.7965 - porcentaje_margen: 0.2772 - val_loss: 15.5769 - val_porcentaje_margen: 0.2454
# Epoch 211/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.7968 - porcentaje_margen: 0.2772 - val_loss: 15.5753 - val_porcentaje_margen: 0.2474
# Epoch 212/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7976 - porcentaje_margen: 0.2762 - val_loss: 15.5725 - val_porcentaje_margen: 0.2474
# Epoch 213/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7963 - porcentaje_margen: 0.2772 - val_loss: 15.5740 - val_porcentaje_margen: 0.2474
# Epoch 214/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7971 - porcentaje_margen: 0.2772 - val_loss: 15.5782 - val_porcentaje_margen: 0.2454
# Epoch 215/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7971 - porcentaje_margen: 0.2772 - val_loss: 15.5787 - val_porcentaje_margen: 0.2474
# Epoch 216/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.7972 - porcentaje_margen: 0.2772 - val_loss: 15.5789 - val_porcentaje_margen: 0.2474
# Epoch 217/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7971 - porcentaje_margen: 0.2772 - val_loss: 15.5783 - val_porcentaje_margen: 0.2454
# Epoch 218/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7969 - porcentaje_margen: 0.2772 - val_loss: 15.5748 - val_porcentaje_margen: 0.2474
# Epoch 219/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.7966 - porcentaje_margen: 0.2772 - val_loss: 15.5737 - val_porcentaje_margen: 0.2474
# Epoch 220/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7974 - porcentaje_margen: 0.2772 - val_loss: 15.5775 - val_porcentaje_margen: 0.2454
# Epoch 221/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7975 - porcentaje_margen: 0.2782 - val_loss: 15.5731 - val_porcentaje_margen: 0.2474
# Epoch 222/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7970 - porcentaje_margen: 0.2772 - val_loss: 15.5776 - val_porcentaje_margen: 0.2454
# Epoch 223/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7967 - porcentaje_margen: 0.2772 - val_loss: 15.5737 - val_porcentaje_margen: 0.2474
# Epoch 224/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7972 - porcentaje_margen: 0.2772 - val_loss: 15.5785 - val_porcentaje_margen: 0.2474
# Epoch 225/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7974 - porcentaje_margen: 0.2772 - val_loss: 15.5783 - val_porcentaje_margen: 0.2454
# Epoch 226/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7970 - porcentaje_margen: 0.2772 - val_loss: 15.5732 - val_porcentaje_margen: 0.2474
# Epoch 227/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7964 - porcentaje_margen: 0.2772 - val_loss: 15.5753 - val_porcentaje_margen: 0.2474
# Epoch 228/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7979 - porcentaje_margen: 0.2772 - val_loss: 15.5713 - val_porcentaje_margen: 0.2474
# Epoch 229/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7965 - porcentaje_margen: 0.2772 - val_loss: 15.5740 - val_porcentaje_margen: 0.2474
# Epoch 230/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7972 - porcentaje_margen: 0.2772 - val_loss: 15.5764 - val_porcentaje_margen: 0.2474
# Epoch 231/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7965 - porcentaje_margen: 0.2772 - val_loss: 15.5769 - val_porcentaje_margen: 0.2454
# Epoch 232/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7965 - porcentaje_margen: 0.2772 - val_loss: 15.5775 - val_porcentaje_margen: 0.2454
# Epoch 233/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7962 - porcentaje_margen: 0.2772 - val_loss: 15.5765 - val_porcentaje_margen: 0.2474
# Epoch 234/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7969 - porcentaje_margen: 0.2772 - val_loss: 15.5743 - val_porcentaje_margen: 0.2474
# Epoch 235/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7965 - porcentaje_margen: 0.2772 - val_loss: 15.5757 - val_porcentaje_margen: 0.2474
# Epoch 236/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7966 - porcentaje_margen: 0.2772 - val_loss: 15.5770 - val_porcentaje_margen: 0.2454
# Epoch 237/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7970 - porcentaje_margen: 0.2772 - val_loss: 15.5737 - val_porcentaje_margen: 0.2474
# Epoch 238/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7970 - porcentaje_margen: 0.2762 - val_loss: 15.5734 - val_porcentaje_margen: 0.2474
# Epoch 239/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7962 - porcentaje_margen: 0.2772 - val_loss: 15.5762 - val_porcentaje_margen: 0.2474
# Epoch 240/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7978 - porcentaje_margen: 0.2772 - val_loss: 15.5796 - val_porcentaje_margen: 0.2474
# Epoch 241/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7964 - porcentaje_margen: 0.2772 - val_loss: 15.5751 - val_porcentaje_margen: 0.2474
# Epoch 242/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7967 - porcentaje_margen: 0.2772 - val_loss: 15.5728 - val_porcentaje_margen: 0.2474
# Epoch 243/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7971 - porcentaje_margen: 0.2772 - val_loss: 15.5727 - val_porcentaje_margen: 0.2474
# Epoch 244/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7982 - porcentaje_margen: 0.2772 - val_loss: 15.5798 - val_porcentaje_margen: 0.2474
# Epoch 245/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7975 - porcentaje_margen: 0.2772 - val_loss: 15.5737 - val_porcentaje_margen: 0.2474
# Epoch 246/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7972 - porcentaje_margen: 0.2772 - val_loss: 15.5798 - val_porcentaje_margen: 0.2474
# Epoch 247/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 13.7967 - porcentaje_margen: 0.2772 - val_loss: 15.5776 - val_porcentaje_margen: 0.2454
# Epoch 248/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 13.7990 - porcentaje_margen: 0.2782 - val_loss: 15.5809 - val_porcentaje_margen: 0.2474
# Epoch 249/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7961 - porcentaje_margen: 0.2772 - val_loss: 15.5740 - val_porcentaje_margen: 0.2474
# Epoch 250/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 13.7955 - porcentaje_margen: 0.2772 - val_loss: 15.5684 - val_porcentaje_margen: 0.2474
# Epoch 251/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 12.9182 - porcentaje_margen: 0.2601 - val_loss: 10.6248 - val_porcentaje_margen: 0.2259
# Epoch 252/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 8.3592 - porcentaje_margen: 0.3115 - val_loss: 8.3340 - val_porcentaje_margen: 0.3778
# Epoch 253/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 7.2103 - porcentaje_margen: 0.3639 - val_loss: 7.4180 - val_porcentaje_margen: 0.4220
# Epoch 254/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 6.5291 - porcentaje_margen: 0.3891 - val_loss: 6.8267 - val_porcentaje_margen: 0.3853
# Epoch 255/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 6.0492 - porcentaje_margen: 0.3911 - val_loss: 6.3028 - val_porcentaje_margen: 0.4107
# Epoch 256/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 5.5663 - porcentaje_margen: 0.4385 - val_loss: 5.8652 - val_porcentaje_margen: 0.4498
# Epoch 257/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 5.1936 - porcentaje_margen: 0.4446 - val_loss: 5.5167 - val_porcentaje_margen: 0.4747
# Epoch 258/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 4.8122 - porcentaje_margen: 0.4819 - val_loss: 5.1386 - val_porcentaje_margen: 0.5236
# Epoch 259/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 4.3725 - porcentaje_margen: 0.5383 - val_loss: 4.8894 - val_porcentaje_margen: 0.5199
# Epoch 260/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 4.1479 - porcentaje_margen: 0.5595 - val_loss: 4.6019 - val_porcentaje_margen: 0.5350
# Epoch 261/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 3.9263 - porcentaje_margen: 0.5585 - val_loss: 4.3126 - val_porcentaje_margen: 0.5780
# Epoch 262/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 3.7249 - porcentaje_margen: 0.5615 - val_loss: 4.1490 - val_porcentaje_margen: 0.5663
# Epoch 263/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 3.5328 - porcentaje_margen: 0.5887 - val_loss: 3.9951 - val_porcentaje_margen: 0.5719
# Epoch 264/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 3.3564 - porcentaje_margen: 0.5948 - val_loss: 3.7517 - val_porcentaje_margen: 0.6164
# Epoch 265/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 3.1691 - porcentaje_margen: 0.6321 - val_loss: 3.5892 - val_porcentaje_margen: 0.6264
# Epoch 266/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 3.0417 - porcentaje_margen: 0.6341 - val_loss: 3.4841 - val_porcentaje_margen: 0.6201
# Epoch 267/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 2.8934 - porcentaje_margen: 0.6583 - val_loss: 3.3125 - val_porcentaje_margen: 0.6479
# Epoch 268/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 2.8151 - porcentaje_margen: 0.6371 - val_loss: 3.2768 - val_porcentaje_margen: 0.6491
# Epoch 269/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 2.7198 - porcentaje_margen: 0.6310 - val_loss: 3.1907 - val_porcentaje_margen: 0.6068
# Epoch 270/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 2.6197 - porcentaje_margen: 0.6542 - val_loss: 2.9671 - val_porcentaje_margen: 0.6711
# Epoch 271/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 2.5031 - porcentaje_margen: 0.6774 - val_loss: 2.8733 - val_porcentaje_margen: 0.6791
# Epoch 272/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 2.4372 - porcentaje_margen: 0.6512 - val_loss: 2.8049 - val_porcentaje_margen: 0.6843
# Epoch 273/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 2.3498 - porcentaje_margen: 0.6815 - val_loss: 2.7175 - val_porcentaje_margen: 0.6921
# Epoch 274/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 2.2614 - porcentaje_margen: 0.6925 - val_loss: 2.6139 - val_porcentaje_margen: 0.7038
# Epoch 275/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 2.1990 - porcentaje_margen: 0.6966 - val_loss: 2.6316 - val_porcentaje_margen: 0.6515
# Epoch 276/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 2.1605 - porcentaje_margen: 0.6966 - val_loss: 2.5762 - val_porcentaje_margen: 0.6608
# Epoch 277/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 2.1049 - porcentaje_margen: 0.6885 - val_loss: 2.4116 - val_porcentaje_margen: 0.7116
# Epoch 278/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 2.0241 - porcentaje_margen: 0.7046 - val_loss: 2.3467 - val_porcentaje_margen: 0.7040
# Epoch 279/1500
# 992/992 [==============================] - 10s 11ms/step - loss: 2.0041 - porcentaje_margen: 0.7056 - val_loss: 2.3388 - val_porcentaje_margen: 0.6940
# Epoch 280/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 1.9551 - porcentaje_margen: 0.6946 - val_loss: 2.2307 - val_porcentaje_margen: 0.7077
# Epoch 281/1500
# 992/992 [==============================] - 11s 11ms/step - loss: 1.9122 - porcentaje_margen: 0.7107 - val_loss: 2.2877 - val_porcentaje_margen: 0.6823
# Epoch 282/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 1.8463 - porcentaje_margen: 0.7188 - val_loss: 2.2037 - val_porcentaje_margen: 0.6633
# Epoch 283/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 1.8092 - porcentaje_margen: 0.7177 - val_loss: 2.1408 - val_porcentaje_margen: 0.7019
# Epoch 284/1500
# ...
# Epoch 1406/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2789 - porcentaje_margen: 0.9335 - val_loss: 0.3751 - val_porcentaje_margen: 0.8833
# Epoch 1407/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2787 - porcentaje_margen: 0.9405 - val_loss: 0.3895 - val_porcentaje_margen: 0.8850
# Epoch 1408/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2818 - porcentaje_margen: 0.9315 - val_loss: 0.3867 - val_porcentaje_margen: 0.8833
# Epoch 1409/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2795 - porcentaje_margen: 0.9365 - val_loss: 0.3762 - val_porcentaje_margen: 0.8811
# Epoch 1410/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2812 - porcentaje_margen: 0.9294 - val_loss: 0.3686 - val_porcentaje_margen: 0.8948
# Epoch 1411/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2816 - porcentaje_margen: 0.9304 - val_loss: 0.3863 - val_porcentaje_margen: 0.8852
# Epoch 1412/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2875 - porcentaje_margen: 0.9254 - val_loss: 0.3800 - val_porcentaje_margen: 0.8774
# Epoch 1413/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2902 - porcentaje_margen: 0.9244 - val_loss: 0.4088 - val_porcentaje_margen: 0.8637
# Epoch 1414/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2881 - porcentaje_margen: 0.9355 - val_loss: 0.3778 - val_porcentaje_margen: 0.8869
# Epoch 1415/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2787 - porcentaje_margen: 0.9365 - val_loss: 0.3884 - val_porcentaje_margen: 0.8791
# Epoch 1416/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2782 - porcentaje_margen: 0.9315 - val_loss: 0.3738 - val_porcentaje_margen: 0.8928
# Epoch 1417/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2833 - porcentaje_margen: 0.9345 - val_loss: 0.3749 - val_porcentaje_margen: 0.8928
# Epoch 1418/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2813 - porcentaje_margen: 0.9325 - val_loss: 0.3876 - val_porcentaje_margen: 0.8850
# Epoch 1419/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2873 - porcentaje_margen: 0.9294 - val_loss: 0.3766 - val_porcentaje_margen: 0.8872
# Epoch 1420/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.3079 - porcentaje_margen: 0.9244 - val_loss: 0.3965 - val_porcentaje_margen: 0.8737
# Epoch 1421/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.3024 - porcentaje_margen: 0.9204 - val_loss: 0.3871 - val_porcentaje_margen: 0.8774
# Epoch 1422/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2917 - porcentaje_margen: 0.9304 - val_loss: 0.3788 - val_porcentaje_margen: 0.8850
# Epoch 1423/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2779 - porcentaje_margen: 0.9325 - val_loss: 0.3721 - val_porcentaje_margen: 0.8909
# Epoch 1424/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2879 - porcentaje_margen: 0.9234 - val_loss: 0.3818 - val_porcentaje_margen: 0.8891
# Epoch 1425/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2908 - porcentaje_margen: 0.9274 - val_loss: 0.3712 - val_porcentaje_margen: 0.8889
# Epoch 1426/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2801 - porcentaje_margen: 0.9365 - val_loss: 0.3864 - val_porcentaje_margen: 0.8830
# Epoch 1427/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2809 - porcentaje_margen: 0.9335 - val_loss: 0.3772 - val_porcentaje_margen: 0.8872
# Epoch 1428/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2828 - porcentaje_margen: 0.9274 - val_loss: 0.3749 - val_porcentaje_margen: 0.8928
# Epoch 1429/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2775 - porcentaje_margen: 0.9294 - val_loss: 0.3676 - val_porcentaje_margen: 0.8928
# Epoch 1430/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2855 - porcentaje_margen: 0.9325 - val_loss: 0.3895 - val_porcentaje_margen: 0.8794
# Epoch 1431/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2874 - porcentaje_margen: 0.9244 - val_loss: 0.3893 - val_porcentaje_margen: 0.8813
# Epoch 1432/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.3018 - porcentaje_margen: 0.9133 - val_loss: 0.3903 - val_porcentaje_margen: 0.8833
# Epoch 1433/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2814 - porcentaje_margen: 0.9315 - val_loss: 0.4024 - val_porcentaje_margen: 0.8674
# Epoch 1434/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2842 - porcentaje_margen: 0.9264 - val_loss: 0.4082 - val_porcentaje_margen: 0.8679
# Epoch 1435/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2863 - porcentaje_margen: 0.9325 - val_loss: 0.3733 - val_porcentaje_margen: 0.8869
# Epoch 1436/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2793 - porcentaje_margen: 0.9365 - val_loss: 0.3698 - val_porcentaje_margen: 0.8987
# Epoch 1437/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2848 - porcentaje_margen: 0.9294 - val_loss: 0.4007 - val_porcentaje_margen: 0.8755
# Epoch 1438/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2973 - porcentaje_margen: 0.9274 - val_loss: 0.3682 - val_porcentaje_margen: 0.8911
# Epoch 1439/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2837 - porcentaje_margen: 0.9294 - val_loss: 0.3686 - val_porcentaje_margen: 0.8891
# Epoch 1440/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2803 - porcentaje_margen: 0.9325 - val_loss: 0.3818 - val_porcentaje_margen: 0.8774
# Epoch 1441/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2984 - porcentaje_margen: 0.9244 - val_loss: 0.3736 - val_porcentaje_margen: 0.8850
# Epoch 1442/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2899 - porcentaje_margen: 0.9274 - val_loss: 0.3748 - val_porcentaje_margen: 0.8850
# Epoch 1443/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.3008 - porcentaje_margen: 0.9204 - val_loss: 0.3696 - val_porcentaje_margen: 0.8928
# Epoch 1444/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2887 - porcentaje_margen: 0.9264 - val_loss: 0.3730 - val_porcentaje_margen: 0.8987
# Epoch 1445/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2807 - porcentaje_margen: 0.9335 - val_loss: 0.3735 - val_porcentaje_margen: 0.8909
# Epoch 1446/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2833 - porcentaje_margen: 0.9335 - val_loss: 0.4052 - val_porcentaje_margen: 0.8733
# Epoch 1447/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2874 - porcentaje_margen: 0.9315 - val_loss: 0.3667 - val_porcentaje_margen: 0.8928
# Epoch 1448/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2769 - porcentaje_margen: 0.9395 - val_loss: 0.3871 - val_porcentaje_margen: 0.8830
# Epoch 1449/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2872 - porcentaje_margen: 0.9335 - val_loss: 0.3911 - val_porcentaje_margen: 0.8791
# Epoch 1450/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2875 - porcentaje_margen: 0.9335 - val_loss: 0.3671 - val_porcentaje_margen: 0.8967
# Epoch 1451/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2909 - porcentaje_margen: 0.9335 - val_loss: 0.3725 - val_porcentaje_margen: 0.8930
# Epoch 1452/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2794 - porcentaje_margen: 0.9365 - val_loss: 0.3729 - val_porcentaje_margen: 0.8872
# Epoch 1453/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2793 - porcentaje_margen: 0.9304 - val_loss: 0.3708 - val_porcentaje_margen: 0.8948
# Epoch 1454/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2868 - porcentaje_margen: 0.9244 - val_loss: 0.3723 - val_porcentaje_margen: 0.8850
# Epoch 1455/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2763 - porcentaje_margen: 0.9335 - val_loss: 0.3683 - val_porcentaje_margen: 0.8889
# Epoch 1456/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2788 - porcentaje_margen: 0.9375 - val_loss: 0.4169 - val_porcentaje_margen: 0.8694
# Epoch 1457/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2850 - porcentaje_margen: 0.9325 - val_loss: 0.3701 - val_porcentaje_margen: 0.8967
# Epoch 1458/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2832 - porcentaje_margen: 0.9264 - val_loss: 0.3641 - val_porcentaje_margen: 0.8909
# Epoch 1459/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2773 - porcentaje_margen: 0.9315 - val_loss: 0.4136 - val_porcentaje_margen: 0.8694
# Epoch 1460/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.3012 - porcentaje_margen: 0.9214 - val_loss: 0.3893 - val_porcentaje_margen: 0.8811
# Epoch 1461/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2870 - porcentaje_margen: 0.9325 - val_loss: 0.3881 - val_porcentaje_margen: 0.8752
# Epoch 1462/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2803 - porcentaje_margen: 0.9304 - val_loss: 0.3898 - val_porcentaje_margen: 0.8811
# Epoch 1463/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2855 - porcentaje_margen: 0.9304 - val_loss: 0.3842 - val_porcentaje_margen: 0.8830
# Epoch 1464/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2830 - porcentaje_margen: 0.9264 - val_loss: 0.3860 - val_porcentaje_margen: 0.8830
# Epoch 1465/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2814 - porcentaje_margen: 0.9304 - val_loss: 0.3782 - val_porcentaje_margen: 0.8850
# Epoch 1466/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2764 - porcentaje_margen: 0.9325 - val_loss: 0.3794 - val_porcentaje_margen: 0.8850
# Epoch 1467/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2789 - porcentaje_margen: 0.9274 - val_loss: 0.3664 - val_porcentaje_margen: 0.8928
# Epoch 1468/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2890 - porcentaje_margen: 0.9304 - val_loss: 0.3765 - val_porcentaje_margen: 0.8911
# Epoch 1469/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2834 - porcentaje_margen: 0.9264 - val_loss: 0.4313 - val_porcentaje_margen: 0.8655
# Epoch 1470/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.3005 - porcentaje_margen: 0.9103 - val_loss: 0.4163 - val_porcentaje_margen: 0.8755
# Epoch 1471/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2771 - porcentaje_margen: 0.9375 - val_loss: 0.3643 - val_porcentaje_margen: 0.8967
# Epoch 1472/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2818 - porcentaje_margen: 0.9284 - val_loss: 0.3741 - val_porcentaje_margen: 0.8891
# Epoch 1473/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2929 - porcentaje_margen: 0.9173 - val_loss: 0.3696 - val_porcentaje_margen: 0.8911
# Epoch 1474/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2785 - porcentaje_margen: 0.9304 - val_loss: 0.3796 - val_porcentaje_margen: 0.8850
# Epoch 1475/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2833 - porcentaje_margen: 0.9335 - val_loss: 0.3814 - val_porcentaje_margen: 0.8869
# Epoch 1476/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2820 - porcentaje_margen: 0.9355 - val_loss: 0.3698 - val_porcentaje_margen: 0.8948
# Epoch 1477/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2808 - porcentaje_margen: 0.9284 - val_loss: 0.3698 - val_porcentaje_margen: 0.8889
# Epoch 1478/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2788 - porcentaje_margen: 0.9335 - val_loss: 0.3762 - val_porcentaje_margen: 0.8869
# Epoch 1479/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2832 - porcentaje_margen: 0.9325 - val_loss: 0.3988 - val_porcentaje_margen: 0.8772
# Epoch 1480/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2811 - porcentaje_margen: 0.9274 - val_loss: 0.3647 - val_porcentaje_margen: 0.8928
# Epoch 1481/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2745 - porcentaje_margen: 0.9355 - val_loss: 0.3683 - val_porcentaje_margen: 0.8948
# Epoch 1482/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2849 - porcentaje_margen: 0.9294 - val_loss: 0.3670 - val_porcentaje_margen: 0.8928
# Epoch 1483/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2777 - porcentaje_margen: 0.9315 - val_loss: 0.3893 - val_porcentaje_margen: 0.8713
# Epoch 1484/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2830 - porcentaje_margen: 0.9315 - val_loss: 0.3724 - val_porcentaje_margen: 0.8928
# Epoch 1485/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2824 - porcentaje_margen: 0.9325 - val_loss: 0.3681 - val_porcentaje_margen: 0.8909
# Epoch 1486/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2821 - porcentaje_margen: 0.9304 - val_loss: 0.3853 - val_porcentaje_margen: 0.8869
# Epoch 1487/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2737 - porcentaje_margen: 0.9385 - val_loss: 0.3708 - val_porcentaje_margen: 0.8928
# Epoch 1488/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2761 - porcentaje_margen: 0.9325 - val_loss: 0.3843 - val_porcentaje_margen: 0.8889
# Epoch 1489/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2743 - porcentaje_margen: 0.9355 - val_loss: 0.3771 - val_porcentaje_margen: 0.8889
# Epoch 1490/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2775 - porcentaje_margen: 0.9325 - val_loss: 0.3764 - val_porcentaje_margen: 0.8869
# Epoch 1491/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2767 - porcentaje_margen: 0.9294 - val_loss: 0.3685 - val_porcentaje_margen: 0.8928
# Epoch 1492/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2776 - porcentaje_margen: 0.9194 - val_loss: 0.3709 - val_porcentaje_margen: 0.8850
# Epoch 1493/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2761 - porcentaje_margen: 0.9355 - val_loss: 0.3759 - val_porcentaje_margen: 0.8889
# Epoch 1494/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2815 - porcentaje_margen: 0.9315 - val_loss: 0.3731 - val_porcentaje_margen: 0.8889
# Epoch 1495/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2776 - porcentaje_margen: 0.9315 - val_loss: 0.3700 - val_porcentaje_margen: 0.8928
# Epoch 1496/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2740 - porcentaje_margen: 0.9325 - val_loss: 0.3679 - val_porcentaje_margen: 0.8909
# Epoch 1497/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2782 - porcentaje_margen: 0.9304 - val_loss: 0.3648 - val_porcentaje_margen: 0.8928
# Epoch 1498/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2897 - porcentaje_margen: 0.9284 - val_loss: 0.3689 - val_porcentaje_margen: 0.8928
# Epoch 1499/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2771 - porcentaje_margen: 0.9325 - val_loss: 0.3783 - val_porcentaje_margen: 0.8850
# Epoch 1500/1500
# 992/992 [==============================] - 10s 10ms/step - loss: 0.2758 - porcentaje_margen: 0.9355 - val_loss: 0.3658 - val_porcentaje_margen: 0.8967

# %% [markdown]
# #### Si vemos que necesitamos mas epocas corremos este codigo
# history_LSTM = model.fit(X_train,
#                   y_train,
#                   initial_epoch=700,
#                   epochs=1500,
#                   verbose=1,
#                   validation_data=(X_test,y_test))

# %%
plt.plot(history_LSTM105.epoch,history_LSTM105.history['val_porcentaje_margen'],label='validation')
plt.plot(history_LSTM105.epoch,history_LSTM105.history['porcentaje_margen'],label="training")
plt.legend()
plt.title('Success Rate Evolution')
plt.xlabel('Epocs')
plt.show()

# %%
# Calculo la prediccion para mi conjunto test
predicted_stock_price = pd.DataFrame(model.predict(Xtt))

# Junto la grafica de los datos de entrenamiento y test para ver cuanto a variado en terminos generales
indicedetiempo = pd.concat((index_time,index_time_t), axis = 0)
yt = pd.DataFrame(yt) ; ytt = pd.DataFrame(ytt)
stock_real_value = pd.concat((yt,ytt),axis = 0)

# Calculo el RMSE para ver el error de prediccion
rmse = sqrt(mean_squared_error(ytt, predicted_stock_price))

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15, 5))
fig.suptitle(tickers[index],fontsize = 20)
# Plot de todo el grafico
ax1.plot(indicedetiempo,stock_real_value,label="Valor Real",color = "blue")
ax1.plot(index_time_t,predicted_stock_price, label="Valor Predicho", color = "black")
ax1.legend()

# Plot de solo la parte que hemos hecho el predict
ax2.plot(index_time_t,ytt,label="Valor Real",color = "blue")
ax2.plot(index_time_t,predicted_stock_price, label="Valor Predicho", color = "black")
ax2.legend()
ax2.annotate('RMSE = %.2f'% rmse, (index_time_t[40], ytt.iloc[40]), xytext=(50, 50), 
            textcoords='offset points',fontsize = 15)

plt.show()

# %% [markdown]
# Queremos realizar una inversion de 100000 euros en el activo que hemos estudiado, nos basamos en un margen entre la diferencia de los dos precios adyacentes para saber si comprar, vender o mantener.
# Tenemos 3 posibles caminos, comprar solo a la alza, comprar solo a la baja o comprar a la alza y a la baja.
# Ciertos actios tienen caidas o subidas muy bruscas imposibles de predecir porque no tienen que ver con los datos historicos si no con la situacion y el contexto que vive la empresa

# %%
pd.options.display.max_rows = 10000 # Para poder ver todos los movimientos

# Es un margen movil, segun lo que busquemos
margen = 0.0005
diferencias = np.zeros(len(predicted_stock_price)-1)
for i in range(len(diferencias)):
    diferencias[i] = (predicted_stock_price.iloc[i+1,0]-predicted_stock_price.iloc[i,0])/max(predicted_stock_price.iloc[i+1,0],predicted_stock_price.iloc[i,0])
    if diferencias[i] > margen:
        diferencias[i] = 1
    elif diferencias[i] < -margen:
        diferencias[i] = -1
    else:
        diferencias[i] = 0
    
print(Counter(diferencias))
# Out:
# Counter({0.0: 120, 1.0: 100, -1.0: 89})

# %%
# Si solo queremos comrpar a la alza
# Estado es lo que hay que hacer ese dia
# estado = 1 comprar, estado = 0 mantener, estado = -1 vender
movimientos_alza = pd.DataFrame(columns = ["presupuesto","acciones","estado","valor","pred","dif"],index = index_time_t)
movimientos_alza.presupuesto[0] = 100000 ; movimientos_alza.acciones[0] = 0 ; movimientos_alza.estado[0] = 0
movimientos_alza.valor[0] = ytt.iloc[0,0] ; movimientos_alza.pred[0] = predicted_stock_price.iloc[0,0]

for i in range(1,len(diferencias)):
    if diferencias[i] == 1:
        if movimientos_alza.acciones[i-1] == 0:
            movimientos_alza.estado[i] = 1
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1] % ytt.iloc[i,0]
            movimientos_alza.acciones[i] = movimientos_alza.presupuesto[i-1] // ytt.iloc[i,0]
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]
        else:
            movimientos_alza.estado[i] = 0
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1]
            movimientos_alza.acciones[i] = movimientos_alza.acciones[i-1]
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]
    elif diferencias[i] == 0:
            movimientos_alza.estado[i] = 0
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1]
            movimientos_alza.acciones[i] = movimientos_alza.acciones[i-1]
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]
    elif diferencias[i] == -1:
        if movimientos_alza.acciones[i-1] > 0:
            movimientos_alza.estado[i] = -1
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1] + movimientos_alza.acciones[i-1] * ytt.iloc[i,0]
            movimientos_alza.acciones[i] = 0
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]
        else:
            movimientos_alza.estado[i] = 0
            movimientos_alza.presupuesto[i] = movimientos_alza.presupuesto[i-1]
            movimientos_alza.acciones[i] = movimientos_alza.acciones[i-1]
            movimientos_alza.valor[i] = ytt.iloc[i,0]
            movimientos_alza.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_alza.dif[i] = diferencias[i]

            
movimientos_alza = movimientos_alza.drop(movimientos_alza.tail(1).index)
print(movimientos_alza.tail(1))
valor_f_alza = movimientos_alza.presupuesto[len(movimientos_alza)-1] + movimientos_alza.valor[len(movimientos_alza)-1] * movimientos_alza.acciones[len(movimientos_alza)-1]
ganancia_alza = valor_f_alza - 100000
print('Valor Final = %.2f' % valor_f_alza)
print('Ganancia con margen = %.2f' % ganancia_alza)
# Out:
#            presupuesto acciones estado  valor     pred dif
# 2018-03-26      128633        0      0  29.81  28.2798  -1
# Valor Final = 128633.35
# Ganancia con margen = 28633.35

# %%
print(movimientos_alza)
# Out:
#            presupuesto acciones estado  valor     pred  dif
# 2016-12-30      100000        0      0  53.58  56.3008  NaN
# 2017-01-03       44.29     1791      1  55.81  56.4817    1
# 2017-01-04      101236        0     -1   56.5  56.5125   -1
# 2017-01-05        1.72     1847      1  54.81  56.4124    1
# 2017-01-06      100996        0     -1  54.68  56.7544   -1
# 2017-01-09      100996        0      0  53.22  56.1689   -1
# 2017-01-10      100996        0      0   52.9  55.5546   -1
# 2017-01-11      100996        0      0  54.45  54.1805   -1
# 2017-01-12       27.54     1913      1  52.78  53.7514    1
# 2017-01-13       27.54     1913      0   53.7  53.8374    1
# 2017-01-17      103330        0     -1     54  54.3208   -1
# 2017-01-18       26.06     1918      1  53.86   54.298    1
# 2017-01-19      102198        0     -1  53.27  54.6275   -1
# 2017-01-20       22.61     1871      1  54.61  54.5827    1
# 2017-01-23       22.61     1871      0   54.9  54.8517    1
# 2017-01-24       22.61     1871      0  56.89  55.4445    1
# 2017-01-25       22.61     1871      0  59.86  55.8165    1
# 2017-01-26       22.61     1871      0  58.14  56.9293    1
# 2017-01-27       22.61     1871      0  54.36  58.0822    1
# 2017-01-30      105753        0     -1  56.51  58.7964   -1
# 2017-01-31      105753        0      0  56.38  57.2486   -1
# 2017-02-01      105753        0      0   56.7  56.6933   -1
# 2017-02-02      105753        0      0  56.51  55.8274   -1
# 2017-02-03       27.57     1863      1  56.75  55.3866    1
# 2017-02-06       27.57     1863      0  56.98   56.136    1
# 2017-02-07       27.57     1863      0  56.71  57.1396    1
# 2017-02-08       27.57     1863      0  56.41  58.4232    1
# 2017-02-09      105119        0     -1  56.41  59.1211   -1
# 2017-02-10      105119        0      0  56.31  58.4565   -1
# 2017-02-13      105119        0      0  56.93  58.1953   -1
# 2017-02-14      105119        0      0  57.01  57.8296   -1
# 2017-02-15       28.95     1835      1  57.27  57.8086    1
# 2017-02-16       28.95     1835      0  57.85   58.073    1
# 2017-02-17       28.95     1835      0  58.87  58.6656    1
# 2017-02-21       28.95     1835      0   58.2  58.8447    1
# 2017-02-22      104073        0     -1   56.7  59.1604   -1
# 2017-02-23      104073        0      0  56.04  58.4506   -1
# 2017-02-24      104073        0      0  55.55  56.1562   -1
# 2017-02-27       24.97     1864      1  55.82  55.2682    1
# 2017-02-28       24.97     1864      0  53.15  56.7994    1
# 2017-03-01      100196        0     -1  53.74  57.6974   -1
# 2017-03-02      100196        0      0  52.28  56.9975   -1
# 2017-03-03      100196        0      0  50.88  56.1926   -1
# 2017-03-06      100196        0      0  50.54  55.1936   -1
# 2017-03-07      100196        0      0  49.99  53.9967   -1
# 2017-03-08      100196        0      0  50.37  53.1379   -1
# 2017-03-09       45.87     1982      1  50.53  52.6684    1
# 2017-03-10       45.87     1982      0  51.03  52.7849    1
# 2017-03-13       45.87     1982      0  49.89  52.9575    1
# 2017-03-14     98016.1        0     -1  49.43  53.1466   -1
# 2017-03-15     98016.1        0      0  49.55  52.2577   -1
# 2017-03-16     98016.1        0      0  50.29   51.164   -1
# 2017-03-17     98016.1        0      0  50.71  50.4096   -1
# 2017-03-20     98016.1        0      0   51.5  50.1754   -1
# 2017-03-21           3     2063      1  47.51  49.9451    1
# 2017-03-22      100698        0     -1  48.81  50.4641   -1
# 2017-03-23       32.75     2032      1  49.54  49.6774    1
# 2017-03-24       32.75     2032      0  49.18   49.683    1
# 2017-03-27      100596        0     -1  49.49  50.1991   -1
# 2017-03-28        29.7     2057      1  48.89  50.0583    1
# 2017-03-29      100864        0     -1  49.02  50.8375   -1
# 2017-03-30       22.54     2029      1   49.7  50.6261    1
# 2017-03-31       22.54     2029      0  49.51  50.6669    1
# 2017-04-03       22.54     2029      0   48.8  51.2978    1
# 2017-04-04     98855.1        0     -1  48.71  51.4834   -1
# 2017-04-05     98855.1        0      0  48.06   51.061   -1
# 2017-04-06     98855.1        0      0  49.31  50.3386   -1
# 2017-04-07     98855.1        0      0  50.93  49.4669   -1
# 2017-04-10       31.73     1910      1  51.74  49.3258    1
# 2017-04-11       31.73     1910      0   51.8  50.6113    1
# 2017-04-12       31.73     1910      0   50.6  52.0234    1
# 2017-04-13     95550.8        0     -1  50.01  52.6119   -1
# 2017-04-17     95550.8        0      0  50.97  51.7607   -1
# 2017-04-18     95550.8        0      0  50.47  50.4633   -1
# 2017-04-19       30.05     1893      1  50.46  49.8705    1
# 2017-04-20       30.05     1893      0   51.1  51.3053    1
# 2017-04-21       30.05     1893      0  50.76  52.0004    1
# 2017-04-24     97898.1        0     -1   51.7  52.1448   -1
# 2017-04-25       16.13     1863      1  52.54  52.0412    1
# 2017-04-26       16.13     1863      0   52.5  52.1351    1
# 2017-04-27       16.13     1863      0  52.87  52.7796    1
# 2017-04-28      102053        0     -1  54.77  53.1361   -1
# 2017-05-01       10.34     1902      1  53.65  53.1203    1
# 2017-05-02       10.34     1902      0  53.69  53.8839    1
# 2017-05-03       10.34     1902      0  53.52  54.3219    1
# 2017-05-04       10.34     1902      0  53.27  54.5392    1
# 2017-05-05      104468        0     -1  54.92  54.8081   -1
# 2017-05-08      104468        0      0  54.91  54.4219   -1
# 2017-05-09      104468        0      0  57.11  54.2084   -1
# 2017-05-10       23.43     1825      1  57.23  54.0261    1
# 2017-05-11       23.43     1825      0  57.32  55.0141    1
# 2017-05-12       23.43     1825      0  56.15  56.5096    1
# 2017-05-15      102734        0     -1  56.28  57.7756   -1
# 2017-05-16      102734        0      0  56.26  57.5856   -1
# 2017-05-17      102734        0      0  54.58  57.2905   -1
# 2017-05-18      102734        0      0  54.91  57.1665   -1
# 2017-05-19      102734        0      0  55.69  56.4086   -1
# 2017-05-22       15.33     1831      1   56.1  56.2994    1
# 2017-05-23       15.33     1831      0  55.77  56.5487    1
# 2017-05-24       15.33     1831      0  56.05   56.811    1
# 2017-05-25       15.33     1831      0     56  56.9618    1
# 2017-05-26      101068        0     -1  55.19  57.0658   -1
# 2017-05-30      101068        0      0   56.4   56.449   -1
# 2017-05-31        4.58     1819      1  55.56  56.1915    1
# 2017-06-01        4.58     1819      0  57.72  56.7676    1
# 2017-06-02        4.58     1819      0  57.53  57.1501    1
# 2017-06-05        4.58     1819      0   57.8  58.3158    1
# 2017-06-06      105798        0     -1  58.16  58.5218   -1
# 2017-06-07      105798        0      0  60.82  58.4762   -1
# 2017-06-08       42.12     1646      1  64.25  57.7293    1
# 2017-06-09       42.12     1646      0  59.66  58.2839    1
# 2017-06-12       42.12     1646      0  58.79  60.3704    1
# 2017-06-13     89156.6        0     -1  54.14  60.8667   -1
# 2017-06-14     89156.6        0      0  52.25  60.2898   -1
# 2017-06-15     89156.6        0      0  52.89  57.7694   -1
# 2017-06-16     89156.6        0      0  52.27  55.8583   -1
# 2017-06-19     89156.6        0      0  54.35  55.4463   -1
# 2017-06-20       43.69     1617      1  55.11  55.3582    1
# 2017-06-21       43.69     1617      0  58.04  56.2275    1
# 2017-06-22       43.69     1617      0  59.55  57.3471    1
# 2017-06-23       43.69     1617      0  59.99  58.8666    1
# 2017-06-26       43.69     1617      0  58.36  60.0834    1
# 2017-06-27     89932.7        0     -1  55.59   60.864   -1
# 2017-06-28     89932.7        0      0  55.82  59.8591   -1
# 2017-06-29     89932.7        0      0  52.86  57.8739   -1
# 2017-06-30     89932.7        0      0  51.71  55.9075   -1
# 2017-07-03     89932.7        0      0  51.95  54.1187   -1
# 2017-07-05       13.72     1746      1   51.5  53.1571    1
# 2017-07-06     88518.5        0     -1  50.69  53.2533   -1
# 2017-07-07     88518.5        0      0  50.86  52.5533   -1
# 2017-07-10        3.46     1686      1   52.5  50.3839    1
# 2017-07-11        3.46     1686      0  52.66  51.2176    1
# 2017-07-12        3.46     1686      0  54.24  53.2316    1
# 2017-07-13        3.46     1686      0  54.47  56.0528    1
# 2017-07-14        3.46     1686      0  55.09  58.4431    1
# 2017-07-17       89058        0     -1  52.82  58.7618   -1
# 2017-07-18       89058        0      0  52.81  58.1861   -1
# 2017-07-19       89058        0      0   54.5  55.4524   -1
# 2017-07-20       89058        0      0  54.14  53.0101   -1
# 2017-07-21       89058        0      0  53.39  51.6197   -1
# 2017-07-24       89058        0      0  53.84   50.903   -1
# 2017-07-25       28.47     1649      1  53.99  50.7258    1
# 2017-07-26       28.47     1649      0  53.93  51.9995    1
# 2017-07-27       28.47     1649      0  56.31  54.2358    1
# 2017-07-28       28.47     1649      0  54.05   55.335    1
# 2017-07-31       28.47     1649      0  52.61  57.3553    1
# 2017-08-01     88926.1        0     -1  53.91  57.8127   -1
# 2017-08-02     88926.1        0      0  51.52  56.5651   -1
# 2017-08-03     88926.1        0      0  50.67  55.8399   -1
# 2017-08-04     88926.1        0      0  45.32  54.7761   -1
# 2017-08-07     88926.1        0      0  44.88  53.6545   -1
# 2017-08-08     88926.1        0      0  42.56  50.1518   -1
# 2017-08-09     88926.1        0      0  42.56  47.8339   -1
# 2017-08-10     88926.1        0      0  40.27  45.6042   -1
# 2017-08-11     88926.1        0      0  40.89  44.9585   -1
# 2017-08-14       22.62     2133      1  41.68  43.7969    1
# 2017-08-15       22.62     2133      0  42.02  44.6067    1
# 2017-08-16     90056.5        0     -1  42.21  45.5541   -1
# 2017-08-17     90056.5        0      0   40.5  44.9735   -1
# 2017-08-18     90056.5        0      0  40.36  44.1849   -1
# 2017-08-21     90056.5        0      0  39.35  42.8075   -1
# 2017-08-22     90056.5        0      0  40.29  41.4664   -1
# 2017-08-23     90056.5        0      0  39.74  40.0343   -1
# 2017-08-24     90056.5        0      0   39.7    39.79   -1
# 2017-08-25       39.99     2232      1  40.33  38.2424    1
# 2017-08-28       39.99     2232      0  41.21  38.4455    1
# 2017-08-29       39.99     2232      0  41.47  39.7178    1
# 2017-08-30       39.99     2232      0  42.38  39.9358    1
# 2017-08-31       39.99     2232      0  41.57  40.7364    1
# 2017-09-01       39.99     2232      0  41.18  41.5547    1
# 2017-09-05       39.99     2232      0  41.21  43.5215    1
# 2017-09-06       39.99     2232      0   39.7   44.022    1
# 2017-09-07     84677.4        0     -1  37.92  44.4145   -1
# 2017-09-08     84677.4        0      0  38.11  43.2647   -1
# 2017-09-11     84677.4        0      0  39.28   42.164   -1
# 2017-09-12     84677.4        0      0  40.79  41.1258   -1
# 2017-09-13       36.23     2072      1  40.85  40.6885    1
# 2017-09-14       36.23     2072      0   40.6  41.0901    1
# 2017-09-15       36.23     2072      0   40.8  41.2722    1
# 2017-09-18       36.23     2072      0  40.44    41.85    1
# 2017-09-19       36.23     2072      0  39.54  42.1672    1
# 2017-09-20     81486.5        0     -1  39.31  42.3773   -1
# 2017-09-21     81486.5        0      0   39.4   41.378   -1
# 2017-09-22     81486.5        0      0  37.98  40.7607   -1
# 2017-09-25     81486.5        0      0  37.13  40.6653   -1
# 2017-09-26     81486.5        0      0  37.57  39.7627   -1
# 2017-09-27     81486.5        0      0  39.54  38.3702   -1
# 2017-09-28        25.6     2085      1  39.07   37.842    1
# 2017-09-29        25.6     2085      0  39.18  38.4434    1
# 2017-10-02        25.6     2085      0  38.65  39.1309    1
# 2017-10-03     80047.9        0     -1  38.38  39.6404   -1
# 2017-10-04        7.98     2092      1  38.26   39.416    1
# 2017-10-05        7.98     2092      0   38.5  39.6635    1
# 2017-10-06        7.98     2092      0  38.49  40.5022    1
# 2017-10-09     77474.7        0     -1  37.03  40.8088   -1
# 2017-10-10     77474.7        0      0  36.97  40.1164   -1
# 2017-10-11     77474.7        0      0  37.07  38.0208   -1
# 2017-10-12     77474.7        0      0  37.72  36.8566   -1
# 2017-10-13        1.26     2042      1  37.94   36.803    1
# 2017-10-16        1.26     2042      0  36.72  37.3087    1
# 2017-10-17        1.26     2042      0  37.31  37.9437    1
# 2017-10-18        1.26     2042      0   38.6  37.9933    1
# 2017-10-19        1.26     2042      0  36.87  38.2066    1
# 2017-10-20        1.26     2042      0  36.72  38.8238    1
# 2017-10-23        1.26     2042      0  35.38  38.8305    1
# 2017-10-24     72553.5        0     -1  35.53  38.8636   -1
# 2017-10-25     72553.5        0      0  35.21   37.793   -1
# 2017-10-26     72553.5        0      0  36.22  36.0863   -1
# 2017-10-27       35.25     1969      1  36.83  35.3753    1
# 2017-10-30       35.25     1969      0  36.74  35.7988    1
# 2017-10-31       35.25     1969      0  37.12  36.7881    1
# 2017-11-01       35.25     1969      0  36.96  37.3667    1
# 2017-11-02     70387.6        0     -1  35.73  37.6821   -1
# 2017-11-03     70387.6        0      0  34.54  37.3706   -1
# 2017-11-06     70387.6        0      0   36.6  36.3481   -1
# 2017-11-07       12.16     1943      1  36.22  35.8273    1
# 2017-11-09       12.16     1943      0  41.29    36.81    1
# 2017-11-10       12.16     1943      0  40.27   37.207    1
# 2017-11-13       12.16     1943      0  38.95  39.5256    1
# 2017-11-14     72991.2        0     -1  37.56  40.2241   -1
# 2017-11-15     72991.2        0      0  37.85  40.0368   -1
# 2017-11-16     72991.2        0      0  37.64  38.6343   -1
# 2017-11-17       10.14     1910      1  38.21  37.2491    1
# 2017-11-20       10.14     1910      0   37.9  37.5439    1
# 2017-11-21       10.14     1910      0   40.1  38.4702    1
# 2017-11-22       10.14     1910      0  39.97   39.614    1
# 2017-11-24       10.14     1910      0  39.51  41.1414    1
# 2017-11-27     72781.1        0     -1   38.1  41.9517   -1
# 2017-11-28     72781.1        0      0  38.67  41.2881   -1
# 2017-11-29     72781.1        0      0  38.42   39.549   -1
# 2017-11-30     72781.1        0      0  37.74   38.934   -1
# 2017-12-01     72781.1        0      0  38.84  38.7253   -1
# 2017-12-04       17.62     1888      1  38.54  38.6248    1
# 2017-12-05       17.62     1888      0  36.87  39.9122    1
# 2017-12-06     66852.8        0     -1   35.4  41.1917   -1
# 2017-12-07     66852.8        0      0  36.23  39.9409   -1
# 2017-12-08     66852.8        0      0  38.91  38.2049   -1
# 2017-12-11       31.54     1752      1  38.14   35.156    1
# 2017-12-12       31.54     1752      0  39.16  36.0124    1
# 2017-12-13       31.54     1752      0  41.41  37.5754    1
# 2017-12-14       31.54     1752      0  40.78  39.6801    1
# 2017-12-15       31.54     1752      0  40.46  41.6006    1
# 2017-12-18     71951.1        0     -1  41.05  42.1161   -1
# 2017-12-19     71951.1        0      0  40.03  41.4591   -1
# 2017-12-20     71951.1        0      0  40.01  41.2547   -1
# 2017-12-21     71951.1        0      0  40.64  39.7302   -1
# 2017-12-22        2.42     1784      1  40.33  39.0982    1
# 2017-12-26        2.42     1784      0  40.05  39.8144    1
# 2017-12-27        2.42     1784      0  40.25  41.0461    1
# 2017-12-28        2.42     1784      0  40.15   41.372    1
# 2017-12-29        2.42     1784      0  39.94  41.5553    1
# 2018-01-02       73414        0     -1  41.15  41.7883   -1
# 2018-01-03       19.06     1766      1  41.56  41.2188    1
# 2018-01-04       19.06     1766      0  41.82  41.5382    1
# 2018-01-05       19.06     1766      0  42.23  42.7996    1
# 2018-01-08       19.06     1766      0  43.64  44.2773    1
# 2018-01-09     74862.1        0     -1  42.38   44.744   -1
# 2018-01-10     74862.1        0      0  41.85  44.1357   -1
# 2018-01-11     74862.1        0      0   43.9  43.4179   -1
# 2018-01-12     74862.1        0      0  49.76  42.4657   -1
# 2018-01-16       33.34     1580      1  47.36   42.166    1
# 2018-01-17       33.34     1580      0  46.82  45.3999    1
# 2018-01-18       33.34     1580      0  44.89  46.9862    1
# 2018-01-19     72065.5        0     -1  45.59   47.013   -1
# 2018-01-22     72065.5        0      0  45.35  46.2951   -1
# 2018-01-23     72065.5        0      0   44.9  46.1776   -1
# 2018-01-24       20.99     1665      1  43.27  46.0398    1
# 2018-01-25       73231        0     -1  43.97  46.0687   -1
# 2018-01-26       37.36     1624      1  45.07  45.7108    1
# 2018-01-29       37.36     1624      0  45.26  45.8826    1
# 2018-01-30       37.36     1624      0  44.31  46.7419    1
# 2018-01-31     70421.5        0     -1  43.34   47.417   -1
# 2018-02-01     70421.5        0      0  42.53  46.7571   -1
# 2018-02-02     70421.5        0      0  41.22  45.5249   -1
# 2018-02-05     70421.5        0      0  39.35  44.4571   -1
# 2018-02-06     70421.5        0      0  40.95  43.3718   -1
# 2018-02-07       24.52     1717      1     41  41.4943    1
# 2018-02-08       24.52     1717      0  43.92   42.193    1
# 2018-02-09       24.52     1717      0  44.09  43.4841    1
# 2018-02-12     76001.8        0     -1  44.25  44.6832   -1
# 2018-02-13     76001.8        0      0  44.07  42.5742   -1
# 2018-02-14       12.23     1637      1  46.42  42.2399    1
# 2018-02-15       12.23     1637      0  46.78   42.717    1
# 2018-02-16       12.23     1637      0  46.01  45.1232    1
# 2018-02-20       12.23     1637      0  46.45  46.4326    1
# 2018-02-21       12.23     1637      0  46.96   46.475    1
# 2018-02-22       12.23     1637      0   47.1  46.5335    1
# 2018-02-23       12.23     1637      0  46.59  47.4105    1
# 2018-02-26       78932        0     -1  48.21  47.7416   -1
# 2018-02-27       25.92     1676      1  47.08  47.0342    1
# 2018-02-28       25.92     1676      0  46.47  47.1082    1
# 2018-03-01       25.92     1676      0  45.51  47.2968    1
# 2018-03-02       25.92     1676      0  46.92  47.6235    1
# 2018-03-05       25.92     1676      0  48.08  47.7152    1
# 2018-03-06       25.92     1676      0  48.39  48.7783    1
# 2018-03-07       25.92     1676      0  48.15   50.621    1
# 2018-03-08     81362.2        0     -1  48.53  51.1022   -1
# 2018-03-09     81362.2        0      0  48.55  50.7686   -1
# 2018-03-12     81362.2        0      0  48.74  49.3495   -1
# 2018-03-13     81362.2        0      0  47.86  48.4797   -1
# 2018-03-14       14.08     1699      1  47.88   48.424    1
# 2018-03-15     81498.1        0     -1  47.96  48.5731   -1
# 2018-03-16     81498.1        0      0  47.82  48.0082   -1
# 2018-03-19       25.97     1739      1  46.85  47.7929    1
# 2018-03-20       82072        0     -1  47.18  48.3101   -1
# 2018-03-21       82072        0      0  47.59  48.3067   -1
# 2018-03-22       31.79     1780      1  46.09  48.2412    1
# 2018-03-23     79900.4        0     -1  44.87  48.4196   -1
# 2018-03-26     79900.4        0      0  47.09  48.1786   -1

# %%
# Compro a la alza y a la baja
# movimiento que se realizao en el dia = estado
# estado = 1 comprar, estado = 0 mantener, estado = -1 vender
movimientos_ab= pd.DataFrame(columns = ["presupuesto","acciones","acciones_debo","estado","valor","pred","dif"],index = index_time_t)
movimientos_ab.presupuesto[0] = 100000 % ytt.iloc[0,0] ; movimientos_ab.acciones[0] = 100000 // ytt.iloc[0,0] ; movimientos_ab.acciones_debo[0] = 0 ;
movimientos_ab.estado[0] = 0 ; movimientos_ab.valor[0] = ytt.iloc[0,0] ;
movimientos_ab.pred[0] = predicted_stock_price.iloc[0,0] 

for i in range(1,len(diferencias)):
    if diferencias[i] == 1:
        if movimientos_ab.acciones[i-1] == 0:
            movimientos_ab.estado[i] = 1
            movimientos_ab.presupuesto[i] = ((movimientos_ab.presupuesto[i-1] - (movimientos_ab.acciones_debo[i-1] * ytt.iloc[i,0]))
                                         % ytt.iloc[i,0])
            movimientos_ab.acciones[i] = ((movimientos_ab.presupuesto[i-1] - (movimientos_ab.acciones_debo[i-1] * ytt.iloc[i,0]))
                                         // ytt.iloc[i,0])
            movimientos_ab.acciones_debo[i] = 0
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
        else:
            movimientos_ab.estado[i] = 0
            movimientos_ab.presupuesto[i] = movimientos_ab.presupuesto[i-1]
            movimientos_ab.acciones[i] = movimientos_ab.acciones[i-1]
            movimientos_ab.acciones_debo[i] = movimientos_ab.acciones_debo[i-1]
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
    elif diferencias[i] == 0:
            movimientos_ab.estado[i] = 0
            movimientos_ab.presupuesto[i] = movimientos_ab.presupuesto[i-1]
            movimientos_ab.acciones[i] = movimientos_ab.acciones[i-1]
            movimientos_ab.acciones_debo[i] = movimientos_ab.acciones_debo[i-1]
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
    elif diferencias[i] == -1:
        if movimientos_ab.acciones_debo[i-1] == 0:
            movimientos_ab.estado[i] = -1
            movimientos_ab.presupuesto[i] = ((movimientos_ab.presupuesto[i-1] + movimientos_ab.acciones[i-1] * ytt.iloc[i,0]) +
                                          ((movimientos_ab.presupuesto[i-1] + movimientos_ab.acciones[i-1] * ytt.iloc[i,0]) //
                                           ytt.iloc[i,0]) * ytt.iloc[i,0])
            movimientos_ab.acciones[i] = 0
            movimientos_ab.acciones_debo[i] = ((movimientos_ab.presupuesto[i-1] + movimientos_ab.acciones[i-1] * ytt.iloc[i,0]) //
                                           ytt.iloc[i,0]) # Las pido prestadas
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
        else:
            movimientos_ab.estado[i] = 0
            movimientos_ab.presupuesto[i] = movimientos_ab.presupuesto[i-1]
            movimientos_ab.acciones[i] = movimientos_ab.acciones[i-1]
            movimientos_ab.acciones_debo[i] = movimientos_ab.acciones_debo[i-1]
            movimientos_ab.valor[i] = ytt.iloc[i,0]
            movimientos_ab.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_ab.dif[i] = diferencias[i]
            
movimientos_ab = movimientos_ab.drop(movimientos_ab.tail(1).index)
print(movimientos_ab.tail(1))
if movimientos_ab.acciones_debo[len(movimientos_ab)-1] == 0 :
    valor_f_ab = movimientos_ab.presupuesto[len(movimientos_ab)-1] + movimientos_ab.valor[len(movimientos_ab)-1] * movimientos_ab.acciones[len(movimientos_ab)-1]
else:
    valor_f_ab = movimientos_ab.presupuesto[len(movimientos_ab)-1] - movimientos_ab.valor[len(movimientos_ab)-1] * movimientos_ab.acciones_debo[len(movimientos_ab)-1]
ganancia_ab = valor_f_ab - 100000
print('Valor Final = %.2f' % valor_f_ab)
print('Ganancia con margen = %.2f' % ganancia_ab)
# Out:
#            presupuesto acciones acciones_debo estado  valor     pred dif
# 2018-03-26      245093        0          4208      0  29.81  28.2798  -1
# Valor Final = 119652.39
# Ganancia con margen = 19652.39

# %%
print(movimientos_ab)

# %%
# Compro a la baja
# movimiento que se realizao en el dia = estado
# estado = 1 comprar, estado = 0 mantener, estado = -1 vender
movimientos_baja = pd.DataFrame(columns = ["presupuesto","acciones","acciones_debo","estado","valor","pred","dif"],index = index_time_t)
movimientos_baja.presupuesto[0] = 100000  ; movimientos_baja.acciones[0] = 0 ; movimientos_baja.acciones_debo[0] = 0 ;
movimientos_baja.estado[0] = 0 ; movimientos_baja.valor[0] = ytt.iloc[0,0] ;
movimientos_baja.pred[0] = predicted_stock_price.iloc[0,0] 

for i in range(1,len(diferencias)):
    if diferencias[i] == 1:
        if movimientos_baja.acciones[i-1] == 0:
            movimientos_baja.estado[i] = 1
            movimientos_baja.presupuesto[i] = ((movimientos_baja.presupuesto[i-1] - (movimientos_baja.acciones_debo[i-1] * ytt.iloc[i,0])))
            movimientos_baja.acciones[i] = 0
            movimientos_baja.acciones_debo[i] = 0
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
        else:
            movimientos_baja.estado[i] = 0
            movimientos_baja.presupuesto[i] = movimientos_baja.presupuesto[i-1]
            movimientos_baja.acciones[i] = movimientos_baja.acciones[i-1]
            movimientos_baja.acciones_debo[i] = movimientos_baja.acciones_debo[i-1]
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
    elif diferencias[i] == 0:
            movimientos_baja.estado[i] = 0
            movimientos_baja.presupuesto[i] = movimientos_baja.presupuesto[i-1]
            movimientos_baja.acciones[i] = movimientos_baja.acciones[i-1]
            movimientos_baja.acciones_debo[i] = movimientos_baja.acciones_debo[i-1]
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
    elif diferencias[i] == -1:
        if movimientos_baja.acciones_debo[i-1] == 0:
            movimientos_baja.estado[i] = -1
            movimientos_baja.presupuesto[i] = ((movimientos_baja.presupuesto[i-1]) + (movimientos_baja.presupuesto[i-1] //
                                           ytt.iloc[i,0]) * ytt.iloc[i,0])
            movimientos_baja.acciones[i] = 0
            movimientos_baja.acciones_debo[i] = (movimientos_baja.presupuesto[i-1] // ytt.iloc[i,0]) # Las pido prestadas
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
        else:
            movimientos_baja.estado[i] = 0
            movimientos_baja.presupuesto[i] = movimientos_baja.presupuesto[i-1]
            movimientos_baja.acciones[i] = movimientos_baja.acciones[i-1]
            movimientos_baja.acciones_debo[i] = movimientos_baja.acciones_debo[i-1]
            movimientos_baja.valor[i] = ytt.iloc[i,0]
            movimientos_baja.pred[i] = predicted_stock_price.iloc[i,0]
            movimientos_baja.dif[i] = diferencias[i]
            
movimientos_baja = movimientos_baja.drop(movimientos_baja.tail(1).index)
print(movimientos_baja.tail(1))
if movimientos_baja.acciones_debo[len(movimientos_baja)-1] == 0 :
    valor_f_baja = movimientos_baja.presupuesto[len(movimientos_baja)-1] + movimientos_baja.valor[len(movimientos_baja)-1] * movimientos_baja.acciones[len(movimientos_baja)-1]
else:
    valor_f_baja = movimientos_baja.presupuesto[len(movimientos_baja)-1] - movimientos_baja.valor[len(movimientos_baja)-1] * movimientos_baja.acciones_debo[len(movimientos_baja)-1]
ganancia_baja = valor_f_baja - 100000
print('Valor Final = %.2f' % valor_f_baja)
print('Ganancia con margen = %.2f' % ganancia_baja)
# Out:
#            presupuesto acciones acciones_debo estado  valor     pred dif
# 2018-03-26      187013        0          3211      0  29.81  28.2798  -1
# Valor Final = 91292.63
# Ganancia con margen = -8707.37

# %%
print(movimientos_baja)
